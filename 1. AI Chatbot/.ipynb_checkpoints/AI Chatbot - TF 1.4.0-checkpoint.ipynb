# %% [markdown]
# # AI CHATBOT
#
# <hr>
#
# In this jupyter notebook, we will build a chatbot using sequence to sequence model.

# %%
# Import the libraries
import numpy as np
import tensorflow as tf
import contractions
from tqdm import tqdm
import re
import time

# %%
# Tensorflow 1.4.0
assert tf.__version__ == '1.4.0'

# %% [markdown]
# <br>
#
# # 1. Load the Dataset
#
# <hr>
#
# For creating our chatbot, we will use a data set called <a href="https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html">Cornell Movie Dialogs Corpus</a> which this corpus contains a large metadata-rich collection of fictional conversations extracted from raw movie scripts:
#
# - 220,579 conversational exchanges between 10,292 pairs of movie characters
# - involves 9,035 characters from 617 movies
# - in total 304,713 utterances
#
#
# However for our purpose, we will only use <i>movie_conversations.txt</i> and <i>movie_lines.txt</i>.

# %%
# Load the lines dataset
lines = open(file = "./dataset/movie_lines.txt", encoding = "utf-8", errors = "ignore").read()

# Split the dataset for every line
lines = lines.split("\n")

# %%
# Print lines
lines[:5]
# Out:
# ['L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!',
#  'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!',
#  'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.',
#  'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?',
#  "L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go."]

# %% [markdown]
# In lines dataset, we have 5 columns. Now let's consider the first line:
#
# - **Line id** --> like L1045
# - **User id** --> like u0
# - **Movie id** --> like m0
# - **User name** --> like BIANCA
# - **Text** --> like They do not!

# %%
# Load the conversations dataset
conversations = open(file = "./dataset/movie_conversations.txt", encoding = "utf-8", errors = "ignore").read()

# Split the dataset for every line
conversations = conversations.split("\n")

# %%
# Print convesations
conversations[:5]
# Out:
# ["u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L198', 'L199']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L200', 'L201', 'L202', 'L203']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L204', 'L205', 'L206']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L207', 'L208']"]

# %% [markdown]
# In conversations dataset, we have 4 columns. Now let's consider the first line:
#
# - **User number 1** --> like u0
# - **User number 2** --> like u2
# - **Movie id** --> like m0
# - **Conversations (array of line ids)** --> ['L194', 'L195', 'L196', 'L197']

# %% [markdown]
# <br>
#
# # 2. Data Prepration
#
# <hr>
#
# Before applying the preprocessing steps, we need to prepare our dataset. In other word, we need to exactly specify our inputs and our outputs.

# %%
### Create a dictionary that maps each line id and its line text

# Initialize an empty dictionary
id2line = {}

# Iterate through lines
for i_line in lines:
    
    # Split the line with +++$+++                       # _ before lines means that this is temporary
    _lines = i_line.split(" +++$+++ ")
    
    # Make sure the length is 5 (otherwise we are going to get the wrong information because of indexing)
    if len(_lines) == 5:
        
        # Get the line id 
        line_id = _lines[0]
        
        # Get the text
        text = _lines[-1]
        
        # Map line ids to its text
        id2line[line_id] = text

# %%
# Take a look at id2line
id2line
# Out:
# {'L1045': 'They do not!',
#  'L1044': 'They do to!',
#  'L985': 'I hope so.',
#  'L984': 'She okay?',
#  'L925': "Let's go.",
#  'L924': 'Wow',
#  'L872': "Okay -- you're gonna need to learn how to lie.",
#  'L871': 'No',
#  'L870': 'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'L869': 'Like my fear of wearing pastels?',
#  'L868': 'The "real you".',
#  'L867': 'What good stuff?',
#  'L866': "I figured you'd get to the good stuff eventually.",
#  'L865': 'Thank God!  If I had to hear one more story about your coiffure...',
#  'L864': "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'L863': 'What crap?',
#  'L862': 'do you listen to this crap?',
#  'L861': 'No...',
#  'L860': 'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'L699': 'You always been this selfish?',
#  'L698': 'But',
#  'L697': "Then that's all you had to say.",
#  'L696': 'Well, no...',
#  'L695': "You never wanted to go out with 'me, did you?",
#  'L694': 'I was?',
#  'L693': 'I looked for you back at the party, but you always seemed to be "occupied".',
#  'L663': 'Tons',
#  'L662': 'Have fun tonight?',
#  'L578': 'I believe we share an art instructor',
#  'L577': 'You know Chastity?',
#  'L576': 'Looks like things worked out tonight, huh?',
#  'L575': 'Hi.',
#  'L407': "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  'L406': "So that's the kind of guy she likes? Pretty ones?",
#  'L405': "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  'L404': "She's not a...",
#  'L403': "I'm workin' on it. But she doesn't seem to be goin' for him.",
#  'L402': "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  'L401': 'Sure have.',
#  'L368': "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  'L367': 'How do you get your hair to look like that?',
#  'L366': "You're sweet.",
#  'L365': 'You have my word.  As a gentleman',
#  'L364': "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  'L363': 'You got something on your mind?',
#  'L281': 'Where?',
#  'L280': 'There.',
#  'L277': "Well, there's someone I think might be --",
#  'L276': 'How is our little Find the Wench A Date plan progressing?',
#  'L275': 'Forget French.',
#  'L274': "That's because it's such a nice one.",
#  'L273': "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  'L272': "Right.  See?  You're ready for the quiz.",
#  'L271': "C'esc ma tete. This is my head",
#  'L208': 'Let me see what I can do.',
#  'L207': 'Gosh, if only we could find Kat a boyfriend...',
#  'L206': "That's a shame.",
#  'L205': 'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'L204': 'Why?',
#  'L203': 'Seems like she could get a date easy enough...',
#  'L202': "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'L201': 'Cameron.',
#  'L200': "No, no, it's my fault -- we didn't have a proper introduction ---",
#  'L199': 'Forget it.',
#  'L198': "You're asking me out.  That's so cute. What's your name again?",
#  'L197': "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'L196': 'Not the hacking and gagging and spitting part.  Please.',
#  'L195': "Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'L194': 'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  'L953': 'I did.',
#  'L952': "You think you ' re the only sophomore at the prom?",
#  'L660': "I don't have to be home 'til two.",
#  'L659': 'I have to be home in twenty minutes.',
#  'L600': "All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  'L599': "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  'L598': "Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  'L597': "Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  'L596': 'Is he oily or dry?',
#  'L595': "He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'L580': 'Would you mind getting me a drink, Cameron?',
#  'L579': 'Great',
#  'L573': 'Joey.',
#  'L572': 'Who?',
#  'L571': 'Where did he go?  He was just here.',
#  'L51': 'You might wanna think about it',
#  'L50': 'No.',
#  'L49': 'Did you change your hair?',
#  'L760': "You know the deal.  I can ' t go if Kat doesn't go --",
#  'L759': 'Listen, I want to talk to you about the prom.',
#  'L758': "You're concentrating awfully hard considering it's gym class.",
#  'L757': 'Hi, Joey.',
#  'L756': 'Hey, sweet cheeks.',
#  'L593': "My agent says I've got a good shot at being the Prada guy next year.",
#  'L592': 'Neat...',
#  'L591': "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  'L590': 'Queen Harry?',
#  'L589': 'So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'L397': 'Hopefully.',
#  'L396': "Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'L395': 'Expensive?',
#  'L394': "It's more",
#  'L1052': 'Perm?',
#  'L1051': 'Patrick -- is that- a.',
#  'L1022': "It's just you.",
#  'L1021': 'Is that woman a complete fruit-loop or is it just me?',
#  'L1011': 'No! I just wanted',
#  'L1010': 'What? To completely damage me?  To send me to therapy forever? What?',
#  'L1009': 'I just wanted --',
#  'L1008': 'You set me up.',
#  'L1007': 'Let go!',
#  'L983': 'So did you',
#  'L982': 'You looked beautiful last night, you know.',
#  'L914': "I guess I'll never know, will I?",
#  'L913': "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  'L912': "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  'L911': 'I guess I thought I was protecting you.',
#  'L910': "I'm not stupid enough to repeat your mistakes.",
#  'L909': "That's not",
#  'L908': "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  'L907': 'I wanted to let you make up your own mind about him.',
#  'L906': "Why didn't you tell me?",
#  'L905': 'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  'L904': 'But',
#  'L903': "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'L902': 'You did what?',
#  'L901': 'He said everyone was doing it.  So I did it.',
#  'L900': 'As in...',
#  'L899': 'Now I do.  Back then, was a different story.',
#  'L898': 'But you hate Joey',
#  'L897': 'He was, like, a total babe',
#  'L896': 'Why?',
#  'L895': 'In 9th.  For a month',
#  'L894': 'What?',
#  'L893': 'Joey never told you we went out, did he?',
#  'L892': "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  'L891': "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'L890': 'Like you care.',
#  'L889': "Listen, I know you hate having to sit home because I'm not Susie High School.",
#  'L656': "You're welcome.",
#  'L655': "I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  'L602': "I really don't think I need any social advice from you right now.",
#  'L601': 'Bianca, I need to talk to you -- I need to tell you --',
#  'L543': 'Can we go now?',
#  'L542': 'You are so completely unbalanced.',
#  'L533': "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  'L532': "It's Shakespeare.  Maybe you've heard of him?",
#  'L531': "Like I'm supposed to know what that even means.",
#  'L530': "At least I'm not a clouted fen- sucked hedge-pig.",
#  'L529': "Can't you forget for just one night that you're completely wretched?",
#  'L527': "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  'L526': "What's normal?",
#  'L525': "You're ruining my life'  Because you won't be normal, I can't be normal.",
#  'L445': "I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  'L444': 'What do you think?',
#  'L443': "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  'L442': "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  'L441': "Oh my God, does this mean you're becoming normal?",
#  'L320': 'Can you at least start wearing a bra?',
#  'L319': "I have the potential to smack the crap out of you if you don't get out of my way.",
#  'L165': 'Nowhere... Hi, Daddy.',
#  'L164': "Where've you been?",
#  'L923': "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  'L922': "I'm missing something.",
#  'L884': "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  'L883': "You're not going unless your sister goes.  End of story.",
#  'L882': 'He\'s not a "hot rod".  Whatever that is.',
#  'L881': "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'L880': 'No, but',
#  'L879': 'The prom?  Kat has a date?',
#  'L878': "Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  'L546': "Because she'll scare them away.",
#  'L545': 'Why?',
#  'L544': "Promise me you won't talk to any boys unless your sister is present.",
#  'L540': 'Just for a minute',
#  'L539': 'Daddy, no!',
#  'L538': 'Wear the belly before you go.',
#  'L537': "It's just a party. Daddy.",
#  'L536': "Oh, God.  It's starting.",
#  'L524': "If Kat's not going, you're not going.",
#  'L523': 'Daddy, people expect me to be there!',
#  'L521': 'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  'L520': 'Otherwise known as an orgy?',
#  'L519': 'If you must know, we were attempting to go to a small study group of friends.',
#  'L518': "And where're you going?",
#  'L517': 'Daddy, I --',
#  'L190': 'Exactly my point',
#  'L189': "But she doesn't want to date.",
#  'L183': "But it's not fair -- she's a mutant, Daddy!",
#  'L182': "Then neither will you.  And I'll get to sleep at night.",
#  'L181': 'What if she never starts dating?',
#  'L180': "No! You're not dating until your sister starts dating.  End of discussion.",
#  'L179': "Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  'L463': "Just sent 'em through.",
#  'L462': 'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'L461': 'Never',
#  'L460': 'Fan of a fan.  You see a couple of minors come in?',
#  'L459': "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'L458': 'Always a pleasure, Brucie.',
#  'L779': "Best case scenario, you're back on the payroll for awhile.",
#  'L778': 'You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  'L586': "No, I ' m not.",
#  'L585': "Buttholus extremus.  But hey, you're making progress.",
#  'L584': "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  'L583': 'Extremely unfortunate maneuver.',
#  'L500': "Hell, I've just been going over the whole thing in my head and -",
#  'L499': 'You told me that part already.',
#  'L433': "It's her favorite band.",
#  'L432': 'Assail your ears for one night.',
#  'L425': "Okay!  I wasn't sure",
#  'L424': "He's pretty!",
#  'L419': 'Dead at forty-one.',
#  'L418': 'Her favorite uncle',
#  'L417': "It's a lung cancer issue",
#  'L416': 'Number one.  She hates smokers',
#  'L391': "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  'L390': 'Will Bogey get bent?',
#  'L389': "In that case, we'll need to make it a school-wide blow out.",
#  'L388': 'This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  'L245': "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  'L244': 'You got him involved?',
#  'L225': "Hey -- I've gotta have a few clients when I get to Wall Street.",
#  'L224': 'I thought you hated those people.',
#  'L223': "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  'L222': "That's what I just said",
#  'L221': "Did she actually say she'd go out with you?",
#  'L220': "Forget his reputation.  Do you think we've got a plan or not?",
#  'L219': "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  'L218': 'They always let felons sit in on Honors Biology?',
#  'L217': "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'L216': 'He seems like he thrives on danger',
#  'L215': "What makes you think he'll do it?",
#  'L213': 'You wanna go out with him?',
#  'L212': 'What about him?',
#  'L211': "Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'L210': 'I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'L159': 'The mewling, rampalian wretch herself.',
#  'L158': "That's her?  Bianca's sister?",
#  'L157': 'Yeah, just a minor encounter with the shrew.',
#  'L147': 'You could consecrate with her, my friend.',
#  'L146': "You mean I'd get a chance to talk to her?",
#  'L145': 'Guess who just signed up for a tutor?',
#  'L144': "Sure do ... my Mom's from Canada",
#  'L143': 'You know French?',
#  'L142': "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  'L141': 'He always have that shit-eating grin?',
#  'L140': "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'L139': 'Why do girls like that always like guys like that?',
#  'L92': "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  'L91': 'Why not?',
#  'L90': "Bianca Stratford.  Sophomore. Don't even think about it",
#  'L89': 'Who is she?',
#  'L88': 'You burn, you pine, you perish?',
#  'L87': 'That girl -- I --',
#  'L78': 'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  'L77': "That I'm used to.",
#  'L74': 'Couple thousand. Most of them evil',
#  'L73': 'How many people go here?',
#  'L72': 'Get out!',
#  'L71': 'Thirty-two.',
#  'L70': 'How many people were in your old school?',
#  'L69': "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'L68': 'I was kidding. People actually live there?',
#  'L67': "North, actually.  How'd you   ?",
#  'L66': 'So -- which Dakota you from?',
#  'L65': "C'mon.  I'm supposed to give you the tour.",
#  'L64': 'So they tell me...',
#  'L63': 'You the new guy?',
#  'L781': 'You get the girl.',
#  'L780': "What's the worst?",
#  'L745': 'Where?',
#  'L744': 'She kissed me.',
#  'L743': "You makin' any headway?",
#  'L741': "She just needs time to cool off I'll give it a day.",
#  'L740': "She hates you with the fire of a thousand suns .  That's a direct quote",
#  'L726': "I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  'L725': "What'd you do to her?",
#  'L625': 'Then, go get her',
#  'L624': 'Sure',
#  'L623': 'Cameron -- do you like the girl?',
#  'L622': "She's partial to Joey, not me",
#  'L621': "What 're you talking about?",
#  'L620': "It's off. The whole thing.",
#  'L619': "Cameron, I'm a little busy",
#  'L431': "Don't make me do it, man",
#  'L430': 'Gigglepuss is playing there tomorrow night.',
#  'L427': "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  'L426': 'Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  'L412': "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  'L411': "What've you got for me?",
#  'L386': "Yeah -- we'll see.",
#  'L385': 'And he means that strictly in a non- prison-movie type of way.',
#  'L558': 'And why would I do that?',
#  'L557': 'Leave my sister alone.',
#  'L556': 'Your sister here?',
#  'L555': 'Away.',
#  'L554': 'Where ya goin?',
#  'L336': 'Not at all',
#  'L335': 'Hey -- do you mind?',
#  'L150': "They're running the rest of me next month.",
#  'L149': 'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  'L148': "The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  'L748': "Enough with the Barbie n' Ken shit. I know.",
#  'L747': "I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'L609': 'Get her to act like a human',
#  'L608': 'Do what?',
#  'L607': "How'd you do it?",
#  'L606': "A deal's a deal.",
#  'L605': "It's about time.",
#  'L358': 'Forget her sister, then.',
#  'L357': 'Forget it.',
#  'L356': 'A hundred bucks a date.',
#  'L355': 'What?',
#  'L354': 'I just upped my price',
#  'L352': 'I got her under control. She just acts crazed in public to keep up the image.',
#  'L351': "Watching the bitch trash my car doesn't count as a date.",
#  'L350': "I'm on it",
#  'L349': 'When I shell out fifty, I expect results.',
#  'L301': "Fifty, and you've got your man.",
#  'L300': "Take it or leave it.  This isn't a negotiation.",
#  'L299': 'Fine, thirty.',
#  'L298': "I can't take a girl like that out on twenty bucks.",
#  'L297': 'How much?',
#  'L296': "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  'L295': "You're gonna pay me to take out some girl?",
#  'L294': 'You got it, Verona.  I pick up the tab, you do the honors.',
#  'L292': "But you'd go out with her if you had the cake?",
#  'L291': 'You need money to take a girl out',
#  'L290': 'You just said',
#  'L289': "Sure, Sparky.  I'll get right on it.",
#  'L288': 'Yeah, whatever.  I want you to go out with her.',
#  'L287': 'Two legs, nice rack...',
#  'L286': 'What do you think?',
#  'L285': 'Yeah',
#  'L509': "Hey -- it's all for the higher good right?",
#  'L508': "You better not fuck this up.  I'm heavily invested.",
#  'L505': 'What?  We took bathes together when we were kids.',
#  'L504': 'You and Verona?',
#  'L503': "Uh,  yeah.  We're old friend*",
#  'L502': "I hear you're helpin' Verona.",
#  'L240': "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  'L239': 'Does this conversation have a purpose?',
#  'L238': "But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  'L236': "We're not.",
#  'L235': "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  'L234': "We don't chat.",
#  'L233': 'Nope - just came by to chat',
#  'L232': 'Are you lost?',
#  'L231': 'Hey.',
#  'L949': "Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'L948': 'William - he asked me to meet him here.',
#  'L947': 'Who?',
#  'L946': 'Have you seen him?',
#  'L755': 'Oh, good.  Something new and different for us.',
#  'L754': "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  'L753': "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  'L752': 'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  'L751': "Well, I guess we're not, since we don't have dates .",
#  'L750': 'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  'L721': 'I got drunk.  I puked.  I got rejected. It was big fun.',
#  'L720': "You didn't",
#  'L719': 'I did Bianca a favor and it backfired.',
#  'L718': "You didn't have a choice?  Where's Kat and what have you done with her?",
#  'L717': "I didn't have a choice.",
#  'L716': 'You went to the party?  I thought we were officially opposed to suburban social activity.',
#  'L491': 'Who cares?',
#  'L490': "What'd he say?",
#  'L448': 'No fear.',
#  'L447': "You think this'll work?",
#  'L254': 'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'L253': 'Does it matter?',
#  'L252': "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'L251': 'Neither has his heterosexuality.',
#  'L250': "That's never been proven",
#  'L249': "William didn't even go to high school",
#  'L248': 'William would never have gone to a state school.',
#  'L247': 'So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  'L152': "You could always go with me.  I'm sure William has some friends.",
#  'L151': 'The people at this school are so incredibly foul.',
#  'L134': "But imagine the things he'd say during sex.",
#  'L133': "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'L132': 'An attempted slit.',
#  'L131': "What's this?",
#  'L130': 'Just a little.',
#  'L129': 'Mandella, eat.  Starving yourself is a very slow way to die.',
#  'L128': 'Block E?',
#  'L127': 'He always look so',
#  'L126': "I'm sure he's completely incapable of doing anything that interesting.",
#  'L125': "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  'L124': 'Patrick Verona   Random skid.',
#  'L123': "Who's that?",
#  'L1043': "Don ' t you even dare. . .",
#  'L1042': 'Oh, Bianca?  Can you get me my freshman yearbook?',
#  'L1041': 'Because I like to torture you.',
#  'L1040': 'Why is my veggie burger the only burnt object on this grill?',
#  'L1035': 'Yeah, but then I fucked up. I fell for her.',
#  'L1034': 'Is that right?',
#  'L1033': 'Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'L1032': 'I thought you could use it. When you start your band.',
#  'L1031': 'A Fender Strat. You bought this?',
#  'L977': "I didn't care about the money.",
#  'L976': 'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  'L975': "It wasn't like that.",
#  'L974': 'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  'L973': 'Wait I...',
#  'L961': 'It gets worse -- you still have your freshman yearbook?',
#  'L960': "That ' s completely adorable!",
#  'L959': "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'L958': 'What?',
#  'L957': "My grandmother's .",
#  'L940': "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'L939': 'Oh huh',
#  'L938': "It's just something I had.  You know",
#  'L937': "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  'L936': "How'd you get a tux at the last minute?",
#  'L857': "Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  'L856': 'Answer the question, Patrick',
#  'L855': 'You need therapy.  Has anyone ever told you that?',
#  'L854': 'You tell me.',
#  'L853': 'So I have to have a motive to be with you?',
#  'L852': 'Create a little drama?  Start a new rumor?  What?',
#  'L848': "Because I don't want to. It's a stupid tradition.",
#  'L847': 'Why not?',
#  'L846': "No, I won't go with you",
#  'L845': 'No what?',
#  'L844': 'No.',
#  'L843': 'You know what I mean',
#  'L842': 'Is that a request or a command?',
#  'L841': 'Go to the prom with me',
#  'L840': "You're amazingly self-assured. Has anyone ever told you that?",
#  'L839': 'No one else knows',
#  'L838': 'What?',
#  'L837': "You're sweet.  And sexy.  And completely hot for me.",
#  'L836': 'No -- something real.  Something no one else knows.',
#  'L835': 'I hate peas.',
#  'L834': 'Tell me something true.',
#  'L832': "I know the porn career's a lie.",
#  'L831': 'Hearsay.',
#  'L830': 'The duck?',
#  'L829': 'Fallacy.',
#  'L828': 'State trooper?',
#  'L825': 'For. . . ?',
#  'L824': 'You up for it?',
#  'L823': 'You never disappointed me.',
#  'L822': 'How?',
#  'L821': 'Then you screwed up',
#  'L820': 'Something like that',
#  'L819': "So if you disappoint them from the start, you're covered?",
#  'L818': "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  'L817': 'Yes',
#  'L816': 'Acting the way we do.',
#  'L815': "So what's your excuse?",
#  'L814': "Yeah, well, don't let it get out",
#  'L813': 'A soft side? Who knew?',
#  'L812': 'I dazzled him with my wit',
#  'L811': "So how'd you get Chapin to look the other way?",
#  'L810': 'Good call.',
#  'L809': 'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'L808': 'The Partridge Family?',
#  'L806': 'Maybe.',
#  'L805': 'You want me to climb up and show you how to get down?',
#  'L804': "Forget it.  I'm stayin'.",
#  'L803': 'Put your right foot there --',
#  'L802': "Try lookin' at it from this angle",
#  'L801': "C'mon.  It's not that bad",
#  'L800': "I guess I never told you I'm afraid of heights.",
#  'L799': 'Look up, sunshine',
#  'L798': 'He left!  I sprung the dickhead and he cruised on me.',
#  'L774': 'Other than my upchuck reflex? Nothing.',
#  'L773': 'So what did I have an effect on ?',
#  'L772': "Don't for one minute think that you had any effect whatsoever on my panties.",
#  'L771': 'Unwelcome?  I guess someone still has her panties in a twist.',
#  'L770': 'Unwelcome.',
#  'L769': 'Wholesome.',
#  'L768': 'Pleasant?',
#  'L767': "You 're so --",
#  'L766': 'I heard there was a poetry reading.',
#  'L765': 'What are you doing here?',
#  'L764': 'Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  'L690': "No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'L689': 'BIANCA',
#  'L688': 'Who?',
#  'L687': "He just wants me to be someone I'm not.",
#  'L686': "So what ' s up with your dad?  He a pain in the ass?",
#  'L684': "I'm gettin' there",
#  'L683': 'Oh, so now you think you know me?',
#  'L682': "You don't strike me as the type that would ask permission.",
#  'L681': "My father wouldn't approve of that that",
#  'L680': 'Start a band?',
#  'L679': 'This.',
#  'L678': 'Do what?',
#  'L677': 'I should do this.',
#  'L676': "Why'd you lie?",
#  'L675': "Then why'd you ask?",
#  'L674': "No, you weren't",
#  'L673': 'Maybe.',
#  'L672': 'Were you in jail?',
#  'L671': 'Busy',
#  'L670': 'When you were gone last year -- where were you?',
#  'L669': "But it's Gigglepuss - I know you like them.  I saw you there.",
#  'L668': "And I'm in control of it.",
#  'L651': 'What?',
#  'L650': 'Kat! Wake up!',
#  'L646': 'You know what they say',
#  'L645': 'I thought you were above all that',
#  'L644': 'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  'L643': "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  'L642': 'I hate him.',
#  'L641': 'Dorsey.',
#  'L640': 'Who?',
#  'L639': "Why'd you let him get to you?",
#  'L636': 'Just let me sit down.',
#  'L635': "See that?  Who needs affection when I've got blind hatred?",
#  'L634': 'Like you could find one',
#  'L633': "Because then I'd have to start taking out girls who like me.",
#  'L632': 'Why?',
#  'L631': 'Sure, I do',
#  'L630': "You don't care if I die",
#  'L629': 'I told you',
#  'L628': "Why 're you doing this?",
#  'L627': "Leave it to you to use big words when you're shitfaced.",
#  'L626': 'This is so patronizing.',
#  'L616': 'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...',
#  'L615': 'I know, just let me sleep',
#  'L614': "Uh, uh. You lie down and you'll go to sleep",
#  'L613': 'I just need to lie down for awhile',
#  'L612': "You're not okay.",
#  'L611': "I'm fine. I'm",
#  'L610': 'Okay?',
#  'L567': "Funny, you're the only one",
#  'L566': 'I say, do what you wanna do.',
#  'L565': '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  'L564': "What's this?",
#  'L483': "Why, don't you?",
#  'L482': 'You know who The Raincoats are?',
#  'L481': "You know, these guys are no Bikini Kill or The Raincoats, but they're right up there.",
#  'L477': "Do you mind?  You're sort of ruining it for me.",
#  'L476': "That's what you want, isn't it?",
#  'L475': 'Excuse me?',
#  'L474': '',
#  'L473': 'hey.  Great show, huh?',
#  'L334': "Depends on the topic. My fenders don't really whip me into a verbal frenzy.",
#  'L333': "You're not a big talker, are you?",
#  'L332': 'Hi',
#  'L331': "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  'L330': 'Are you following me?',
#  'L328': 'Seven-thirty?',
#  'L327': 'You -- covered in my vomit.',
#  'L326': 'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  'L325': 'And why would I do that?',
#  'L324': "Then say you'll spend Dollar Night at the track with me.",
#  'L323': "I don't really think you warrant that strong an emotion.",
#  'L322': "You hate me don't you?",
#  'L313': 'I know a lot more than that',
#  'L312': 'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  'L311': "The night I take you to places you've never been before.  And back.",
#  'L310': 'Oh, right.  Friday.',
#  'L309': 'Pick you up Friday, then',
#  'L307': 'My mission in life.',
#  'L306': "There's a way to get a guy's attention.",
#  'L305': 'Sweating like a pig, actually.  And yourself?',
#  'L304': "I mean Wo-man.  How ya doin'?",
#  'L1000': "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check.",
#  'L999': 'When I go?',
#  'L998': "You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game.",
#  'L997': 'No -- impressed.',
#  'L996': "What's the matter?  Upset that I rubbed off on her?",
#  'L995': 'Bianca did what?',
#  'L994': 'The part where Bianca beat the hell out of some guy.',
#  'L993': 'Which parts?',
#  'L992': 'Parts of it.',
#  'L991': 'So tell me about this dance. Was it fun?',
#  'L990': 'No, Daddy.',
#  'L989': "I don't understand the allure of dehydrated food.  Is this something I should be hip to?",
#  'L988': 'Funny.',
#  'L987': 'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  'L986': 'Was that your sister?',
#  'L347': 'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --',
#  'L346': "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'L345': "So what I want doesn't matter?",
#  'L344': "As a parent, that's my right",
#  'L343': "Because you're making decisions for me.",
#  'L342': "Why can't we agree on this?",
#  'L341': 'I thought you were punishing me.',
#  'L340': 'Is this about Sarah Lawrence? You punishing me?',
#  'L339': 'Then tell them I had a seizure.',
#  'L338': 'My insurance does not cover PMS',
#  'L185': 'Enough!',
#  'L184': 'This from someone whose diary is devoted to favorite grooming tips?',
#  'L174': 'You decided.',
#  'L173': 'I thought we decided you were going to school here.  At U of 0.',
#  'L172': 'I know.',
#  'L1018': 'Just smack her now.',
#  'L1017': 'Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?',
#  'L109': 'No ... I believe "heinous bitch" is the term used most often.',
#  'L108': 'Tempestuous?',
#  'L107': 'The point is Kat -- people perceive you as somewhat ...',
#  'L106': 'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  'L105': "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  'L104': 'Expressing my opinion is not a terrorist action.',
#  'L103': "Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#  'L738': 'Yeah...',
#  'L737': 'Kat a fan, too?',
#  'L736': 'Right.',
#  'L735': 'Macbeth, right?',
#  'L733': 'Oh yeah.',
#  'L732': 'You think?',
#  'L731': 'Yeah.  I guess.',
#  'L730': 'Cool pictures.  You a fan?',
#  'L729': 'Hi.',
#  'L728': 'Hey there.  Tired of breathing?',
#  'L777': "Man -- don't say shit like that to  me. People can hear you.",
#  'L776': 'Sweet love, renew thy force!',
#  'L775': "You were right. She's still pissed.",
#  'L724': "No - I've got a sweet-payin' job that I'm about to lose.",
#  'L723': 'So you got cozy with she who stings?',
#  'L437': "I'm likin' you guys better",
#  'L436': 'I prefer to think of it simply as an alternative to what the law allows.',
#  'L429': 'Yeah.',
#  'L428': 'Ever been to Club Skunk?',
#  'L421': 'Just for now.',
#  'L420': 'Are you telling me I\'m a -  "non-smoker"?',
#  'L415': 'Good enough.',
#  'L414': 'What?!',
#  'L384': "We're your guys.",
#  'L383': 'You two are gonna help me tame the wild beast?',
#  'L382': "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl.",
#  'L381': 'So Dorsey can get the girl?',
#  'L380': "That's where we can help you.  With Kat.",
#  'L379': "Dorsey can plow whoever he wants. I'm just in this for the cash.",
#  'L378': "I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's.",
#  'L377': 'What is it with this chick?  She have three tits?',
#  'L376': 'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  'L375': 'What plan?',
#  'L373': "Whatever the hell it is you're standin' there waitin' to say.",
#  'L372': 'What?',
#  'L371': 'Say it',
#  'L512': 'See you next week!',
#  'L511': "You're completely demented.",
#  'L264': "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good...",
#  'L263': "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  'L262': "What's to discuss?",
#  'L261': "Why don't we discuss your driving need to be a hemorrhoid?",
#  'L259': "I'm at a loss, then.  What should we talk about? Your year of absence?",
#  'L258': 'Touch of the flu.',
#  'L257': "I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#  'L62': 'With the teeth of your zipper?',
#  'L61': 'It was a bratwurst.  I was eating lunch.',
#  'L60': 'It says here you exposed yourself to a group of freshmen girls.',
#  'L59': 'I missed you.',
#  'L933': "That ' s what I thought",
#  'L932': 'Absolutely not.',
#  'L931': 'Did I have anything to say about it?',
#  'L930': 'Your daughters went to the prom.',
#  'L929': 'What just happened?',
#  'L927': 'But -- who -- what --?',
#  'L926': 'Have a great time, honey!',
#  'L918': 'Dr. Ruth?',
#  'L917': "What do you wanna watch?  We've got crap, crap, crap or crap",
#  'L887': "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  'L886': "They'll dance, they'll kiss, they'll come home.  Let her go.",
#  'L877': 'Pirate -- no question.',
#  'L876': 'Would you rather be ravished by a pirate or a British rear admiral?',
#  'L193': "You're not helping.",
#  'L192': 'Tumescent!',
#  'L191': 'Jesus!  Can a man even grab a sandwich before you women start dilating?',
#  'L171': 'Sarah Lawrence is on the other side of the country.',
#  'L170': "What's a synonym for throbbing?",
#  'L162': 'Make anyone cry today?',
#  'L161': 'In the microwave.',
#  'L2181': "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign...",
#  'L2180': "We left three weeks ago, Alonso. Can't be that near.",
#  'L2179': 'We should have seen land.',
#  'L2177': "We'll all go crazy...",
#  'L2176': "He's the devil's child...",
#  'L2175': "With a face like that?  I don't want you looking at me.  You hear?",
#  'L2174': "Ah, leave him alone.  He's doing no harm.",
#  'L2173': 'What are you listening to, chicken ass?',
#  'L2172': "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!",
#  'L2171': "The water's going putrid in the barrels.",
#  'L2170': 'I never seen heat like this!  Not even in Las Minas!',
#  'L2025': 'IF-GOD-WILLS-IT!',
#  'L2024': 'Asia can be found to the west -- and I will prove it.',
#  'L2023': 'Blind faith is what I consider heresy!',
#  'L2022': "Don't you realize your words could be considered heretical?",
#  'L2020': "Did He not choose a carpenter's son to reveal Himself to the world?",
#  'L2019': 'If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?',
#  'L2016': 'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.',
#  'L2015': 'Is that all that interests you? Gold?',
#  'L2014': 'Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.',
#  'L2012': 'If they agree to follow me, yes.',
#  'L2011': 'Your life, and that of others!',
#  'L2010': 'Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.',
#  'L2006': 'Excellency, you are right.',
#  'L2005': 'Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.',
#  'L1993': 'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.',
#  'L1992': 'I am, Your Eminence',
#  'L1991': 'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  'L1990': 'Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  'L1989': 'You say Asia can be found by sailing west?',
#  'L2524': 'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.',
#  'L2523': 'What a tragedy... what a waste of a life...',
#  'L2522': 'You can see for yourself.',
#  'L2275': 'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.',
#  'L2274': "It won't be easy to get rid of your prophet now, Don Sanchez.",
#  'L2031': 'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.',
#  'L2030': 'He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?',
#  'L2029': 'Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.',
#  'L2028': 'The Judgment is ours!',
#  'L2027': "The State has some reason to be interested in this man's proposition, Your Eminence...",
#  'L2540': "I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you.",
#  'L2539': 'What is it, now?  Tell me...',
#  'L2538': 'I am busy inside.',
#  'L2537': "Can't you stay with us a little?",
#  'L2474': "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier...",
#  'L2473': 'They took everything...',
#  'L2472': "They tried... but I didn't let them.",
#  'L2471': "God... you're so beautiful!  I can't believe no other man has ever taken you away from me...",
#  'L2320': 'I can arrange for the Queen to take Fernando and Diego into her service.',
#  'L2319': "You don't usually ask.",
#  'L2318': 'Beatrix, I want to ask you something.',
#  'L2123': "That's something you can't decide.",
#  'L2122': "I don't want you to wait for me.",
#  'L2121': "I'm not asking you to swear to anything.",
#  'L2119': 'Thank God...',
#  'L2118': 'She said yes.',
#  'L1986': 'I find that hard to believe.',
#  'L1985': 'Perhaps I was never meant to live with a woman...',
#  'L1984': "I'd love to argue with you sometimes.  But you're never here!",
#  'L1983': 'Are we going to argue?',
#  'L1982': "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  'L1981': "I haven't given you much of a life.",
#  'L1980': 'I know.',
#  'L1979': 'I could be gone for years.',
#  'L2432': 'I am afraid this is not the worst news.',
#  'L2431': 'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'L2430': 'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  'L2429': 'How far from here?',
#  'L2426': 'Congratulations.  Then I am free to search for the mainland.',
#  'L2425': 'Viceroy of the West Indies.',
#  'L2424': 'Appointment to what?',
#  'L2423': 'My letters of appointment.',
#  'L2422': 'Yes... I remember...',
#  'L2421': 'Don Alonso de Bobadilla.',
#  'L2293': 'Bartolome and Giacomo Colon.',
#  'L2292': 'May I ask by whom?',
#  'L2291': 'Forgive me, Don Bobadilla -- those positions have already been taken.',
#  'L2290': 'I understand that you will soon be appointing Governors for the islands?  Is it not so?',
#  'L2552': 'Tell me the first thing that comes to your mind.',
#  'L2551': "Really?  God... I wouldn't know where to start... and yet...",
#  'L2550': 'I want you to tell me everything you remember, Father.  From the beginning.  Everything.',
#  'L2549': 'He never had one... except aboard my ships!',
#  'L2548': 'He asks when he can come to visit you.  He left his address.',
#  'L2547': 'What does he say?',
#  'L2542': "I am not listening, Father.  But I can't help hearing.",
#  'L2541': 'What are you listening to?',
#  'L2501': 'There must be a passage to that other ocean.',
#  'L2500': 'Father...',
#  'L2485': 'Not bad.',
#  'L2484': 'How are you feeling, Fernando?',
#  'L2440': 'This time with me!',
#  'L2439': 'I have to explore the mainland.',
#  'L2131': 'Yes... Yes, I do... On all of them!',
#  'L2130': 'Do you swear on all the Holy Saints in heaven?',
#  'L2129': 'You promise?  Do you swear on St. Christopher...?',
#  'L2128': "There'll be a time.",
#  'L2127': 'I want to go with you!',
#  'L2469': 'All of them created by people like me.',
#  'L2468': 'Roofs... towers, palaces... spires...',
#  'L2467': 'What do you see?',
#  'L2466': 'Look out of that window.',
#  'L2465': 'I am not afraid of you.  You are nothing but a dreamer.',
#  'L2464': 'Call them.',
#  'L2463': 'All I have to do is call the guards.',
#  'L2301': 'To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.',
#  'L2300': 'What...?  Do I have so many already?',
#  'L2299': 'You seem to have a special talent for making friends.',
#  'L2297': 'Good!  We are also in need of judges.  Except there are no thieves!',
#  'L2296': 'Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  'L2295': 'But we do have a lack of notaries. You should contact my administration.',
#  'L2287': '... for a commoner?',
#  'L2286': 'You defend yourself admirably...',
#  'L2282': 'Forgive me, Don Colon.  But what about gold?',
#  'L2281': "They don't see sin in their nakedness.  They live according to nature, in a never ending summer. The islands are covered with trees, filled with blossoms and fruits. And...",
#  'L2110': "If you won't accept our proposal, we'll simply find someone who will.",
#  'L2109': 'And were you never ambitious, Excellency?  Or is ambition only a virtue among the nobles, a fault for the rest of us?',
#  'L2108': 'Then you are too ambitious.',
#  'L2107': "I'm not bargaining!",
#  'L2106': 'I remind you, Senor Colon, that you are in no position to bargain with me.',
#  'L2105': 'NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!',
#  'L2104': 'No?',
#  'L2103': 'No...',
#  'L2410': 'You never learned how to speak my language.',
#  'L2409': "Utapan, won't you speak to me?  You used to know how to speak to me.",
#  'L2394': 'You did the same to your God!',
#  'L2393': 'You have to find them, Utapan.  Look what they did!',
#  'L2343': 'Ask him if he will help.',
#  'L2342': 'He understands.',
#  'L2341': 'We will work with his people.  We want peace.  Ask the Chief if he understands?',
#  'L2260': 'He has medicine.  Tell him we admire his people.',
#  'L2259': 'Chief says...',
#  'L2258': '... and also to bring medicine.',
#  'L2257': 'Chief says -- he has a God.',
#  'L2256': 'To bring the word of God.',
#  'L2255': 'Why?',
#  'L2254': 'Thousands.',
#  'L2253': 'Chief says -- how many?',
#  'L2251': 'Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.',
#  'L2250': 'Chief knows.',
#  'L2249': 'Tell the Chief we thank him.',
#  'L2248': 'You come!  You speak first!',
#  'L2239': 'Island.  Far.',
#  'L2238': 'What is it?  A tribe?  An island?',
#  'L2237': 'Say not here!  Cuba!',
#  'L2535': "I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!",
#  'L2534': 'Oh?  So you are a new man?',
#  'L2533': 'New worlds create new people.',
#  'L2532': 'I knew you would.',
#  'L2531': 'I have to disagree.',
#  'L2526': "You'll always be older than me, Father.",
#  'L2525': "I suppose we're both old men now.",
#  'L2145': 'Give me absolution.',
#  'L2144': 'I believed in you...',
#  'L2143': 'You are bound by an oath, Father.',
#  'L2142': "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  'L2141': "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  'L2140': 'May God forgive you...!  You must tell them!  You must tell your men!',
#  'L2139': 'I am not sure... It could be twice the distance.',
#  'L2138': 'How long?',
#  'L2137': 'I lied.  The journey will be longer than I said.',
#  'L2136': 'What are you saying?',
#  'L2135': 'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  'L2134': 'I am listening, my son.',
#  'L2133': 'Forgive me, Father.  For I have sinned.',
#  'L2132': 'In Nomine Patris et Filius, et Spiritus Sancti.',
#  'L2046': "Colon!  Don't!",
#  'L2045': 'All of them!  Just lies!',
#  'L2042': 'Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!',
#  'L2041': 'Colon!',
#  'L2040': 'Damn God!',
#  'L2039': 'If God intends you to go, then you will go.',
#  'L2038': "Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  'L2037': "You mustn't give way to despair. You must wait.",
#  'L1969': 'Only God knows the meaning of such words, my son.',
#  'L1968': "I've been contradicted all my life... Eternity!",
#  'L1967': 'You get so carried away when you are being contradicted!',
#  'L1966': 'Passion is something one cannot control!',
#  'L1965': 'Father Marchena!',
#  'L1964': "I'll try to remember that, Marchena...",
#  'L1963': "Two minutes... and already you're a dead man.  Don't let passion overwhelm you, Colon.",
#  'L1962': 'So was Christ!',
#  'L1961': 'Esdras is a Jew.',
#  'L1960': 'The calculations of Toscanelli Marin de Tyr, Esdras...',
#  'L1959': 'How can you be so certain?',
#  'L1958': 'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'L1957': 'How can you be so certain?  The Ocean is said to be infinite.',
#  'L1952': 'To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'L1951': 'Why do you wish to sail west?',
#  'L1950': 'With some difficulty.  I had to promise them you were not a total fool.',
#  'L1949': 'How did you manage it?',
#  'L1948': "That's what it says.",
#  'L1947': "God... That's in a week!",
#  'L1943': 'Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  'L1942': 'Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  'L2459': 'Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  'L2458': "There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'L2457': 'Thank you.',
#  'L2456': 'But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'L2280': 'They come and go as naked as the day God created them...',
#  'L2279': 'Do they have such thoughts?',
#  'L2086': 'Thirty seven, Your Majesty... And you?',
#  'L2085': 'How old are you, Senor Colon?',
#  'L2082': 'A woman?',
#  'L2081': 'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'L2080': 'You show no inclination to speak otherwise!',
#  'L2079': 'May I speak freely?',
#  'L2077': 'Surely you can do anything you want.',
#  'L2076': 'I cannot ignore the verdict of my council.',
#  'L2075': 'That she was impregnable.',
#  'L2074': 'What did they say about Granada before today?',
#  'L2073': 'The ocean is uncrossable?',
#  'L2072': 'No more than the woman who said she would take Granada from the Moors.',
#  'L2071': 'I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'L2389': 'You will regret this.',
#  'L2388': "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'L2387': 'Savagery is what monkeys understand.',
#  'L2386': 'In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'L2348': 'You did not hear me, Don Colon.  Not my horse.',
#  'L2347': 'Don Moxica -- we all have to work.',
#  'L2346': "My horse doesn't work.",
#  'L2345': "We can't raise the wheel without it.",
#  'L2333': 'We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  'L2332': "We don't need to know.",
#  'L2331': 'You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  'L2329': "If you want to keep your head on your shoulders, you'll do as I say.",
#  'L2328': 'We lost cousins, friends.  We will wash this in blood.',
#  'L2278': 'The Indians have no such word, Don Moxica.',
#  'L2277': "And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  'L2492': "We can't be.",
#  'L2491': "He's drawing an isthmus... He's saying we're on an isthmus.",
#  'L2490': "What's he doing?",
#  'L2165': 'Twenty eight.',
#  'L2164': 'What do you read?',
#  'L2160': 'Come over here.',
#  'L2159': "Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'L2158': 'And what do you think Mendez?',
#  'L2157': "Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'L2155': 'God be with us admiral.',
#  'L2154': 'Due west, Captain Mendez.  And may God be with us...',
#  'L2211': "You're right.  Let the men decide.",
#  'L2210': 'You tell that to them!',
#  'L2209': 'Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'L2208': 'You bloody...',
#  'L2207': 'You never did.  You did all the talking for both of us, remember?',
#  'L2206': 'Jesus Maria!  I should have never listened to you!',
#  'L2205': 'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  'L2204': "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'L2203': 'The land is there.  I know it!',
#  'L2202': "We're lost!",
#  'L2201': "You think I don't know that?",
#  'L2200': "We're on the verge of a mutiny, Colon!",
#  'L2199': 'We have to keep the hopes of these men alive!',
#  'L2198': 'You must be mad...!',
#  'L2197': 'Six days ago, yes.',
#  'L2196': "You lied!  You cheated!  We're way past 750 leagues!",
#  'L2065': 'Immediately.',
#  'L2064': 'Where can I meet this man?',
#  'L2462': 'Because he is not afraid of me.',
#  'L2461': 'Then why?',
#  'L2460': 'I know, I should not tolerate his impertinence.',
#  'L2419': 'And who would you think of, for such a task?',
#  'L2418': 'He must be replaced.',
#  'L2417': 'Then, what do you suggest, Don Sanchez?',
#  'L2415': 'Is this true, Brother Buyl?',
#  'L2414': '... But there is worse.  He ordered the execution of five members of the nobility...',
#  'L2377': "We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'L2376': 'Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  'L2116': "Yes.  It would be a pity, wouldn't it?  Call him back!",
#  'L2115': '... Into a monk...',
#  'L2113': 'Never, Your Majesty.  Although...',
#  'L2112': 'You were right, Don Sanchez... His demands could never be granted.',
#  'L1931': 'Yes, Your Majesty.',
#  'L1930': 'Is that the man I knew, Treasurer Sanchez?',
#  'L3546': "Officers, there's your killer, do your duty, arrest him!",
#  'L3545': '...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  'L3497': "I don't think it's abuse, I think it's torture.",
#  'L3496': "I'm abused.  Don't you think?",
#  'L3493': 'Can I see your back?',
#  'L3492': 'Out on my back when I was a small boy.',
#  'L3491': 'Your father put cigarettes out on you?',
#  'L3490': "That's what he did to me.  He put cigarettes out on me.",
#  'L3489': 'Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  'L3488': "Your father blamed you for your mother's blindness?",
#  'L3487': 'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  'L3486': 'Back in the Czech Republic?',
#  'L3485': 'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'L3484': 'Your mother was blind?',
#  'L3483': 'My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'L3482': 'Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'L3481': 'Give me another one, please.',
#  'L3480': "I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'L3479': 'What else do you need?',
#  'L3478': 'This is not about money, Emil.  I need your trust in me.',
#  'L3477': "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  'L3476': "But it's...",
#  'L3475': 'No.  No way.',
#  'L3474': 'I would say...half.  Half is fair.',
#  'L3473': "What's your cut?  How much?",
#  'L3472': "Look, I haven't really focused on that kind of thing.",
#  'L3471': 'What about my movie rights?  Book rights?',
#  'L3470': "Don't worry about him.  Think about yourself.",
#  'L3469': 'No, he is here.  Shit...',
#  'L3468': "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'L3467': 'What about Oleg?',
#  'L3466': "Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'L3465': 'I was all of these.',
#  'L3464': '...delusions and paranoia.',
#  'L3461': 'Oh, sure.',
#  'L3460': 'You bring the cigarettes?',
#  'L3459': "I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  'L3396': "I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'L3395': 'Yes.  Yes, come with me!',
#  'L3394': "I'm coming with you.",
#  'L3393': 'Where are we going?',
#  'L3392': "Don't say anything.",
#  'L3385': 'He has the camera!  He took the movie!',
#  'L3384': 'Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'L3383': 'Oh no!  No!  Shit!',
#  'L3382': 'Here.  I have your money.',
#  'L3381': "I'm not your lawyer until I see the money.",
#  'L3380': "Are you my attorney?  I'm Emil.  I'm insane.",
#  'L3517': 'Daphne, I...',
#  'L3516': "I don't want to drag you down with me.",
#  'L3515': '...Do you really want me to forget about you?',
#  'L3514': 'Forget about me.  You have enough problems of your own.',
#  'L3330': 'Pouring it out!',
#  'L3329': 'What are you doing?',
#  'L3318': "I'll get my clothes.",
#  'L3317': "I'll make some for us.",
#  'L3316': 'In the kitchen.',
#  'L3315': 'Do you have coffee?',
#  ...}

# %%
### Create a list of all conversations

# Initialize an empty array
conversation_ids = []

# Iterate through conversations                  # We don't take the last row because it's an empty string
for i_conversation in conversations[:-1]:
    
    # Split each conversation with +++$+++
    _conversation = i_conversation.split(" +++$+++ ")
    
    # Get the lines ids
    _conversation = _conversation[-1]
    
    # Remove the square brackets                 # Remmber that this array is inside a string so we can use indexing like below
    _conversation = _conversation[1:-1]
    
    # Remove quotes
    _conversation = _conversation.replace("'", "")
    
    # Remove empty spaces
    _conversation = _conversation.replace(" ", "")
    
    # Split the conversation with ,
    _conversation = _conversation.split(",")
    
    # Append the conversations to our list
    conversation_ids.append(_conversation)

# %%
# Print conversation_ids
conversation_ids
# Out:
# [['L194', 'L195', 'L196', 'L197'],
#  ['L198', 'L199'],
#  ['L200', 'L201', 'L202', 'L203'],
#  ['L204', 'L205', 'L206'],
#  ['L207', 'L208'],
#  ['L271', 'L272', 'L273', 'L274', 'L275'],
#  ['L276', 'L277'],
#  ['L280', 'L281'],
#  ['L363', 'L364'],
#  ['L365', 'L366'],
#  ['L367', 'L368'],
#  ['L401', 'L402', 'L403'],
#  ['L404', 'L405', 'L406', 'L407'],
#  ['L575', 'L576'],
#  ['L577', 'L578'],
#  ['L662', 'L663'],
#  ['L693', 'L694', 'L695'],
#  ['L696', 'L697', 'L698', 'L699'],
#  ['L860', 'L861'],
#  ['L862', 'L863', 'L864', 'L865'],
#  ['L866', 'L867', 'L868', 'L869'],
#  ['L870', 'L871', 'L872'],
#  ['L924', 'L925'],
#  ['L984', 'L985'],
#  ['L1044', 'L1045'],
#  ['L49', 'L50', 'L51'],
#  ['L571', 'L572', 'L573'],
#  ['L579', 'L580'],
#  ['L595', 'L596', 'L597'],
#  ['L598', 'L599', 'L600'],
#  ['L659', 'L660'],
#  ['L952', 'L953'],
#  ['L394', 'L395'],
#  ['L396', 'L397'],
#  ['L589', 'L590', 'L591'],
#  ['L592', 'L593'],
#  ['L756', 'L757', 'L758'],
#  ['L759', 'L760'],
#  ['L164', 'L165'],
#  ['L319', 'L320'],
#  ['L441', 'L442', 'L443', 'L444', 'L445'],
#  ['L525', 'L526', 'L527'],
#  ['L529', 'L530'],
#  ['L531', 'L532', 'L533'],
#  ['L542', 'L543'],
#  ['L601', 'L602'],
#  ['L655', 'L656'],
#  ['L889', 'L890', 'L891', 'L892'],
#  ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900'],
#  ['L901', 'L902', 'L903'],
#  ['L904', 'L905', 'L906', 'L907', 'L908'],
#  ['L909', 'L910', 'L911', 'L912', 'L913', 'L914'],
#  ['L982', 'L983'],
#  ['L1007', 'L1008', 'L1009', 'L1010', 'L1011'],
#  ['L1021', 'L1022'],
#  ['L1051', 'L1052'],
#  ['L179', 'L180', 'L181', 'L182', 'L183'],
#  ['L189', 'L190'],
#  ['L517', 'L518', 'L519', 'L520', 'L521'],
#  ['L523', 'L524'],
#  ['L536', 'L537'],
#  ['L538', 'L539', 'L540'],
#  ['L544', 'L545', 'L546'],
#  ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884'],
#  ['L922', 'L923'],
#  ['L458', 'L459', 'L460', 'L461', 'L462', 'L463'],
#  ['L63', 'L64', 'L65'],
#  ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74'],
#  ['L77', 'L78'],
#  ['L87', 'L88', 'L89', 'L90', 'L91', 'L92'],
#  ['L139', 'L140', 'L141', 'L142'],
#  ['L143', 'L144', 'L145', 'L146', 'L147'],
#  ['L157', 'L158', 'L159'],
#  ['L210', 'L211'],
#  ['L212', 'L213'],
#  ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222'],
#  ['L223', 'L224', 'L225'],
#  ['L244', 'L245'],
#  ['L388', 'L389', 'L390', 'L391'],
#  ['L416', 'L417', 'L418', 'L419'],
#  ['L424', 'L425'],
#  ['L432', 'L433'],
#  ['L499', 'L500'],
#  ['L583', 'L584', 'L585', 'L586'],
#  ['L778', 'L779'],
#  ['L385', 'L386'],
#  ['L411', 'L412'],
#  ['L426', 'L427'],
#  ['L430', 'L431'],
#  ['L619', 'L620'],
#  ['L621', 'L622'],
#  ['L623', 'L624', 'L625'],
#  ['L725', 'L726'],
#  ['L740', 'L741'],
#  ['L743', 'L744', 'L745'],
#  ['L780', 'L781'],
#  ['L148', 'L149', 'L150'],
#  ['L335', 'L336'],
#  ['L554', 'L555', 'L556'],
#  ['L557', 'L558'],
#  ['L285', 'L286'],
#  ['L287', 'L288', 'L289', 'L290', 'L291', 'L292'],
#  ['L294', 'L295', 'L296', 'L297'],
#  ['L298', 'L299'],
#  ['L300', 'L301'],
#  ['L349', 'L350', 'L351', 'L352'],
#  ['L354', 'L355', 'L356', 'L357', 'L358'],
#  ['L605', 'L606'],
#  ['L607', 'L608', 'L609'],
#  ['L747', 'L748'],
#  ['L231', 'L232', 'L233', 'L234', 'L235', 'L236'],
#  ['L238', 'L239', 'L240'],
#  ['L502', 'L503', 'L504', 'L505'],
#  ['L508', 'L509'],
#  ['L123', 'L124', 'L125', 'L126', 'L127', 'L128'],
#  ['L129', 'L130'],
#  ['L131', 'L132'],
#  ['L133', 'L134'],
#  ['L151', 'L152'],
#  ['L247', 'L248', 'L249', 'L250', 'L251'],
#  ['L252', 'L253', 'L254'],
#  ['L447', 'L448'],
#  ['L490', 'L491'],
#  ['L716', 'L717', 'L718', 'L719', 'L720', 'L721'],
#  ['L750', 'L751', 'L752', 'L753', 'L754', 'L755'],
#  ['L946', 'L947', 'L948', 'L949'],
#  ['L304', 'L305', 'L306', 'L307'],
#  ['L309', 'L310'],
#  ['L311', 'L312', 'L313'],
#  ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328'],
#  ['L330', 'L331', 'L332'],
#  ['L333', 'L334'],
#  ['L473', 'L474'],
#  ['L475', 'L476', 'L477'],
#  ['L481', 'L482', 'L483'],
#  ['L564', 'L565', 'L566', 'L567'],
#  ['L610', 'L611'],
#  ['L612', 'L613', 'L614', 'L615', 'L616'],
#  ['L626',
#   'L627',
#   'L628',
#   'L629',
#   'L630',
#   'L631',
#   'L632',
#   'L633',
#   'L634',
#   'L635',
#   'L636'],
#  ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646'],
#  ['L650', 'L651'],
#  ['L668', 'L669'],
#  ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676'],
#  ['L677', 'L678', 'L679'],
#  ['L680', 'L681', 'L682'],
#  ['L683', 'L684'],
#  ['L686', 'L687', 'L688', 'L689', 'L690'],
#  ['L764', 'L765', 'L766', 'L767', 'L768'],
#  ['L769', 'L770', 'L771', 'L772', 'L773', 'L774'],
#  ['L798', 'L799'],
#  ['L800', 'L801', 'L802'],
#  ['L803', 'L804', 'L805', 'L806'],
#  ['L808', 'L809', 'L810', 'L811', 'L812'],
#  ['L813',
#   'L814',
#   'L815',
#   'L816',
#   'L817',
#   'L818',
#   'L819',
#   'L820',
#   'L821',
#   'L822',
#   'L823'],
#  ['L824', 'L825'],
#  ['L828', 'L829', 'L830', 'L831', 'L832'],
#  ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841'],
#  ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848'],
#  ['L852', 'L853', 'L854', 'L855', 'L856', 'L857'],
#  ['L936', 'L937', 'L938', 'L939', 'L940'],
#  ['L957', 'L958', 'L959'],
#  ['L960', 'L961'],
#  ['L973', 'L974', 'L975', 'L976', 'L977'],
#  ['L1031', 'L1032'],
#  ['L1033', 'L1034', 'L1035'],
#  ['L1040', 'L1041', 'L1042', 'L1043'],
#  ['L172', 'L173', 'L174'],
#  ['L184', 'L185'],
#  ['L338',
#   'L339',
#   'L340',
#   'L341',
#   'L342',
#   'L343',
#   'L344',
#   'L345',
#   'L346',
#   'L347'],
#  ['L986', 'L987', 'L988'],
#  ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997'],
#  ['L998', 'L999', 'L1000'],
#  ['L103', 'L104', 'L105', 'L106', 'L107'],
#  ['L108', 'L109'],
#  ['L1017', 'L1018'],
#  ['L728', 'L729', 'L730', 'L731'],
#  ['L732', 'L733'],
#  ['L735', 'L736', 'L737', 'L738'],
#  ['L371', 'L372', 'L373'],
#  ['L375', 'L376', 'L377'],
#  ['L378', 'L379'],
#  ['L380', 'L381', 'L382'],
#  ['L383', 'L384'],
#  ['L414', 'L415'],
#  ['L420', 'L421'],
#  ['L428', 'L429'],
#  ['L436', 'L437'],
#  ['L723', 'L724'],
#  ['L775', 'L776', 'L777'],
#  ['L59', 'L60', 'L61', 'L62'],
#  ['L257', 'L258', 'L259'],
#  ['L261', 'L262', 'L263', 'L264'],
#  ['L511', 'L512'],
#  ['L161', 'L162'],
#  ['L170', 'L171'],
#  ['L191', 'L192', 'L193'],
#  ['L876', 'L877'],
#  ['L886', 'L887'],
#  ['L917', 'L918'],
#  ['L926', 'L927'],
#  ['L929', 'L930', 'L931', 'L932', 'L933'],
#  ['L2170', 'L2171', 'L2172'],
#  ['L2173', 'L2174', 'L2175'],
#  ['L2176', 'L2177'],
#  ['L2179', 'L2180', 'L2181'],
#  ['L1989', 'L1990', 'L1991', 'L1992', 'L1993'],
#  ['L2005', 'L2006'],
#  ['L2010', 'L2011', 'L2012'],
#  ['L2014', 'L2015', 'L2016'],
#  ['L2019', 'L2020'],
#  ['L2022', 'L2023'],
#  ['L2024', 'L2025'],
#  ['L2027', 'L2028', 'L2029'],
#  ['L2030', 'L2031'],
#  ['L2274', 'L2275'],
#  ['L2522', 'L2523', 'L2524'],
#  ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984'],
#  ['L1985', 'L1986'],
#  ['L2118', 'L2119'],
#  ['L2121', 'L2122', 'L2123'],
#  ['L2318', 'L2319', 'L2320'],
#  ['L2471', 'L2472'],
#  ['L2473', 'L2474'],
#  ['L2537', 'L2538'],
#  ['L2539', 'L2540'],
#  ['L2290', 'L2291', 'L2292', 'L2293'],
#  ['L2421', 'L2422'],
#  ['L2423', 'L2424', 'L2425', 'L2426'],
#  ['L2429', 'L2430', 'L2431', 'L2432'],
#  ['L2127', 'L2128', 'L2129'],
#  ['L2130', 'L2131'],
#  ['L2439', 'L2440'],
#  ['L2484', 'L2485'],
#  ['L2500', 'L2501'],
#  ['L2541', 'L2542'],
#  ['L2547', 'L2548', 'L2549'],
#  ['L2550', 'L2551', 'L2552'],
#  ['L2103', 'L2104', 'L2105'],
#  ['L2106', 'L2107', 'L2108'],
#  ['L2109', 'L2110'],
#  ['L2281', 'L2282'],
#  ['L2286', 'L2287'],
#  ['L2295', 'L2296', 'L2297'],
#  ['L2299', 'L2300', 'L2301'],
#  ['L2463', 'L2464'],
#  ['L2465', 'L2466'],
#  ['L2467', 'L2468', 'L2469'],
#  ['L2237', 'L2238', 'L2239'],
#  ['L2248', 'L2249', 'L2250', 'L2251'],
#  ['L2253', 'L2254', 'L2255'],
#  ['L2256', 'L2257', 'L2258', 'L2259', 'L2260'],
#  ['L2341', 'L2342', 'L2343'],
#  ['L2393', 'L2394'],
#  ['L2409', 'L2410'],
#  ['L1942', 'L1943'],
#  ['L1947', 'L1948', 'L1949', 'L1950'],
#  ['L1951', 'L1952'],
#  ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962'],
#  ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969'],
#  ['L2037', 'L2038', 'L2039', 'L2040'],
#  ['L2041', 'L2042'],
#  ['L2045', 'L2046'],
#  ['L2132', 'L2133'],
#  ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139'],
#  ['L2140', 'L2141', 'L2142', 'L2143'],
#  ['L2144', 'L2145'],
#  ['L2525', 'L2526'],
#  ['L2531', 'L2532', 'L2533', 'L2534', 'L2535'],
#  ['L2071', 'L2072'],
#  ['L2073', 'L2074', 'L2075'],
#  ['L2076', 'L2077'],
#  ['L2079', 'L2080', 'L2081', 'L2082'],
#  ['L2085', 'L2086'],
#  ['L2279', 'L2280'],
#  ['L2456', 'L2457', 'L2458', 'L2459'],
#  ['L2277', 'L2278'],
#  ['L2328', 'L2329'],
#  ['L2331', 'L2332', 'L2333'],
#  ['L2345', 'L2346'],
#  ['L2347', 'L2348'],
#  ['L2386', 'L2387', 'L2388', 'L2389'],
#  ['L2154', 'L2155'],
#  ['L2157', 'L2158', 'L2159', 'L2160'],
#  ['L2164', 'L2165'],
#  ['L2490', 'L2491', 'L2492'],
#  ['L2064', 'L2065'],
#  ['L2196',
#   'L2197',
#   'L2198',
#   'L2199',
#   'L2200',
#   'L2201',
#   'L2202',
#   'L2203',
#   'L2204',
#   'L2205',
#   'L2206',
#   'L2207',
#   'L2208',
#   'L2209',
#   'L2210',
#   'L2211'],
#  ['L1930', 'L1931'],
#  ['L2112', 'L2113'],
#  ['L2115', 'L2116'],
#  ['L2376', 'L2377'],
#  ['L2414', 'L2415'],
#  ['L2417', 'L2418', 'L2419'],
#  ['L2460', 'L2461', 'L2462'],
#  ['L3380', 'L3381', 'L3382'],
#  ['L3383', 'L3384', 'L3385'],
#  ['L3392', 'L3393', 'L3394', 'L3395', 'L3396'],
#  ['L3459', 'L3460', 'L3461'],
#  ['L3464',
#   'L3465',
#   'L3466',
#   'L3467',
#   'L3468',
#   'L3469',
#   'L3470',
#   'L3471',
#   'L3472',
#   'L3473',
#   'L3474',
#   'L3475',
#   'L3476',
#   'L3477',
#   'L3478',
#   'L3479',
#   'L3480',
#   'L3481'],
#  ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489'],
#  ['L3490', 'L3491', 'L3492', 'L3493'],
#  ['L3496', 'L3497'],
#  ['L3545', 'L3546'],
#  ['L3059', 'L3060', 'L3061'],
#  ['L3089', 'L3090', 'L3091', 'L3092'],
#  ['L3093', 'L3094', 'L3095'],
#  ['L3096', 'L3097'],
#  ['L3158', 'L3159', 'L3160'],
#  ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166'],
#  ['L3167', 'L3168', 'L3169', 'L3170'],
#  ['L3177', 'L3178', 'L3179', 'L3180', 'L3181'],
#  ['L3300', 'L3301', 'L3302'],
#  ['L3305', 'L3306', 'L3307', 'L3308'],
#  ['L3309', 'L3310', 'L3311'],
#  ['L3313', 'L3314'],
#  ['L3315', 'L3316', 'L3317', 'L3318'],
#  ['L3329', 'L3330'],
#  ['L3514', 'L3515', 'L3516', 'L3517'],
#  ['L3045', 'L3046', 'L3047', 'L3048'],
#  ['L3049', 'L3050', 'L3051'],
#  ['L3055', 'L3056'],
#  ['L3062', 'L3063', 'L3064', 'L3065'],
#  ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214'],
#  ['L2797', 'L2798', 'L2799', 'L2800'],
#  ['L3196', 'L3197'],
#  ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203'],
#  ['L3293', 'L3294'],
#  ['L3498',
#   'L3499',
#   'L3500',
#   'L3501',
#   'L3502',
#   'L3503',
#   'L3504',
#   'L3505',
#   'L3506'],
#  ['L2801', 'L2802', 'L2803', 'L2804', 'L2805'],
#  ['L3289', 'L3290', 'L3291', 'L3292'],
#  ['L2599', 'L2600', 'L2601'],
#  ['L2602', 'L2603'],
#  ['L2630', 'L2631', 'L2632', 'L2633'],
#  ['L2751', 'L2752'],
#  ['L2920', 'L2921', 'L2922', 'L2923'],
#  ['L2924', 'L2925'],
#  ['L2936', 'L2937', 'L2938'],
#  ['L3016', 'L3017'],
#  ['L3022', 'L3023'],
#  ['L3027', 'L3028'],
#  ['L2964', 'L2965', 'L2966', 'L2967'],
#  ['L2971', 'L2972', 'L2973'],
#  ['L2975', 'L2976', 'L2977', 'L2978'],
#  ['L2979', 'L2980', 'L2981'],
#  ['L2986', 'L2987', 'L2988', 'L2989', 'L2990'],
#  ['L2730', 'L2731'],
#  ['L2746', 'L2747', 'L2748'],
#  ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882'],
#  ['L2883', 'L2884', 'L2885', 'L2886'],
#  ['L2887', 'L2888', 'L2889', 'L2890', 'L2891'],
#  ['L2892', 'L2893'],
#  ['L2895', 'L2896', 'L2897'],
#  ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906'],
#  ['L2949', 'L2950', 'L2951', 'L2952', 'L2953'],
#  ['L2955', 'L2956', 'L2957', 'L2958'],
#  ['L2962', 'L2963'],
#  ['L2991', 'L2992'],
#  ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999'],
#  ['L3052', 'L3053', 'L3054'],
#  ['L3057', 'L3058'],
#  ['L3067', 'L3068'],
#  ['L3069',
#   'L3070',
#   'L3071',
#   'L3072',
#   'L3073',
#   'L3074',
#   'L3075',
#   'L3076',
#   'L3077',
#   'L3078',
#   'L3079'],
#  ['L3080', 'L3081', 'L3082'],
#  ['L3219', 'L3220', 'L3221', 'L3222'],
#  ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228'],
#  ['L3229', 'L3230'],
#  ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242'],
#  ['L3243', 'L3244'],
#  ['L3248', 'L3249'],
#  ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765'],
#  ['L3029', 'L3030'],
#  ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037'],
#  ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044'],
#  ['L3101', 'L3102'],
#  ['L3103',
#   'L3104',
#   'L3105',
#   'L3106',
#   'L3107',
#   'L3108',
#   'L3109',
#   'L3110',
#   'L3111',
#   'L3112',
#   'L3113',
#   'L3114',
#   'L3115',
#   'L3116',
#   'L3117'],
#  ['L3119', 'L3120', 'L3121'],
#  ['L3126', 'L3127', 'L3128', 'L3129', 'L3130'],
#  ['L3135',
#   'L3136',
#   'L3137',
#   'L3138',
#   'L3139',
#   'L3140',
#   'L3141',
#   'L3142',
#   'L3143',
#   'L3144',
#   'L3145',
#   'L3146',
#   'L3147'],
#  ['L3148',
#   'L3149',
#   'L3150',
#   'L3151',
#   'L3152',
#   'L3153',
#   'L3154',
#   'L3155',
#   'L3156',
#   'L3157'],
#  ['L2595', 'L2596'],
#  ['L2604', 'L2605', 'L2606', 'L2607'],
#  ['L2611', 'L2612'],
#  ['L2644', 'L2645'],
#  ['L2646', 'L2647', 'L2648'],
#  ['L2651', 'L2652'],
#  ['L2653', 'L2654', 'L2655', 'L2656'],
#  ['L2664', 'L2665'],
#  ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626'],
#  ['L2627', 'L2628'],
#  ['L3278',
#   'L3279',
#   'L3280',
#   'L3281',
#   'L3282',
#   'L3283',
#   'L3284',
#   'L3285',
#   'L3286'],
#  ['L3419', 'L3420', 'L3421'],
#  ['L3431', 'L3432'],
#  ['L3433', 'L3434'],
#  ['L3435', 'L3436'],
#  ['L3554', 'L3555', 'L3556'],
#  ['L2845', 'L2846', 'L2847'],
#  ['L2848', 'L2849'],
#  ['L2850', 'L2851', 'L2852', 'L2853', 'L2854'],
#  ['L2855', 'L2856'],
#  ['L2857', 'L2858'],
#  ['L2563', 'L2564'],
#  ['L2565', 'L2566', 'L2567', 'L2568', 'L2569'],
#  ['L2570', 'L2571', 'L2572', 'L2573', 'L2574'],
#  ['L2577', 'L2578', 'L2579', 'L2580', 'L2581'],
#  ['L2908', 'L2909'],
#  ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915'],
#  ['L2557', 'L2558'],
#  ['L2559', 'L2560'],
#  ['L2561', 'L2562'],
#  ['L2635', 'L2636', 'L2637', 'L2638'],
#  ['L2639', 'L2640'],
#  ['L2666', 'L2667', 'L2668'],
#  ['L2670', 'L2671'],
#  ['L2778', 'L2779'],
#  ['L2780', 'L2781', 'L2782', 'L2783'],
#  ['L2789', 'L2790'],
#  ['L2842', 'L2843', 'L2844'],
#  ['L3083', 'L3084', 'L3085'],
#  ['L3087', 'L3088'],
#  ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188'],
#  ['L3189', 'L3190'],
#  ['L3191', 'L3192', 'L3193'],
#  ['L3246', 'L3247'],
#  ['L3250', 'L3251'],
#  ['L3356', 'L3357'],
#  ['L3359', 'L3360'],
#  ['L3361', 'L3362'],
#  ['L3363', 'L3364'],
#  ['L3365', 'L3366'],
#  ['L3368', 'L3369', 'L3370'],
#  ['L3372', 'L3373', 'L3374', 'L3375'],
#  ['L3376', 'L3377', 'L3378'],
#  ['L3547', 'L3548'],
#  ['L2672', 'L2673'],
#  ['L2674', 'L2675', 'L2676'],
#  ['L2678', 'L2679'],
#  ['L2680', 'L2681', 'L2682'],
#  ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692'],
#  ['L3271', 'L3272', 'L3273', 'L3274', 'L3275'],
#  ['L3352', 'L3353'],
#  ['L2608', 'L2609', 'L2610'],
#  ['L2614', 'L2615'],
#  ['L3409', 'L3410'],
#  ['L3411', 'L3412', 'L3413'],
#  ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269'],
#  ['L2575', 'L2576'],
#  ['L2582',
#   'L2583',
#   'L2584',
#   'L2585',
#   'L2586',
#   'L2587',
#   'L2588',
#   'L2589',
#   'L2590',
#   'L2591'],
#  ['L2732', 'L2733'],
#  ['L2740', 'L2741', 'L2742', 'L2743'],
#  ['L2744', 'L2745'],
#  ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403'],
#  ['L2698', 'L2699', 'L2700'],
#  ['L2701', 'L2702', 'L2703'],
#  ['L2706', 'L2707'],
#  ['L2771', 'L2772', 'L2773'],
#  ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813'],
#  ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721'],
#  ['L2724', 'L2725'],
#  ['L2735', 'L2736', 'L2737'],
#  ['L2738', 'L2739'],
#  ['L2754', 'L2755', 'L2756', 'L2757'],
#  ['L2767', 'L2768'],
#  ['L2793', 'L2794', 'L2795'],
#  ['L2863', 'L2864', 'L2865'],
#  ['L2870', 'L2871', 'L2872'],
#  ['L3024', 'L3025', 'L3026'],
#  ['L3287', 'L3288'],
#  ['L3342', 'L3343', 'L3344'],
#  ['L2928', 'L2929', 'L2930'],
#  ['L3422', 'L3423', 'L3424'],
#  ['L3425', 'L3426', 'L3427'],
#  ['L2828',
#   'L2829',
#   'L2830',
#   'L2831',
#   'L2832',
#   'L2833',
#   'L2834',
#   'L2835',
#   'L2836',
#   'L2837',
#   'L2838',
#   'L2839',
#   'L2840'],
#  ['L3712', 'L3713'],
#  ['L3720', 'L3721'],
#  ['L3728', 'L3729'],
#  ['L3749', 'L3750'],
#  ['L3756', 'L3757'],
#  ['L3770', 'L3771'],
#  ['L3777', 'L3778'],
#  ['L3942', 'L3943', 'L3944', 'L3945'],
#  ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969'],
#  ['L3972', 'L3973', 'L3974', 'L3975', 'L3976'],
#  ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984'],
#  ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992'],
#  ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001'],
#  ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017'],
#  ['L4159', 'L4160', 'L4161', 'L4162', 'L4163'],
#  ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193'],
#  ['L4196', 'L4197', 'L4198', 'L4199'],
#  ['L4208', 'L4209'],
#  ['L4282', 'L4283'],
#  ['L4296', 'L4297', 'L4298', 'L4299', 'L4300'],
#  ['L4006', 'L4007'],
#  ['L4068', 'L4069', 'L4070'],
#  ['L4079', 'L4080'],
#  ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224'],
#  ['L4227', 'L4228', 'L4229', 'L4230'],
#  ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271'],
#  ['L4333', 'L4334', 'L4335'],
#  ['L4346', 'L4347', 'L4348', 'L4349', 'L4350'],
#  ['L4353', 'L4354', 'L4355', 'L4356', 'L4357'],
#  ['L4360', 'L4361', 'L4362', 'L4363'],
#  ['L4366', 'L4367', 'L4368'],
#  ['L3970', 'L3971'],
#  ['L3977', 'L3978'],
#  ['L3993', 'L3994'],
#  ['L4002', 'L4003'],
#  ['L4009', 'L4010'],
#  ['L4018', 'L4019'],
#  ['L3668', 'L3669'],
#  ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677'],
#  ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685'],
#  ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693'],
#  ['L3797', 'L3798', 'L3799'],
#  ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810'],
#  ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735'],
#  ['L3758', 'L3759'],
#  ['L3774', 'L3775', 'L3776'],
#  ['L3779', 'L3780'],
#  ['L3622', 'L3623'],
#  ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631'],
#  ['L3651', 'L3652', 'L3653'],
#  ['L3724', 'L3725', 'L3726'],
#  ['L3738', 'L3739', 'L3740'],
#  ['L3745', 'L3746', 'L3747', 'L3748'],
#  ['L3751', 'L3752', 'L3753', 'L3754'],
#  ['L3760', 'L3761', 'L3762', 'L3763'],
#  ['L3766', 'L3767', 'L3768'],
#  ['L3772', 'L3773'],
#  ['L3868', 'L3869'],
#  ['L3889', 'L3890', 'L3891', 'L3892', 'L3893'],
#  ['L3896', 'L3897'],
#  ['L3904', 'L3905', 'L3906', 'L3907'],
#  ['L3817', 'L3818', 'L3819', 'L3820', 'L3821'],
#  ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829'],
#  ['L3832', 'L3833', 'L3834'],
#  ['L3837', 'L3838', 'L3839'],
#  ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025'],
#  ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033'],
#  ['L4096', 'L4097'],
#  ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113'],
#  ['L4118', 'L4119'],
#  ['L4169', 'L4170'],
#  ['L4174', 'L4175'],
#  ['L4181', 'L4182', 'L4183'],
#  ['L5039', 'L5040'],
#  ['L5041', 'L5042'],
#  ['L5043', 'L5044'],
#  ['L5045', 'L5046', 'L5047', 'L5048'],
#  ['L4897', 'L4898', 'L4899', 'L4900'],
#  ['L4903', 'L4904', 'L4905', 'L4906'],
#  ['L4922', 'L4923'],
#  ['L4924', 'L4925'],
#  ['L4453', 'L4454'],
#  ['L4501', 'L4502', 'L4503', 'L4504', 'L4505'],
#  ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511'],
#  ['L4562', 'L4563'],
#  ['L4567', 'L4568'],
#  ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180'],
#  ['L5181', 'L5182'],
#  ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188'],
#  ['L5193', 'L5194'],
#  ['L5215', 'L5216'],
#  ['L5366', 'L5367', 'L5368'],
#  ['L5370', 'L5371'],
#  ['L4944', 'L4945'],
#  ['L4959', 'L4960'],
#  ['L5316', 'L5317', 'L5318'],
#  ['L5321', 'L5322', 'L5323', 'L5324', 'L5325'],
#  ['L5328', 'L5329'],
#  ['L4628', 'L4629'],
#  ['L5338', 'L5339', 'L5340'],
#  ['L5346', 'L5347', 'L5348'],
#  ['L4727', 'L4728', 'L4729'],
#  ['L4731', 'L4732'],
#  ['L4739', 'L4740', 'L4741'],
#  ['L4743',
#   'L4744',
#   'L4745',
#   'L4746',
#   'L4747',
#   'L4748',
#   'L4749',
#   'L4750',
#   'L4751'],
#  ['L4763', 'L4764'],
#  ['L4765', 'L4766'],
#  ['L4769', 'L4770'],
#  ['L4771', 'L4772', 'L4773', 'L4774', 'L4775'],
#  ['L4778', 'L4779'],
#  ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785'],
#  ['L4786', 'L4787', 'L4788'],
#  ['L4789', 'L4790', 'L4791', 'L4792'],
#  ['L4800', 'L4801', 'L4802', 'L4803'],
#  ['L4814', 'L4815', 'L4816'],
#  ['L4825', 'L4826', 'L4827', 'L4828'],
#  ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855'],
#  ['L4857', 'L4858'],
#  ['L4860', 'L4861'],
#  ['L4863', 'L4864'],
#  ['L4866', 'L4867'],
#  ['L4868', 'L4869'],
#  ['L4870', 'L4871'],
#  ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879'],
#  ['L4880', 'L4881'],
#  ['L4882', 'L4883', 'L4884', 'L4885', 'L4886'],
#  ['L4887', 'L4888', 'L4889', 'L4890', 'L4891'],
#  ['L4893', 'L4894'],
#  ['L4895', 'L4896'],
#  ['L4911', 'L4912'],
#  ['L4929', 'L4930'],
#  ['L4937', 'L4938', 'L4939'],
#  ['L4964', 'L4965'],
#  ['L4969', 'L4970', 'L4971', 'L4972', 'L4973'],
#  ['L4974', 'L4975'],
#  ['L4994', 'L4995', 'L4996', 'L4997'],
#  ['L5002', 'L5003', 'L5004', 'L5005'],
#  ['L5007', 'L5008', 'L5009', 'L5010'],
#  ['L5011', 'L5012', 'L5013', 'L5014'],
#  ['L5016', 'L5017'],
#  ['L5018', 'L5019', 'L5020'],
#  ['L5021', 'L5022'],
#  ['L5023', 'L5024', 'L5025'],
#  ['L5028', 'L5029', 'L5030'],
#  ['L5033', 'L5034', 'L5035'],
#  ['L5036', 'L5037', 'L5038'],
#  ['L5049', 'L5050', 'L5051'],
#  ['L5052', 'L5053', 'L5054', 'L5055', 'L5056'],
#  ['L5057', 'L5058', 'L5059'],
#  ['L5060', 'L5061', 'L5062', 'L5063', 'L5064'],
#  ['L5065', 'L5066'],
#  ['L5067', 'L5068'],
#  ['L5069', 'L5070', 'L5071', 'L5072'],
#  ['L5073', 'L5074'],
#  ['L5076', 'L5077'],
#  ['L5083', 'L5084', 'L5085'],
#  ['L5171', 'L5172'],
#  ['L5190', 'L5191', 'L5192'],
#  ['L5195', 'L5196'],
#  ['L5197', 'L5198', 'L5199', 'L5200'],
#  ['L5201', 'L5202'],
#  ['L5204', 'L5205'],
#  ['L5206', 'L5207'],
#  ['L5208', 'L5209', 'L5210'],
#  ['L5212', 'L5213'],
#  ['L5224', 'L5225', 'L5226', 'L5227'],
#  ['L5236', 'L5237'],
#  ['L5249', 'L5250', 'L5251', 'L5252'],
#  ['L5253', 'L5254', 'L5255'],
#  ['L5256', 'L5257'],
#  ['L5290', 'L5291'],
#  ['L5304', 'L5305'],
#  ['L5306', 'L5307'],
#  ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314'],
#  ['L5351', 'L5352', 'L5353'],
#  ['L5372', 'L5373'],
#  ['L5375', 'L5376'],
#  ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382'],
#  ['L5383', 'L5384'],
#  ['L4689', 'L4690'],
#  ['L4691', 'L4692'],
#  ['L4693',
#   'L4694',
#   'L4695',
#   'L4696',
#   'L4697',
#   'L4698',
#   'L4699',
#   'L4700',
#   'L4701',
#   'L4702',
#   'L4703'],
#  ['L5093', 'L5094', 'L5095', 'L5096'],
#  ['L5097', 'L5098', 'L5099'],
#  ['L5100', 'L5101'],
#  ['L5102', 'L5103', 'L5104'],
#  ['L5242', 'L5243'],
#  ['L5244', 'L5245'],
#  ['L4636', 'L4637', 'L4638', 'L4639'],
#  ['L4642', 'L4643', 'L4644'],
#  ['L4669', 'L4670', 'L4671'],
#  ['L4672', 'L4673'],
#  ['L4675', 'L4676'],
#  ['L4677', 'L4678', 'L4679', 'L4680'],
#  ['L4681', 'L4682'],
#  ['L4685', 'L4686', 'L4687'],
#  ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138'],
#  ['L5142', 'L5143'],
#  ['L5144', 'L5145'],
#  ['L5158', 'L5159'],
#  ['L5162', 'L5163'],
#  ['L4809', 'L4810', 'L4811', 'L4812', 'L4813'],
#  ['L4817', 'L4818', 'L4819'],
#  ['L4821', 'L4822', 'L4823'],
#  ['L4467', 'L4468'],
#  ['L4469', 'L4470', 'L4471'],
#  ['L4472', 'L4473', 'L4474'],
#  ['L4475', 'L4476'],
#  ['L4477',
#   'L4478',
#   'L4479',
#   'L4480',
#   'L4481',
#   'L4482',
#   'L4483',
#   'L4484',
#   'L4485',
#   'L4486',
#   'L4487',
#   'L4488'],
#  ['L4513', 'L4514'],
#  ['L4516', 'L4517'],
#  ['L4519', 'L4520', 'L4521', 'L4522'],
#  ['L4523', 'L4524', 'L4525'],
#  ['L4528', 'L4529', 'L4530', 'L4531', 'L4532'],
#  ['L4533', 'L4534', 'L4535'],
#  ['L4704', 'L4705', 'L4706'],
#  ['L4707', 'L4708', 'L4709'],
#  ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718'],
#  ['L4836', 'L4837'],
#  ['L4839', 'L4840'],
#  ['L5149', 'L5150', 'L5151', 'L5152', 'L5153'],
#  ['L5164', 'L5165'],
#  ['L5167', 'L5168', 'L5169'],
#  ['L5219', 'L5220', 'L5221'],
#  ['L5258', 'L5259', 'L5260', 'L5261', 'L5262', 'L5263'],
#  ['L5275', 'L5276'],
#  ['L5284', 'L5285', 'L5286', 'L5287'],
#  ['L5292', 'L5293', 'L5294', 'L5295', 'L5296', 'L5297', 'L5298'],
#  ['L5301', 'L5302', 'L5303'],
#  ['L5355', 'L5356', 'L5357', 'L5358'],
#  ['L5359', 'L5360', 'L5361', 'L5362', 'L5363'],
#  ['L5364', 'L5365'],
#  ['L5264', 'L5265'],
#  ['L5266', 'L5267', 'L5268'],
#  ['L5279', 'L5280', 'L5281', 'L5282'],
#  ['L5288', 'L5289'],
#  ['L4600', 'L4601', 'L4602'],
#  ['L4603', 'L4604'],
#  ['L4609', 'L4610'],
#  ['L4612', 'L4613'],
#  ['L4493', 'L4494'],
#  ['L4495', 'L4496', 'L4497', 'L4498', 'L4499', 'L4500'],
#  ['L4543', 'L4544', 'L4545', 'L4546', 'L4547'],
#  ['L4548', 'L4549', 'L4550', 'L4551', 'L4552', 'L4553', 'L4554', 'L4555'],
#  ['L4558', 'L4559'],
#  ['L5230', 'L5231'],
#  ['L5233', 'L5234'],
#  ['L5105', 'L5106'],
#  ['L5107', 'L5108'],
#  ['L5109', 'L5110'],
#  ['L5113', 'L5114'],
#  ['L5115', 'L5116', 'L5117', 'L5118', 'L5119', 'L5120'],
#  ['L5121', 'L5122', 'L5123'],
#  ['L5124', 'L5125'],
#  ['L5643', 'L5644', 'L5645'],
#  ['L5673', 'L5674'],
#  ['L5678', 'L5679', 'L5680'],
#  ['L5692', 'L5693'],
#  ['L5875', 'L5876'],
#  ['L5889', 'L5890'],
#  ['L5710', 'L5711'],
#  ['L5737',
#   'L5738',
#   'L5739',
#   'L5740',
#   'L5741',
#   'L5742',
#   'L5743',
#   'L5744',
#   'L5745'],
#  ['L5746', 'L5747', 'L5748'],
#  ['L5751', 'L5752'],
#  ['L5754', 'L5755', 'L5756'],
#  ['L5760', 'L5761'],
#  ['L5613', 'L5614'],
#  ['L5615', 'L5616', 'L5617'],
#  ['L5620', 'L5621', 'L5622'],
#  ['L5624', 'L5625', 'L5626', 'L5627', 'L5628'],
#  ['L5648', 'L5649', 'L5650', 'L5651'],
#  ['L5652', 'L5653', 'L5654', 'L5655'],
#  ['L5656', 'L5657', 'L5658'],
#  ['L5826', 'L5827', 'L5828', 'L5829', 'L5830', 'L5831', 'L5832', 'L5833'],
#  ['L5839', 'L5840'],
#  ['L6168', 'L6169', 'L6170', 'L6171', 'L6172'],
#  ['L6258', 'L6259'],
#  ['L6263', 'L6264', 'L6265', 'L6266'],
#  ['L5463', 'L5464'],
#  ['L5468', 'L5469', 'L5470'],
#  ['L5508', 'L5509', 'L5510'],
#  ['L5511', 'L5512'],
#  ['L5515', 'L5516'],
#  ['L5521', 'L5522'],
#  ['L5556', 'L5557'],
#  ['L5630', 'L5631', 'L5632'],
#  ['L5636', 'L5637'],
#  ['L5646', 'L5647'],
#  ['L5671', 'L5672'],
#  ['L5675', 'L5676'],
#  ['L5686', 'L5687'],
#  ['L5688', 'L5689'],
#  ['L5730', 'L5731'],
#  ['L5911', 'L5912', 'L5913'],
#  ['L6251', 'L6252'],
#  ['L6105', 'L6106', 'L6107'],
#  ['L6108', 'L6109', 'L6110'],
#  ['L6114', 'L6115', 'L6116', 'L6117', 'L6118', 'L6119', 'L6120'],
#  ['L6123', 'L6124'],
#  ['L5488', 'L5489'],
#  ['L5490', 'L5491', 'L5492'],
#  ['L5493', 'L5494', 'L5495', 'L5496'],
#  ['L5497', 'L5498', 'L5499'],
#  ['L5501', 'L5502', 'L5503', 'L5504', 'L5505', 'L5506'],
#  ['L5664', 'L5665', 'L5666', 'L5667', 'L5668'],
#  ['L5669', 'L5670'],
#  ['L5596', 'L5597'],
#  ['L5605', 'L5606'],
#  ['L5609', 'L5610'],
#  ['L5611', 'L5612'],
#  ['L5633', 'L5634'],
#  ['L5638', 'L5639', 'L5640', 'L5641'],
#  ['L5420', 'L5421'],
#  ['L5422', 'L5423', 'L5424', 'L5425'],
#  ['L5426', 'L5427'],
#  ['L5777', 'L5778', 'L5779', 'L5780'],
#  ['L5782', 'L5783'],
#  ['L5785', 'L5786'],
#  ['L5787', 'L5788', 'L5789'],
#  ['L5790', 'L5791', 'L5792'],
#  ['L5880', 'L5881', 'L5882'],
#  ['L6029', 'L6030', 'L6031', 'L6032'],
#  ['L5543', 'L5544'],
#  ['L5545', 'L5546', 'L5547', 'L5548'],
#  ['L5834', 'L5835'],
#  ['L6208', 'L6209'],
#  ['L6211', 'L6212'],
#  ['L5922', 'L5923'],
#  ['L5924', 'L5925'],
#  ['L5933', 'L5934'],
#  ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026'],
#  ['L6132', 'L6133'],
#  ['L6156', 'L6157', 'L6158'],
#  ['L6183', 'L6184'],
#  ['L6190', 'L6191'],
#  ['L6206', 'L6207'],
#  ['L6213', 'L6214'],
#  ['L6215', 'L6216'],
#  ['L6278', 'L6279', 'L6280'],
#  ['L6282', 'L6283'],
#  ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800'],
#  ['L5801', 'L5802', 'L5803'],
#  ['L5804', 'L5805', 'L5806'],
#  ['L5809', 'L5810', 'L5811', 'L5812', 'L5813'],
#  ['L5815', 'L5816'],
#  ['L5817', 'L5818', 'L5819'],
#  ['L5820', 'L5821', 'L5822'],
#  ['L5824', 'L5825'],
#  ['L5858', 'L5859'],
#  ['L5869', 'L5870', 'L5871'],
#  ['L5900', 'L5901'],
#  ['L5943', 'L5944'],
#  ['L5946', 'L5947'],
#  ['L5949', 'L5950'],
#  ['L5954', 'L5955', 'L5956', 'L5957'],
#  ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965'],
#  ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056'],
#  ['L6057', 'L6058', 'L6059'],
#  ['L6062', 'L6063', 'L6064'],
#  ['L6066', 'L6067'],
#  ['L6237', 'L6238', 'L6239', 'L6240', 'L6241'],
#  ['L6267', 'L6268', 'L6269', 'L6270'],
#  ['L6289', 'L6290', 'L6291', 'L6292', 'L6293'],
#  ['L6297', 'L6298', 'L6299', 'L6300', 'L6301'],
#  ['L6302', 'L6303', 'L6304', 'L6305'],
#  ['L6308', 'L6309'],
#  ['L5722', 'L5723', 'L5724', 'L5725', 'L5726'],
#  ['L5728', 'L5729'],
#  ['L5531', 'L5532', 'L5533'],
#  ['L5534', 'L5535', 'L5536'],
#  ['L5537', 'L5538'],
#  ['L5539', 'L5540'],
#  ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567'],
#  ['L5568', 'L5569', 'L5570'],
#  ['L5573', 'L5574'],
#  ['L5585', 'L5586'],
#  ['L6313', 'L6314'],
#  ['L5767', 'L5768', 'L5769', 'L5770'],
#  ['L5773', 'L5774'],
#  ['L6254', 'L6255'],
#  ['L5441', 'L5442'],
#  ['L5443', 'L5444', 'L5445', 'L5446', 'L5447'],
#  ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453'],
#  ['L5479', 'L5480'],
#  ['L5396', 'L5397', 'L5398'],
#  ['L5399', 'L5400'],
#  ['L5404', 'L5405'],
#  ['L5406', 'L5407'],
#  ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225'],
#  ['L6002', 'L6003'],
#  ['L6004', 'L6005'],
#  ['L6006', 'L6007', 'L6008', 'L6009'],
#  ['L6011', 'L6012'],
#  ['L6335', 'L6336'],
#  ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344'],
#  ['L6347', 'L6348', 'L6349', 'L6350'],
#  ['L6351', 'L6352'],
#  ['L6361', 'L6362', 'L6363', 'L6364', 'L6365'],
#  ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435'],
#  ['L6957', 'L6958', 'L6959'],
#  ['L6960', 'L6961', 'L6962', 'L6963', 'L6964'],
#  ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976'],
#  ['L6977', 'L6978', 'L6979'],
#  ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985'],
#  ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993'],
#  ['L6996', 'L6997', 'L6998', 'L6999', 'L7000'],
#  ['L7001', 'L7002'],
#  ['L6605', 'L6606'],
#  ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612'],
#  ['L6707',
#   'L6708',
#   'L6709',
#   'L6710',
#   'L6711',
#   'L6712',
#   'L6713',
#   'L6714',
#   'L6715',
#   'L6716',
#   'L6717'],
#  ['L6909', 'L6910'],
#  ['L6779', 'L6780'],
#  ['L6781', 'L6782', 'L6783', 'L6784'],
#  ['L6789', 'L6790'],
#  ['L6791',
#   'L6792',
#   'L6793',
#   'L6794',
#   'L6795',
#   'L6796',
#   'L6797',
#   'L6798',
#   'L6799'],
#  ['L6800', 'L6801', 'L6802'],
#  ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808'],
#  ['L6810', 'L6811', 'L6812'],
#  ['L6814', 'L6815'],
#  ['L6828', 'L6829'],
#  ['L6830', 'L6831', 'L6832'],
#  ['L6833', 'L6834', 'L6835'],
#  ['L6840', 'L6841', 'L6842'],
#  ['L6844', 'L6845', 'L6846'],
#  ['L6852', 'L6853'],
#  ['L6858', 'L6859', 'L6860', 'L6861', 'L6862'],
#  ['L6863', 'L6864'],
#  ['L6847', 'L6848'],
#  ['L6865', 'L6866'],
#  ['L6906', 'L6907', 'L6908'],
#  ['L6911', 'L6912'],
#  ['L6935', 'L6936'],
#  ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442'],
#  ['L6443',
#   'L6444',
#   'L6445',
#   'L6446',
#   'L6447',
#   'L6448',
#   'L6449',
#   'L6450',
#   'L6451',
#   'L6452'],
#  ['L6453', 'L6454'],
#  ['L6460', 'L6461', 'L6462', 'L6463', 'L6464'],
#  ['L6693',
#   'L6694',
#   'L6695',
#   'L6696',
#   'L6697',
#   'L6698',
#   'L6699',
#   'L6700',
#   'L6701',
#   'L6702'],
#  ['L6919', 'L6920'],
#  ['L7013', 'L7014', 'L7015'],
#  ['L7016', 'L7017'],
#  ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025'],
#  ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033'],
#  ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039'],
#  ['L7043', 'L7044', 'L7045'],
#  ['L7048',
#   'L7049',
#   'L7050',
#   'L7051',
#   'L7052',
#   'L7053',
#   'L7054',
#   'L7055',
#   'L7056',
#   'L7057'],
#  ['L7059', 'L7060'],
#  ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067'],
#  ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076'],
#  ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692'],
#  ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380'],
#  ['L6868',
#   'L6869',
#   'L6870',
#   'L6871',
#   'L6872',
#   'L6873',
#   'L6874',
#   'L6875',
#   'L6876',
#   'L6877',
#   'L6878',
#   'L6879',
#   'L6880'],
#  ['L6881', 'L6882', 'L6883', 'L6884', 'L6885'],
#  ['L6886', 'L6887', 'L6888', 'L6889'],
#  ['L6890', 'L6891', 'L6892', 'L6893', 'L6894'],
#  ['L6898', 'L6899'],
#  ['L6900', 'L6901'],
#  ['L6902', 'L6903'],
#  ['L6921', 'L6922'],
#  ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553'],
#  ['L6556', 'L6557'],
#  ['L6558', 'L6559', 'L6560', 'L6561'],
#  ['L6568', 'L6569'],
#  ['L6570', 'L6571'],
#  ['L6574', 'L6575'],
#  ['L6576',
#   'L6577',
#   'L6578',
#   'L6579',
#   'L6580',
#   'L6581',
#   'L6582',
#   'L6583',
#   'L6584',
#   'L6585',
#   'L6586',
#   'L6587',
#   'L6588',
#   'L6589',
#   'L6590',
#   'L6591',
#   'L6592',
#   'L6593',
#   'L6594',
#   'L6595',
#   'L6596'],
#  ['L6597', 'L6598'],
#  ['L6614',
#   'L6615',
#   'L6616',
#   'L6617',
#   'L6618',
#   'L6619',
#   'L6620',
#   'L6621',
#   'L6622'],
#  ['L6623',
#   'L6624',
#   'L6625',
#   'L6626',
#   'L6627',
#   'L6628',
#   'L6629',
#   'L6630',
#   'L6631',
#   'L6632',
#   'L6633',
#   'L6634',
#   'L6635',
#   'L6636',
#   'L6637'],
#  ['L6722',
#   'L6723',
#   'L6724',
#   'L6725',
#   'L6726',
#   'L6727',
#   'L6728',
#   'L6729',
#   'L6730',
#   'L6731',
#   'L6732',
#   'L6733',
#   'L6734',
#   'L6735',
#   'L6736',
#   'L6737'],
#  ['L6750', 'L6751', 'L6752'],
#  ['L6753', 'L6754'],
#  ['L6757', 'L6758'],
#  ['L6762', 'L6763', 'L6764', 'L6765'],
#  ['L6768', 'L6769'],
#  ['L6787', 'L6788'],
#  ['L6816', 'L6817', 'L6818', 'L6819'],
#  ['L6821', 'L6822'],
#  ['L6823', 'L6824'],
#  ['L6368', 'L6369'],
#  ['L6372', 'L6373'],
#  ['L6382', 'L6383'],
#  ['L6384', 'L6385'],
#  ['L6386', 'L6387', 'L6388'],
#  ['L6389', 'L6390', 'L6391', 'L6392'],
#  ['L6395', 'L6396', 'L6397', 'L6398'],
#  ['L6399', 'L6400', 'L6401'],
#  ['L6402', 'L6403', 'L6404', 'L6405', 'L6406'],
#  ['L6407', 'L6408', 'L6409'],
#  ['L6410', 'L6411'],
#  ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418'],
#  ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424'],
#  ['L6425', 'L6426', 'L6427', 'L6428'],
#  ['L6639', 'L6640', 'L6641', 'L6642'],
#  ['L6643', 'L6644', 'L6645', 'L6646', 'L6647'],
#  ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655'],
#  ['L6738',
#   'L6739',
#   'L6740',
#   'L6741',
#   'L6742',
#   'L6743',
#   'L6744',
#   'L6745',
#   'L6746'],
#  ['L6747', 'L6748', 'L6749'],
#  ['L6466', 'L6467'],
#  ['L6468', 'L6469', 'L6470', 'L6471', 'L6472'],
#  ['L6473', 'L6474', 'L6475', 'L6476', 'L6477'],
#  ['L6479', 'L6480', 'L6481'],
#  ['L6482', 'L6483'],
#  ['L6485',
#   'L6486',
#   'L6487',
#   'L6488',
#   'L6489',
#   'L6490',
#   'L6491',
#   'L6492',
#   'L6493',
#   'L6494',
#   'L6495',
#   'L6496',
#   'L6497',
#   'L6498',
#   'L6499',
#   'L6500',
#   'L6501',
#   'L6502'],
#  ['L6503', 'L6504'],
#  ['L6507', 'L6508'],
#  ['L6511', 'L6512', 'L6513', 'L6514', 'L6515'],
#  ['L6516',
#   'L6517',
#   'L6518',
#   'L6519',
#   'L6520',
#   'L6521',
#   'L6522',
#   'L6523',
#   'L6524'],
#  ['L6525', 'L6526', 'L6527', 'L6528'],
#  ['L6531', 'L6532'],
#  ['L6534', 'L6535', 'L6536'],
#  ['L7081', 'L7082', 'L7083', 'L7084'],
#  ['L7085', 'L7086', 'L7087'],
#  ['L7088',
#   'L7089',
#   'L7090',
#   'L7091',
#   'L7092',
#   'L7093',
#   'L7094',
#   'L7095',
#   'L7096',
#   'L7097',
#   'L7098'],
#  ['L6657', 'L6658', 'L6659'],
#  ['L6661', 'L6662'],
#  ['L6665', 'L6666', 'L6667', 'L6668'],
#  ['L6669', 'L6670', 'L6671'],
#  ['L6354', 'L6355', 'L6356', 'L6357'],
#  ['L6358', 'L6359', 'L6360'],
#  ['L6676', 'L6677', 'L6678'],
#  ['L6679', 'L6680', 'L6681'],
#  ['L6682', 'L6683', 'L6684'],
#  ['L8029', 'L8030', 'L8031', 'L8032'],
#  ['L8033', 'L8034', 'L8035'],
#  ['L8036', 'L8037'],
#  ['L8094', 'L8095', 'L8096', 'L8097'],
#  ['L8155', 'L8156'],
#  ['L8196', 'L8197', 'L8198', 'L8199'],
#  ...]

# %%
### Get the questions and answers seperatly

# Initialize an empry list for questions
questions = []

# Initialize an empry list for answers
answers = []

# Iterate through conversation ids
for i_conversation in conversation_ids:
    
    # Iterate through length of i_conversation
    for index in range(len(i_conversation) - 1):

        # Get the text of current index
        current_text = id2line[i_conversation[index]]
        
        # Append the text to questions array
        questions.append(current_text)
        
        # Get the text of next index
        next_text = id2line[i_conversation[index + 1]]
        
        # Append the text to answers array
        answers.append(next_text)

# %%
# Take a look at questions
questions[:5]
# Out:
# ['Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  "Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "You're asking me out.  That's so cute. What's your name again?",
#  "No, no, it's my fault -- we didn't have a proper introduction ---"]

# %%
# Take a look at answers
answers[:5]
# Out:
# ["Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'Forget it.',
#  'Cameron.']

# %% [markdown]
# <br>
#
# # 3. Data Preprocessing
#
# <hr>
#
# In this section we will take the following steps for preprocessing our dataset:
# 1. Lowercasing the text
# 2. Decontracting the text
# 3. Remove the punctuation

# %%
# Preprocessing function
def preprocess_text(text):
    """
    Function for applying the preprocesssing steps.
    """
    # 1. Lowercase the text
    text = text.lower()
    
    # 2. De-contract the text
    text = contractions.fix(text)
    
    # 3. Remove the punctuation
    text = re.sub(r"[^a-zA-Z0-9]", " ", text)

    return text

# %%
# Apply preprocesing function to our questions
questions_preprocessed = []
for i_question in tqdm(questions):
    questions_preprocessed.append(preprocess_text(i_question))

# Apply preprocesing function to our answers
answers_preprocessed = []
for i_answer in tqdm(answers):
    answers_preprocessed.append(preprocess_text(i_answer))
# Out:
# 100%|██████████| 221616/221616 [00:51<00:00, 4275.71it/s]
# 100%|██████████| 221616/221616 [00:57<00:00, 3887.97it/s]

# %%
# Take a look at preprocessed questions
questions_preprocessed[:5]
# Out:
# ['can we make this quick   roxanne korrine and andrew barrett are having an incredibly horrendous public break  up on the quad   again ',
#  'well  i thought we would start with pronunciation  if that is okay with you ',
#  'not the hacking and gagging and spitting part   please ',
#  'you are asking me out   that is so cute  what is your name again ',
#  'no  no  it is my fault    we did not have a proper introduction    ']

# %%
# Take a look at preprocessed answers
answers_preprocessed[:5]
# Out:
# ['well  i thought we would start with pronunciation  if that is okay with you ',
#  'not the hacking and gagging and spitting part   please ',
#  'okay    then how  bout we try out some french cuisine   saturday   night ',
#  'forget it ',
#  'cameron ']

# %%
# Initialize an empty dictionary for counting words
word2count = {}

# Create a word count dictionary for questions
for i_question in tqdm(questions_preprocessed):
    for i_word in i_question.split():
        if i_word not in word2count:
            word2count[i_word] = 1
        else:
            word2count[i_word] += 1

# Create a word count dictionary for answers
for i_answer in tqdm(questions_preprocessed):
    for i_word in i_answer.split():
        if i_word not in word2count:
            word2count[i_word] = 1
        else:
            word2count[i_word] += 1
# Out:
# 100%|██████████| 221616/221616 [00:01<00:00, 124866.25it/s]
# 100%|██████████| 221616/221616 [00:01<00:00, 169782.75it/s]

# %%
### Remove the least used words

# Threshold; If occurrence of each word is below this number, it will get deleted
threshold = 20    

# Map the question words to a unique integer
questionwords2int = {}
word_number = 0
for i_word, i_count in word2count.items():
    if i_count >= threshold:
        questionwords2int[i_word] = word_number
        word_number += 1

# Map the answer words to a unique integer
answerwords2int = {}
word_number = 0
for i_word, i_count in word2count.items():
    if i_count >= threshold:
        answerwords2int[i_word] = word_number
        word_number += 1

# %%
# Take a look at questionsword2int
questionwords2int
# Out:
# {'can': 0,
#  'we': 1,
#  'make': 2,
#  'this': 3,
#  'quick': 4,
#  'and': 5,
#  'andrew': 6,
#  'barrett': 7,
#  'are': 8,
#  'having': 9,
#  'an': 10,
#  'incredibly': 11,
#  'public': 12,
#  'break': 13,
#  'up': 14,
#  'on': 15,
#  'the': 16,
#  'again': 17,
#  'well': 18,
#  'i': 19,
#  'thought': 20,
#  'would': 21,
#  'start': 22,
#  'with': 23,
#  'if': 24,
#  'that': 25,
#  'is': 26,
#  'okay': 27,
#  'you': 28,
#  'not': 29,
#  'part': 30,
#  'please': 31,
#  'asking': 32,
#  'me': 33,
#  'out': 34,
#  'so': 35,
#  'cute': 36,
#  'what': 37,
#  'your': 38,
#  'name': 39,
#  'no': 40,
#  'it': 41,
#  'my': 42,
#  'fault': 43,
#  'did': 44,
#  'have': 45,
#  'a': 46,
#  'proper': 47,
#  'introduction': 48,
#  'cameron': 49,
#  'thing': 50,
#  'm': 51,
#  'at': 52,
#  'mercy': 53,
#  'of': 54,
#  'particularly': 55,
#  'hideous': 56,
#  'breed': 57,
#  'loser': 58,
#  'sister': 59,
#  'cannot': 60,
#  'date': 61,
#  'until': 62,
#  'she': 63,
#  'does': 64,
#  'why': 65,
#  'mystery': 66,
#  'used': 67,
#  'to': 68,
#  'be': 69,
#  'really': 70,
#  'popular': 71,
#  'when': 72,
#  'started': 73,
#  'high': 74,
#  'school': 75,
#  'then': 76,
#  'was': 77,
#  'just': 78,
#  'like': 79,
#  'got': 80,
#  'sick': 81,
#  'or': 82,
#  'something': 83,
#  'gosh': 84,
#  'only': 85,
#  'could': 86,
#  'find': 87,
#  'kat': 88,
#  'boyfriend': 89,
#  'c': 90,
#  'ma': 91,
#  'head': 92,
#  'right': 93,
#  'see': 94,
#  'ready': 95,
#  'for': 96,
#  'do': 97,
#  'want': 98,
#  'know': 99,
#  'how': 100,
#  'say': 101,
#  'though': 102,
#  'useful': 103,
#  'things': 104,
#  'where': 105,
#  'good': 106,
#  'stores': 107,
#  'much': 108,
#  'champagne': 109,
#  'cost': 110,
#  'stuff': 111,
#  'chat': 112,
#  'never': 113,
#  'in': 114,
#  'life': 115,
#  'had': 116,
#  'point': 117,
#  'someone': 118,
#  'because': 119,
#  'such': 120,
#  'nice': 121,
#  'one': 122,
#  'our': 123,
#  'little': 124,
#  'plan': 125,
#  'there': 126,
#  'mind': 127,
#  'word': 128,
#  'as': 129,
#  'gentleman': 130,
#  'get': 131,
#  'hair': 132,
#  'look': 133,
#  'sure': 134,
#  'go': 135,
#  'but': 136,
#  'unless': 137,
#  'goes': 138,
#  'lesbian': 139,
#  'found': 140,
#  'picture': 141,
#  'her': 142,
#  'pretty': 143,
#  'same': 144,
#  'sex': 145,
#  'kind': 146,
#  'guy': 147,
#  'likes': 148,
#  'ones': 149,
#  'hi': 150,
#  'fun': 151,
#  'tonight': 152,
#  'looked': 153,
#  'back': 154,
#  'party': 155,
#  'always': 156,
#  'seemed': 157,
#  'occupied': 158,
#  'all': 159,
#  'says': 160,
#  'any': 161,
#  'lighter': 162,
#  'going': 163,
#  'extra': 164,
#  'listen': 165,
#  'crap': 166,
#  'endless': 167,
#  'blonde': 168,
#  'boring': 169,
#  'myself': 170,
#  'figured': 171,
#  'eventually': 172,
#  'real': 173,
#  'kidding': 174,
#  'sometimes': 175,
#  'become': 176,
#  'quit': 177,
#  'wow': 178,
#  'they': 179,
#  'change': 180,
#  'he': 181,
#  'here': 182,
#  'who': 183,
#  'great': 184,
#  'practically': 185,
#  'proposed': 186,
#  'mean': 187,
#  'dr': 188,
#  'exactly': 189,
#  'relevant': 190,
#  'conversation': 191,
#  'dry': 192,
#  'bianca': 193,
#  'think': 194,
#  'dating': 195,
#  'joey': 196,
#  'include': 197,
#  'door': 198,
#  'opening': 199,
#  'coat': 200,
#  'holding': 201,
#  'wonder': 202,
#  'guys': 203,
#  'supposed': 204,
#  'actually': 205,
#  'home': 206,
#  'twenty': 207,
#  'minutes': 208,
#  're': 209,
#  'prom': 210,
#  'more': 211,
#  's': 212,
#  'saturday': 213,
#  'yeah': 214,
#  've': 215,
#  'tube': 216,
#  'sock': 217,
#  'gig': 218,
#  'huge': 219,
#  'ad': 220,
#  'queen': 221,
#  'harry': 222,
#  'next': 223,
#  'week': 224,
#  'neat': 225,
#  'hey': 226,
#  'sweet': 227,
#  'cheeks': 228,
#  'talk': 229,
#  'about': 230,
#  'been': 231,
#  'potential': 232,
#  'smack': 233,
#  'way': 234,
#  'oh': 235,
#  'god': 236,
#  'becoming': 237,
#  'normal': 238,
#  'means': 239,
#  'playing': 240,
#  'club': 241,
#  'skunk': 242,
#  'might': 243,
#  'bothering': 244,
#  'ask': 245,
#  'night': 246,
#  'ruining': 247,
#  'will': 248,
#  'forget': 249,
#  'completely': 250,
#  'wretched': 251,
#  'even': 252,
#  'shakespeare': 253,
#  'maybe': 254,
#  'heard': 255,
#  'him': 256,
#  'need': 257,
#  'tell': 258,
#  'act': 259,
#  'too': 260,
#  'totally': 261,
#  'hate': 262,
#  'sit': 263,
#  'susie': 264,
#  'care': 265,
#  'firm': 266,
#  'believer': 267,
#  'doing': 268,
#  'own': 269,
#  'reasons': 270,
#  'else': 271,
#  'told': 272,
#  'went': 273,
#  'month': 274,
#  'total': 275,
#  'babe': 276,
#  'now': 277,
#  'different': 278,
#  'story': 279,
#  'said': 280,
#  'everyone': 281,
#  'after': 282,
#  'swore': 283,
#  'anything': 284,
#  'since': 285,
#  'except': 286,
#  'display': 287,
#  'wanted': 288,
#  'let': 289,
#  'stupid': 290,
#  'enough': 291,
#  'repeat': 292,
#  'mistakes': 293,
#  'guess': 294,
#  'protecting': 295,
#  'keep': 296,
#  'locked': 297,
#  'away': 298,
#  'dark': 299,
#  'experience': 300,
#  'experiences': 301,
#  'trust': 302,
#  'people': 303,
#  'beautiful': 304,
#  'last': 305,
#  'set': 306,
#  'damage': 307,
#  'send': 308,
#  'therapy': 309,
#  'forever': 310,
#  'woman': 311,
#  'complete': 312,
#  'fruit': 313,
#  'loop': 314,
#  'patrick': 315,
#  'upset': 316,
#  'daddy': 317,
#  'boy': 318,
#  'starts': 319,
#  'end': 320,
#  'discussion': 321,
#  'neither': 322,
#  'sleep': 323,
#  'must': 324,
#  'were': 325,
#  'attempting': 326,
#  'small': 327,
#  'study': 328,
#  'group': 329,
#  'friends': 330,
#  'otherwise': 331,
#  'known': 332,
#  'expect': 333,
#  'starting': 334,
#  'wear': 335,
#  'belly': 336,
#  'before': 337,
#  'promise': 338,
#  'boys': 339,
#  'present': 340,
#  'discuss': 341,
#  'tomorrow': 342,
#  'has': 343,
#  'hot': 344,
#  'rod': 345,
#  'bend': 346,
#  'rules': 347,
#  'whatever': 348,
#  'missing': 349,
#  'pleasure': 350,
#  'fan': 351,
#  'pre': 352,
#  'button': 353,
#  'ring': 354,
#  'couple': 355,
#  'minors': 356,
#  'come': 357,
#  'girls': 358,
#  'tall': 359,
#  'decent': 360,
#  'body': 361,
#  'other': 362,
#  'kinda': 363,
#  'short': 364,
#  'new': 365,
#  'which': 366,
#  'dakota': 367,
#  'from': 368,
#  'north': 369,
#  'live': 370,
#  'by': 371,
#  'cows': 372,
#  'many': 373,
#  'old': 374,
#  'thirty': 375,
#  'two': 376,
#  'girl': 377,
#  'burn': 378,
#  'pine': 379,
#  'bred': 380,
#  'their': 381,
#  'mothers': 382,
#  'liked': 383,
#  'them': 384,
#  'gene': 385,
#  'pool': 386,
#  'rarely': 387,
#  'shit': 388,
#  'eating': 389,
#  'french': 390,
#  'mom': 391,
#  'canada': 392,
#  'signed': 393,
#  'chance': 394,
#  'minor': 395,
#  'encounter': 396,
#  'teach': 397,
#  'charm': 398,
#  'falls': 399,
#  'love': 400,
#  'makes': 401,
#  'seems': 402,
#  'danger': 403,
#  'criminal': 404,
#  'lit': 405,
#  'state': 406,
#  'fire': 407,
#  'serious': 408,
#  'man': 409,
#  'whacked': 410,
#  'sold': 411,
#  'his': 412,
#  'liver': 413,
#  'black': 414,
#  'market': 415,
#  'buy': 416,
#  'reputation': 417,
#  'strictly': 418,
#  'list': 419,
#  'side': 420,
#  'hated': 421,
#  'those': 422,
#  'involved': 423,
#  'golden': 424,
#  'opportunity': 425,
#  'case': 426,
#  'wide': 427,
#  'blow': 428,
#  'bent': 429,
#  'number': 430,
#  'hates': 431,
#  'lung': 432,
#  'cancer': 433,
#  'issue': 434,
#  'favorite': 435,
#  'uncle': 436,
#  'ears': 437,
#  'already': 438,
#  'extremely': 439,
#  'unfortunate': 440,
#  'maneuver': 441,
#  'hell': 442,
#  'picks': 443,
#  'carries': 444,
#  'while': 445,
#  'talking': 446,
#  'making': 447,
#  'progress': 448,
#  'humiliated': 449,
#  'sacrifice': 450,
#  'yourself': 451,
#  'dignity': 452,
#  'score': 453,
#  'non': 454,
#  'prison': 455,
#  'movie': 456,
#  'type': 457,
#  'food': 458,
#  'angry': 459,
#  'music': 460,
#  'rock': 461,
#  'busy': 462,
#  'thousand': 463,
#  'direct': 464,
#  'quote': 465,
#  'makin': 466,
#  'kissed': 467,
#  'worst': 468,
#  'over': 469,
#  'reading': 470,
#  'noticed': 471,
#  'big': 472,
#  'spread': 473,
#  'elbow': 474,
#  'tough': 475,
#  'ya': 476,
#  'leave': 477,
#  'alone': 478,
#  'legs': 479,
#  'rack': 480,
#  'money': 481,
#  'take': 482,
#  'verona': 483,
#  'pick': 484,
#  'tab': 485,
#  'pay': 486,
#  'some': 487,
#  'gets': 488,
#  'catch': 489,
#  'bucks': 490,
#  'negotiation': 491,
#  'fifty': 492,
#  'results': 493,
#  'watching': 494,
#  'bitch': 495,
#  'trash': 496,
#  'car': 497,
#  'count': 498,
#  'price': 499,
#  'hundred': 500,
#  'time': 501,
#  'limo': 502,
#  'flowers': 503,
#  'another': 504,
#  'lost': 505,
#  'nope': 506,
#  'came': 507,
#  'run': 508,
#  'idea': 509,
#  'interested': 510,
#  'insane': 511,
#  'purpose': 512,
#  'hear': 513,
#  'uh': 514,
#  'friend': 515,
#  'better': 516,
#  'fuck': 517,
#  'heavily': 518,
#  'invested': 519,
#  'random': 520,
#  'pat': 521,
#  'gone': 522,
#  'year': 523,
#  'porn': 524,
#  'movies': 525,
#  'incapable': 526,
#  'interesting': 527,
#  'eat': 528,
#  'starving': 529,
#  'very': 530,
#  'slow': 531,
#  'die': 532,
#  'realize': 533,
#  'men': 534,
#  'fine': 535,
#  'institution': 536,
#  'lacking': 537,
#  'killing': 538,
#  'william': 539,
#  'beyond': 540,
#  'scope': 541,
#  'teenage': 542,
#  'far': 543,
#  'past': 544,
#  'daytime': 545,
#  'show': 546,
#  'entering': 547,
#  'world': 548,
#  'expensive': 549,
#  'foul': 550,
#  'fit': 551,
#  'sarah': 552,
#  'lawrence': 553,
#  'insists': 554,
#  'male': 555,
#  'golf': 556,
#  'team': 557,
#  'proven': 558,
#  'appreciate': 559,
#  'efforts': 560,
#  'toward': 561,
#  'death': 562,
#  'matter': 563,
#  'work': 564,
#  'officially': 565,
#  'opposed': 566,
#  'social': 567,
#  'activity': 568,
#  'choice': 569,
#  'done': 570,
#  'favor': 571,
#  'imagine': 572,
#  'commercial': 573,
#  'dates': 574,
#  'sound': 575,
#  'betty': 576,
#  'pissed': 577,
#  'off': 578,
#  'archie': 579,
#  'taking': 580,
#  'veronica': 581,
#  'dress': 582,
#  'anyway': 583,
#  'looking': 584,
#  'wrong': 585,
#  'perspective': 586,
#  'statement': 587,
#  'seen': 588,
#  'asked': 589,
#  'meet': 590,
#  'sweating': 591,
#  'pig': 592,
#  'attention': 593,
#  'friday': 594,
#  'places': 595,
#  '7': 596,
#  'eleven': 597,
#  'warrant': 598,
#  'strong': 599,
#  'emotion': 600,
#  'spend': 601,
#  'dollar': 602,
#  'track': 603,
#  'flat': 604,
#  'beer': 605,
#  'eyes': 606,
#  'hand': 607,
#  'ass': 608,
#  'covered': 609,
#  'vomit': 610,
#  'following': 611,
#  'saw': 612,
#  'huh': 613,
#  'excuse': 614,
#  'these': 615,
#  'kill': 616,
#  'getting': 617,
#  'trashed': 618,
#  'lie': 619,
#  'down': 620,
#  'awhile': 621,
#  'use': 622,
#  'words': 623,
#  'needs': 624,
#  'affection': 625,
#  'blind': 626,
#  'hatred': 627,
#  'deal': 628,
#  'tequila': 629,
#  'seem': 630,
#  'don': 631,
#  't': 632,
#  'cool': 633,
#  'laid': 634,
#  'above': 635,
#  'wake': 636,
#  'control': 637,
#  'jail': 638,
#  'should': 639,
#  'band': 640,
#  'father': 641,
#  'approve': 642,
#  'dad': 643,
#  'pain': 644,
#  'wants': 645,
#  'feminine': 646,
#  'copy': 647,
#  'poetry': 648,
#  'still': 649,
#  'panties': 650,
#  'twist': 651,
#  'minute': 652,
#  'effect': 653,
#  'whatsoever': 654,
#  'left': 655,
#  'dickhead': 656,
#  'afraid': 657,
#  'heights': 658,
#  'mon': 659,
#  'bad': 660,
#  'put': 661,
#  'foot': 662,
#  'stayin': 663,
#  'climb': 664,
#  'family': 665,
#  'ridiculous': 666,
#  'win': 667,
#  'respect': 668,
#  'piss': 669,
#  'call': 670,
#  'soft': 671,
#  'knew': 672,
#  'acting': 673,
#  'yes': 674,
#  'disappointed': 675,
#  'disappoint': 676,
#  'screwed': 677,
#  'duck': 678,
#  'true': 679,
#  'knows': 680,
#  'sexy': 681,
#  'self': 682,
#  'assured': 683,
#  'anyone': 684,
#  'ever': 685,
#  'request': 686,
#  'command': 687,
#  'create': 688,
#  'drama': 689,
#  'rumor': 690,
#  'motive': 691,
#  'answer': 692,
#  'question': 693,
#  'convicted': 694,
#  'grandmother': 695,
#  'adorable': 696,
#  'wait': 697,
#  'paid': 698,
#  'person': 699,
#  'truly': 700,
#  'payment': 701,
#  'bonus': 702,
#  'sleeping': 703,
#  'bought': 704,
#  'besides': 705,
#  'cash': 706,
#  'asshole': 707,
#  'burger': 708,
#  'burnt': 709,
#  'object': 710,
#  'torture': 711,
#  'decided': 712,
#  '0': 713,
#  'whose': 714,
#  'diary': 715,
#  'devoted': 716,
#  'tips': 717,
#  'insurance': 718,
#  'cover': 719,
#  'pms': 720,
#  'agree': 721,
#  'decisions': 722,
#  'parent': 723,
#  'eighteen': 724,
#  'forty': 725,
#  'five': 726,
#  'full': 727,
#  'sperm': 728,
#  'understand': 729,
#  'hip': 730,
#  'dance': 731,
#  'parts': 732,
#  'beat': 733,
#  'fathers': 734,
#  'admit': 735,
#  'daughters': 736,
#  'capable': 737,
#  'running': 738,
#  'lives': 739,
#  'us': 740,
#  'play': 741,
#  'few': 742,
#  'years': 743,
#  'able': 744,
#  'watch': 745,
#  'game': 746,
#  'ms': 747,
#  'opinion': 748,
#  'terrorist': 749,
#  'action': 750,
#  'compared': 751,
#  'choices': 752,
#  'expression': 753,
#  'today': 754,
#  'events': 755,
#  'quite': 756,
#  'bobby': 757,
#  'retrieval': 758,
#  'operation': 759,
#  'maintain': 760,
#  'kicked': 761,
#  'himself': 762,
#  'balls': 763,
#  'merely': 764,
#  'am': 765,
#  'feel': 766,
#  'tired': 767,
#  'breathing': 768,
#  'pictures': 769,
#  'situation': 770,
#  'major': 771,
#  'jones': 772,
#  'speak': 773,
#  'pure': 774,
#  'than': 775,
#  'help': 776,
#  'wild': 777,
#  'beast': 778,
#  'telling': 779,
#  'prefer': 780,
#  'simply': 781,
#  'alternative': 782,
#  'law': 783,
#  'allows': 784,
#  'cozy': 785,
#  'thy': 786,
#  'force': 787,
#  'missed': 788,
#  'exposed': 789,
#  'lunch': 790,
#  'feeling': 791,
#  'touch': 792,
#  'flu': 793,
#  'driving': 794,
#  'slightly': 795,
#  'psychotic': 796,
#  'microwave': 797,
#  'jesus': 798,
#  'grab': 799,
#  'sandwich': 800,
#  'women': 801,
#  'rather': 802,
#  'pirate': 803,
#  'british': 804,
#  'rear': 805,
#  'admiral': 806,
#  'kiss': 807,
#  'honey': 808,
#  'happened': 809,
#  'absolutely': 810,
#  'heat': 811,
#  'las': 812,
#  'water': 813,
#  'barrels': 814,
#  'listening': 815,
#  'chicken': 816,
#  'ah': 817,
#  'harm': 818,
#  'devil': 819,
#  'child': 820,
#  'land': 821,
#  'three': 822,
#  'weeks': 823,
#  'ago': 824,
#  'near': 825,
#  'asia': 826,
#  'sailing': 827,
#  'west': 828,
#  'voyage': 829,
#  'six': 830,
#  'seven': 831,
#  'unfortunately': 832,
#  'colon': 833,
#  'precisely': 834,
#  'opinions': 835,
#  'familiar': 836,
#  'senor': 837,
#  'experienced': 838,
#  'captain': 839,
#  'concern': 840,
#  'crew': 841,
#  'willing': 842,
#  'conscience': 843,
#  'loss': 844,
#  'upon': 845,
#  'judgment': 846,
#  'settle': 847,
#  'journey': 848,
#  'risk': 849,
#  'prove': 850,
#  'possible': 851,
#  'others': 852,
#  'trade': 853,
#  'excellency': 854,
#  'according': 855,
#  'marco': 856,
#  'polo': 857,
#  'kingdom': 858,
#  'china': 859,
#  'richest': 860,
#  'buildings': 861,
#  'gold': 862,
#  'interests': 863,
#  'intended': 864,
#  'believe': 865,
#  'waited': 866,
#  'considered': 867,
#  'reason': 868,
#  'proposition': 869,
#  'ours': 870,
#  'try': 871,
#  'convince': 872,
#  'king': 873,
#  'absurd': 874,
#  'notions': 875,
#  'easy': 876,
#  'rid': 877,
#  'sanchez': 878,
#  'tragedy': 879,
#  'waste': 880,
#  'given': 881,
#  'marry': 882,
#  'leaving': 883,
#  'argue': 884,
#  'perhaps': 885,
#  'meant': 886,
#  'swear': 887,
#  'usually': 888,
#  'taken': 889,
#  'took': 890,
#  'everything': 891,
#  'stay': 892,
#  'soon': 893,
#  'islands': 894,
#  'forgive': 895,
#  'positions': 896,
#  'may': 897,
#  'whom': 898,
#  'de': 899,
#  'letters': 900,
#  'appointment': 901,
#  'sea': 902,
#  'hope': 903,
#  'mainland': 904,
#  'holy': 905,
#  'saints': 906,
#  'heaven': 907,
#  'explore': 908,
#  'asks': 909,
#  'visit': 910,
#  'address': 911,
#  'remember': 912,
#  'beginning': 913,
#  'yet': 914,
#  'remind': 915,
#  'position': 916,
#  'bargain': 917,
#  'ambitious': 918,
#  'ambition': 919,
#  'virtue': 920,
#  'among': 921,
#  'rest': 922,
#  'sin': 923,
#  'nature': 924,
#  'ending': 925,
#  'summer': 926,
#  'trees': 927,
#  'filled': 928,
#  'defend': 929,
#  'lack': 930,
#  'contact': 931,
#  'administration': 932,
#  'judge': 933,
#  'dear': 934,
#  'special': 935,
#  'talent': 936,
#  'guards': 937,
#  'nothing': 938,
#  'dreamer': 939,
#  'towers': 940,
#  'cuba': 941,
#  'tribe': 942,
#  'island': 943,
#  'first': 944,
#  'chief': 945,
#  'thank': 946,
#  'thousands': 947,
#  'bring': 948,
#  'also': 949,
#  'medicine': 950,
#  'peace': 951,
#  'understands': 952,
#  'diego': 953,
#  'bright': 954,
#  'brothers': 955,
#  'raised': 956,
#  'together': 957,
#  'manage': 958,
#  'wish': 959,
#  'sail': 960,
#  'certain': 961,
#  'ocean': 962,
#  'ignorance': 963,
#  'leagues': 964,
#  'canary': 965,
#  'jew': 966,
#  'dead': 967,
#  'passion': 968,
#  'carried': 969,
#  'being': 970,
#  'eternity': 971,
#  'give': 972,
#  'despair': 973,
#  'longer': 974,
#  'lies': 975,
#  'et': 976,
#  'son': 977,
#  'betrayed': 978,
#  'saying': 979,
#  'lied': 980,
#  'long': 981,
#  'follow': 982,
#  'frightening': 983,
#  'believed': 984,
#  'suppose': 985,
#  'both': 986,
#  'disagree': 987,
#  'worlds': 988,
#  'council': 989,
#  'tells': 990,
#  'honor': 991,
#  'fool': 992,
#  'ignore': 993,
#  'freely': 994,
#  'accept': 995,
#  'thinks': 996,
#  'thoughts': 997,
#  'without': 998,
#  'nor': 999,
#  ...}

# %%
# Take a look at answerwords2int
answerwords2int
# Out:
# {'can': 0,
#  'we': 1,
#  'make': 2,
#  'this': 3,
#  'quick': 4,
#  'and': 5,
#  'andrew': 6,
#  'barrett': 7,
#  'are': 8,
#  'having': 9,
#  'an': 10,
#  'incredibly': 11,
#  'public': 12,
#  'break': 13,
#  'up': 14,
#  'on': 15,
#  'the': 16,
#  'again': 17,
#  'well': 18,
#  'i': 19,
#  'thought': 20,
#  'would': 21,
#  'start': 22,
#  'with': 23,
#  'if': 24,
#  'that': 25,
#  'is': 26,
#  'okay': 27,
#  'you': 28,
#  'not': 29,
#  'part': 30,
#  'please': 31,
#  'asking': 32,
#  'me': 33,
#  'out': 34,
#  'so': 35,
#  'cute': 36,
#  'what': 37,
#  'your': 38,
#  'name': 39,
#  'no': 40,
#  'it': 41,
#  'my': 42,
#  'fault': 43,
#  'did': 44,
#  'have': 45,
#  'a': 46,
#  'proper': 47,
#  'introduction': 48,
#  'cameron': 49,
#  'thing': 50,
#  'm': 51,
#  'at': 52,
#  'mercy': 53,
#  'of': 54,
#  'particularly': 55,
#  'hideous': 56,
#  'breed': 57,
#  'loser': 58,
#  'sister': 59,
#  'cannot': 60,
#  'date': 61,
#  'until': 62,
#  'she': 63,
#  'does': 64,
#  'why': 65,
#  'mystery': 66,
#  'used': 67,
#  'to': 68,
#  'be': 69,
#  'really': 70,
#  'popular': 71,
#  'when': 72,
#  'started': 73,
#  'high': 74,
#  'school': 75,
#  'then': 76,
#  'was': 77,
#  'just': 78,
#  'like': 79,
#  'got': 80,
#  'sick': 81,
#  'or': 82,
#  'something': 83,
#  'gosh': 84,
#  'only': 85,
#  'could': 86,
#  'find': 87,
#  'kat': 88,
#  'boyfriend': 89,
#  'c': 90,
#  'ma': 91,
#  'head': 92,
#  'right': 93,
#  'see': 94,
#  'ready': 95,
#  'for': 96,
#  'do': 97,
#  'want': 98,
#  'know': 99,
#  'how': 100,
#  'say': 101,
#  'though': 102,
#  'useful': 103,
#  'things': 104,
#  'where': 105,
#  'good': 106,
#  'stores': 107,
#  'much': 108,
#  'champagne': 109,
#  'cost': 110,
#  'stuff': 111,
#  'chat': 112,
#  'never': 113,
#  'in': 114,
#  'life': 115,
#  'had': 116,
#  'point': 117,
#  'someone': 118,
#  'because': 119,
#  'such': 120,
#  'nice': 121,
#  'one': 122,
#  'our': 123,
#  'little': 124,
#  'plan': 125,
#  'there': 126,
#  'mind': 127,
#  'word': 128,
#  'as': 129,
#  'gentleman': 130,
#  'get': 131,
#  'hair': 132,
#  'look': 133,
#  'sure': 134,
#  'go': 135,
#  'but': 136,
#  'unless': 137,
#  'goes': 138,
#  'lesbian': 139,
#  'found': 140,
#  'picture': 141,
#  'her': 142,
#  'pretty': 143,
#  'same': 144,
#  'sex': 145,
#  'kind': 146,
#  'guy': 147,
#  'likes': 148,
#  'ones': 149,
#  'hi': 150,
#  'fun': 151,
#  'tonight': 152,
#  'looked': 153,
#  'back': 154,
#  'party': 155,
#  'always': 156,
#  'seemed': 157,
#  'occupied': 158,
#  'all': 159,
#  'says': 160,
#  'any': 161,
#  'lighter': 162,
#  'going': 163,
#  'extra': 164,
#  'listen': 165,
#  'crap': 166,
#  'endless': 167,
#  'blonde': 168,
#  'boring': 169,
#  'myself': 170,
#  'figured': 171,
#  'eventually': 172,
#  'real': 173,
#  'kidding': 174,
#  'sometimes': 175,
#  'become': 176,
#  'quit': 177,
#  'wow': 178,
#  'they': 179,
#  'change': 180,
#  'he': 181,
#  'here': 182,
#  'who': 183,
#  'great': 184,
#  'practically': 185,
#  'proposed': 186,
#  'mean': 187,
#  'dr': 188,
#  'exactly': 189,
#  'relevant': 190,
#  'conversation': 191,
#  'dry': 192,
#  'bianca': 193,
#  'think': 194,
#  'dating': 195,
#  'joey': 196,
#  'include': 197,
#  'door': 198,
#  'opening': 199,
#  'coat': 200,
#  'holding': 201,
#  'wonder': 202,
#  'guys': 203,
#  'supposed': 204,
#  'actually': 205,
#  'home': 206,
#  'twenty': 207,
#  'minutes': 208,
#  're': 209,
#  'prom': 210,
#  'more': 211,
#  's': 212,
#  'saturday': 213,
#  'yeah': 214,
#  've': 215,
#  'tube': 216,
#  'sock': 217,
#  'gig': 218,
#  'huge': 219,
#  'ad': 220,
#  'queen': 221,
#  'harry': 222,
#  'next': 223,
#  'week': 224,
#  'neat': 225,
#  'hey': 226,
#  'sweet': 227,
#  'cheeks': 228,
#  'talk': 229,
#  'about': 230,
#  'been': 231,
#  'potential': 232,
#  'smack': 233,
#  'way': 234,
#  'oh': 235,
#  'god': 236,
#  'becoming': 237,
#  'normal': 238,
#  'means': 239,
#  'playing': 240,
#  'club': 241,
#  'skunk': 242,
#  'might': 243,
#  'bothering': 244,
#  'ask': 245,
#  'night': 246,
#  'ruining': 247,
#  'will': 248,
#  'forget': 249,
#  'completely': 250,
#  'wretched': 251,
#  'even': 252,
#  'shakespeare': 253,
#  'maybe': 254,
#  'heard': 255,
#  'him': 256,
#  'need': 257,
#  'tell': 258,
#  'act': 259,
#  'too': 260,
#  'totally': 261,
#  'hate': 262,
#  'sit': 263,
#  'susie': 264,
#  'care': 265,
#  'firm': 266,
#  'believer': 267,
#  'doing': 268,
#  'own': 269,
#  'reasons': 270,
#  'else': 271,
#  'told': 272,
#  'went': 273,
#  'month': 274,
#  'total': 275,
#  'babe': 276,
#  'now': 277,
#  'different': 278,
#  'story': 279,
#  'said': 280,
#  'everyone': 281,
#  'after': 282,
#  'swore': 283,
#  'anything': 284,
#  'since': 285,
#  'except': 286,
#  'display': 287,
#  'wanted': 288,
#  'let': 289,
#  'stupid': 290,
#  'enough': 291,
#  'repeat': 292,
#  'mistakes': 293,
#  'guess': 294,
#  'protecting': 295,
#  'keep': 296,
#  'locked': 297,
#  'away': 298,
#  'dark': 299,
#  'experience': 300,
#  'experiences': 301,
#  'trust': 302,
#  'people': 303,
#  'beautiful': 304,
#  'last': 305,
#  'set': 306,
#  'damage': 307,
#  'send': 308,
#  'therapy': 309,
#  'forever': 310,
#  'woman': 311,
#  'complete': 312,
#  'fruit': 313,
#  'loop': 314,
#  'patrick': 315,
#  'upset': 316,
#  'daddy': 317,
#  'boy': 318,
#  'starts': 319,
#  'end': 320,
#  'discussion': 321,
#  'neither': 322,
#  'sleep': 323,
#  'must': 324,
#  'were': 325,
#  'attempting': 326,
#  'small': 327,
#  'study': 328,
#  'group': 329,
#  'friends': 330,
#  'otherwise': 331,
#  'known': 332,
#  'expect': 333,
#  'starting': 334,
#  'wear': 335,
#  'belly': 336,
#  'before': 337,
#  'promise': 338,
#  'boys': 339,
#  'present': 340,
#  'discuss': 341,
#  'tomorrow': 342,
#  'has': 343,
#  'hot': 344,
#  'rod': 345,
#  'bend': 346,
#  'rules': 347,
#  'whatever': 348,
#  'missing': 349,
#  'pleasure': 350,
#  'fan': 351,
#  'pre': 352,
#  'button': 353,
#  'ring': 354,
#  'couple': 355,
#  'minors': 356,
#  'come': 357,
#  'girls': 358,
#  'tall': 359,
#  'decent': 360,
#  'body': 361,
#  'other': 362,
#  'kinda': 363,
#  'short': 364,
#  'new': 365,
#  'which': 366,
#  'dakota': 367,
#  'from': 368,
#  'north': 369,
#  'live': 370,
#  'by': 371,
#  'cows': 372,
#  'many': 373,
#  'old': 374,
#  'thirty': 375,
#  'two': 376,
#  'girl': 377,
#  'burn': 378,
#  'pine': 379,
#  'bred': 380,
#  'their': 381,
#  'mothers': 382,
#  'liked': 383,
#  'them': 384,
#  'gene': 385,
#  'pool': 386,
#  'rarely': 387,
#  'shit': 388,
#  'eating': 389,
#  'french': 390,
#  'mom': 391,
#  'canada': 392,
#  'signed': 393,
#  'chance': 394,
#  'minor': 395,
#  'encounter': 396,
#  'teach': 397,
#  'charm': 398,
#  'falls': 399,
#  'love': 400,
#  'makes': 401,
#  'seems': 402,
#  'danger': 403,
#  'criminal': 404,
#  'lit': 405,
#  'state': 406,
#  'fire': 407,
#  'serious': 408,
#  'man': 409,
#  'whacked': 410,
#  'sold': 411,
#  'his': 412,
#  'liver': 413,
#  'black': 414,
#  'market': 415,
#  'buy': 416,
#  'reputation': 417,
#  'strictly': 418,
#  'list': 419,
#  'side': 420,
#  'hated': 421,
#  'those': 422,
#  'involved': 423,
#  'golden': 424,
#  'opportunity': 425,
#  'case': 426,
#  'wide': 427,
#  'blow': 428,
#  'bent': 429,
#  'number': 430,
#  'hates': 431,
#  'lung': 432,
#  'cancer': 433,
#  'issue': 434,
#  'favorite': 435,
#  'uncle': 436,
#  'ears': 437,
#  'already': 438,
#  'extremely': 439,
#  'unfortunate': 440,
#  'maneuver': 441,
#  'hell': 442,
#  'picks': 443,
#  'carries': 444,
#  'while': 445,
#  'talking': 446,
#  'making': 447,
#  'progress': 448,
#  'humiliated': 449,
#  'sacrifice': 450,
#  'yourself': 451,
#  'dignity': 452,
#  'score': 453,
#  'non': 454,
#  'prison': 455,
#  'movie': 456,
#  'type': 457,
#  'food': 458,
#  'angry': 459,
#  'music': 460,
#  'rock': 461,
#  'busy': 462,
#  'thousand': 463,
#  'direct': 464,
#  'quote': 465,
#  'makin': 466,
#  'kissed': 467,
#  'worst': 468,
#  'over': 469,
#  'reading': 470,
#  'noticed': 471,
#  'big': 472,
#  'spread': 473,
#  'elbow': 474,
#  'tough': 475,
#  'ya': 476,
#  'leave': 477,
#  'alone': 478,
#  'legs': 479,
#  'rack': 480,
#  'money': 481,
#  'take': 482,
#  'verona': 483,
#  'pick': 484,
#  'tab': 485,
#  'pay': 486,
#  'some': 487,
#  'gets': 488,
#  'catch': 489,
#  'bucks': 490,
#  'negotiation': 491,
#  'fifty': 492,
#  'results': 493,
#  'watching': 494,
#  'bitch': 495,
#  'trash': 496,
#  'car': 497,
#  'count': 498,
#  'price': 499,
#  'hundred': 500,
#  'time': 501,
#  'limo': 502,
#  'flowers': 503,
#  'another': 504,
#  'lost': 505,
#  'nope': 506,
#  'came': 507,
#  'run': 508,
#  'idea': 509,
#  'interested': 510,
#  'insane': 511,
#  'purpose': 512,
#  'hear': 513,
#  'uh': 514,
#  'friend': 515,
#  'better': 516,
#  'fuck': 517,
#  'heavily': 518,
#  'invested': 519,
#  'random': 520,
#  'pat': 521,
#  'gone': 522,
#  'year': 523,
#  'porn': 524,
#  'movies': 525,
#  'incapable': 526,
#  'interesting': 527,
#  'eat': 528,
#  'starving': 529,
#  'very': 530,
#  'slow': 531,
#  'die': 532,
#  'realize': 533,
#  'men': 534,
#  'fine': 535,
#  'institution': 536,
#  'lacking': 537,
#  'killing': 538,
#  'william': 539,
#  'beyond': 540,
#  'scope': 541,
#  'teenage': 542,
#  'far': 543,
#  'past': 544,
#  'daytime': 545,
#  'show': 546,
#  'entering': 547,
#  'world': 548,
#  'expensive': 549,
#  'foul': 550,
#  'fit': 551,
#  'sarah': 552,
#  'lawrence': 553,
#  'insists': 554,
#  'male': 555,
#  'golf': 556,
#  'team': 557,
#  'proven': 558,
#  'appreciate': 559,
#  'efforts': 560,
#  'toward': 561,
#  'death': 562,
#  'matter': 563,
#  'work': 564,
#  'officially': 565,
#  'opposed': 566,
#  'social': 567,
#  'activity': 568,
#  'choice': 569,
#  'done': 570,
#  'favor': 571,
#  'imagine': 572,
#  'commercial': 573,
#  'dates': 574,
#  'sound': 575,
#  'betty': 576,
#  'pissed': 577,
#  'off': 578,
#  'archie': 579,
#  'taking': 580,
#  'veronica': 581,
#  'dress': 582,
#  'anyway': 583,
#  'looking': 584,
#  'wrong': 585,
#  'perspective': 586,
#  'statement': 587,
#  'seen': 588,
#  'asked': 589,
#  'meet': 590,
#  'sweating': 591,
#  'pig': 592,
#  'attention': 593,
#  'friday': 594,
#  'places': 595,
#  '7': 596,
#  'eleven': 597,
#  'warrant': 598,
#  'strong': 599,
#  'emotion': 600,
#  'spend': 601,
#  'dollar': 602,
#  'track': 603,
#  'flat': 604,
#  'beer': 605,
#  'eyes': 606,
#  'hand': 607,
#  'ass': 608,
#  'covered': 609,
#  'vomit': 610,
#  'following': 611,
#  'saw': 612,
#  'huh': 613,
#  'excuse': 614,
#  'these': 615,
#  'kill': 616,
#  'getting': 617,
#  'trashed': 618,
#  'lie': 619,
#  'down': 620,
#  'awhile': 621,
#  'use': 622,
#  'words': 623,
#  'needs': 624,
#  'affection': 625,
#  'blind': 626,
#  'hatred': 627,
#  'deal': 628,
#  'tequila': 629,
#  'seem': 630,
#  'don': 631,
#  't': 632,
#  'cool': 633,
#  'laid': 634,
#  'above': 635,
#  'wake': 636,
#  'control': 637,
#  'jail': 638,
#  'should': 639,
#  'band': 640,
#  'father': 641,
#  'approve': 642,
#  'dad': 643,
#  'pain': 644,
#  'wants': 645,
#  'feminine': 646,
#  'copy': 647,
#  'poetry': 648,
#  'still': 649,
#  'panties': 650,
#  'twist': 651,
#  'minute': 652,
#  'effect': 653,
#  'whatsoever': 654,
#  'left': 655,
#  'dickhead': 656,
#  'afraid': 657,
#  'heights': 658,
#  'mon': 659,
#  'bad': 660,
#  'put': 661,
#  'foot': 662,
#  'stayin': 663,
#  'climb': 664,
#  'family': 665,
#  'ridiculous': 666,
#  'win': 667,
#  'respect': 668,
#  'piss': 669,
#  'call': 670,
#  'soft': 671,
#  'knew': 672,
#  'acting': 673,
#  'yes': 674,
#  'disappointed': 675,
#  'disappoint': 676,
#  'screwed': 677,
#  'duck': 678,
#  'true': 679,
#  'knows': 680,
#  'sexy': 681,
#  'self': 682,
#  'assured': 683,
#  'anyone': 684,
#  'ever': 685,
#  'request': 686,
#  'command': 687,
#  'create': 688,
#  'drama': 689,
#  'rumor': 690,
#  'motive': 691,
#  'answer': 692,
#  'question': 693,
#  'convicted': 694,
#  'grandmother': 695,
#  'adorable': 696,
#  'wait': 697,
#  'paid': 698,
#  'person': 699,
#  'truly': 700,
#  'payment': 701,
#  'bonus': 702,
#  'sleeping': 703,
#  'bought': 704,
#  'besides': 705,
#  'cash': 706,
#  'asshole': 707,
#  'burger': 708,
#  'burnt': 709,
#  'object': 710,
#  'torture': 711,
#  'decided': 712,
#  '0': 713,
#  'whose': 714,
#  'diary': 715,
#  'devoted': 716,
#  'tips': 717,
#  'insurance': 718,
#  'cover': 719,
#  'pms': 720,
#  'agree': 721,
#  'decisions': 722,
#  'parent': 723,
#  'eighteen': 724,
#  'forty': 725,
#  'five': 726,
#  'full': 727,
#  'sperm': 728,
#  'understand': 729,
#  'hip': 730,
#  'dance': 731,
#  'parts': 732,
#  'beat': 733,
#  'fathers': 734,
#  'admit': 735,
#  'daughters': 736,
#  'capable': 737,
#  'running': 738,
#  'lives': 739,
#  'us': 740,
#  'play': 741,
#  'few': 742,
#  'years': 743,
#  'able': 744,
#  'watch': 745,
#  'game': 746,
#  'ms': 747,
#  'opinion': 748,
#  'terrorist': 749,
#  'action': 750,
#  'compared': 751,
#  'choices': 752,
#  'expression': 753,
#  'today': 754,
#  'events': 755,
#  'quite': 756,
#  'bobby': 757,
#  'retrieval': 758,
#  'operation': 759,
#  'maintain': 760,
#  'kicked': 761,
#  'himself': 762,
#  'balls': 763,
#  'merely': 764,
#  'am': 765,
#  'feel': 766,
#  'tired': 767,
#  'breathing': 768,
#  'pictures': 769,
#  'situation': 770,
#  'major': 771,
#  'jones': 772,
#  'speak': 773,
#  'pure': 774,
#  'than': 775,
#  'help': 776,
#  'wild': 777,
#  'beast': 778,
#  'telling': 779,
#  'prefer': 780,
#  'simply': 781,
#  'alternative': 782,
#  'law': 783,
#  'allows': 784,
#  'cozy': 785,
#  'thy': 786,
#  'force': 787,
#  'missed': 788,
#  'exposed': 789,
#  'lunch': 790,
#  'feeling': 791,
#  'touch': 792,
#  'flu': 793,
#  'driving': 794,
#  'slightly': 795,
#  'psychotic': 796,
#  'microwave': 797,
#  'jesus': 798,
#  'grab': 799,
#  'sandwich': 800,
#  'women': 801,
#  'rather': 802,
#  'pirate': 803,
#  'british': 804,
#  'rear': 805,
#  'admiral': 806,
#  'kiss': 807,
#  'honey': 808,
#  'happened': 809,
#  'absolutely': 810,
#  'heat': 811,
#  'las': 812,
#  'water': 813,
#  'barrels': 814,
#  'listening': 815,
#  'chicken': 816,
#  'ah': 817,
#  'harm': 818,
#  'devil': 819,
#  'child': 820,
#  'land': 821,
#  'three': 822,
#  'weeks': 823,
#  'ago': 824,
#  'near': 825,
#  'asia': 826,
#  'sailing': 827,
#  'west': 828,
#  'voyage': 829,
#  'six': 830,
#  'seven': 831,
#  'unfortunately': 832,
#  'colon': 833,
#  'precisely': 834,
#  'opinions': 835,
#  'familiar': 836,
#  'senor': 837,
#  'experienced': 838,
#  'captain': 839,
#  'concern': 840,
#  'crew': 841,
#  'willing': 842,
#  'conscience': 843,
#  'loss': 844,
#  'upon': 845,
#  'judgment': 846,
#  'settle': 847,
#  'journey': 848,
#  'risk': 849,
#  'prove': 850,
#  'possible': 851,
#  'others': 852,
#  'trade': 853,
#  'excellency': 854,
#  'according': 855,
#  'marco': 856,
#  'polo': 857,
#  'kingdom': 858,
#  'china': 859,
#  'richest': 860,
#  'buildings': 861,
#  'gold': 862,
#  'interests': 863,
#  'intended': 864,
#  'believe': 865,
#  'waited': 866,
#  'considered': 867,
#  'reason': 868,
#  'proposition': 869,
#  'ours': 870,
#  'try': 871,
#  'convince': 872,
#  'king': 873,
#  'absurd': 874,
#  'notions': 875,
#  'easy': 876,
#  'rid': 877,
#  'sanchez': 878,
#  'tragedy': 879,
#  'waste': 880,
#  'given': 881,
#  'marry': 882,
#  'leaving': 883,
#  'argue': 884,
#  'perhaps': 885,
#  'meant': 886,
#  'swear': 887,
#  'usually': 888,
#  'taken': 889,
#  'took': 890,
#  'everything': 891,
#  'stay': 892,
#  'soon': 893,
#  'islands': 894,
#  'forgive': 895,
#  'positions': 896,
#  'may': 897,
#  'whom': 898,
#  'de': 899,
#  'letters': 900,
#  'appointment': 901,
#  'sea': 902,
#  'hope': 903,
#  'mainland': 904,
#  'holy': 905,
#  'saints': 906,
#  'heaven': 907,
#  'explore': 908,
#  'asks': 909,
#  'visit': 910,
#  'address': 911,
#  'remember': 912,
#  'beginning': 913,
#  'yet': 914,
#  'remind': 915,
#  'position': 916,
#  'bargain': 917,
#  'ambitious': 918,
#  'ambition': 919,
#  'virtue': 920,
#  'among': 921,
#  'rest': 922,
#  'sin': 923,
#  'nature': 924,
#  'ending': 925,
#  'summer': 926,
#  'trees': 927,
#  'filled': 928,
#  'defend': 929,
#  'lack': 930,
#  'contact': 931,
#  'administration': 932,
#  'judge': 933,
#  'dear': 934,
#  'special': 935,
#  'talent': 936,
#  'guards': 937,
#  'nothing': 938,
#  'dreamer': 939,
#  'towers': 940,
#  'cuba': 941,
#  'tribe': 942,
#  'island': 943,
#  'first': 944,
#  'chief': 945,
#  'thank': 946,
#  'thousands': 947,
#  'bring': 948,
#  'also': 949,
#  'medicine': 950,
#  'peace': 951,
#  'understands': 952,
#  'diego': 953,
#  'bright': 954,
#  'brothers': 955,
#  'raised': 956,
#  'together': 957,
#  'manage': 958,
#  'wish': 959,
#  'sail': 960,
#  'certain': 961,
#  'ocean': 962,
#  'ignorance': 963,
#  'leagues': 964,
#  'canary': 965,
#  'jew': 966,
#  'dead': 967,
#  'passion': 968,
#  'carried': 969,
#  'being': 970,
#  'eternity': 971,
#  'give': 972,
#  'despair': 973,
#  'longer': 974,
#  'lies': 975,
#  'et': 976,
#  'son': 977,
#  'betrayed': 978,
#  'saying': 979,
#  'lied': 980,
#  'long': 981,
#  'follow': 982,
#  'frightening': 983,
#  'believed': 984,
#  'suppose': 985,
#  'both': 986,
#  'disagree': 987,
#  'worlds': 988,
#  'council': 989,
#  'tells': 990,
#  'honor': 991,
#  'fool': 992,
#  'ignore': 993,
#  'freely': 994,
#  'accept': 995,
#  'thinks': 996,
#  'thoughts': 997,
#  'without': 998,
#  'nor': 999,
#  ...}

# %% [markdown]
# These are some special tokens which is used in seq2seq:
#
# - `SOS` - Start of string which is the first token that should start in the decoding layers.
#
# - `EOS` - End of sentence. As soon as decoder generates this token we consider the answer to be complete (you can't use usual punctuation marks for this purpose cause their meaning can be different)
#
# - `UNK` - Unknown token. This is used to replace the rare words that did not fit in your vocabulary. So your sentence My name is guotong1988 will be translated into My name is _unk_.
#
# - `PAD` - Your GPU (or CPU at worst) processes your training data in batches and all the sequences in your batch should have the same length. If the max length of your sequence is 8, your sentence My name is guotong1988 will be padded from either side to fit this length: My name is guotong1988 _pad_ _pad_ _pad_ _pad_
#
# - `OUT` - Tokens by which all the words that were filtered out by our previous dictionaries will be replaced. We call it OUT as in filter out.

# %%
# Adding the special tokens to the previous two dictionaries
tokens = ["<PAD>", "<EOS>", "<OUT>", "<SOS>"]

for i_token in tokens:
    questionwords2int[i_token] = len(questionwords2int) + 1
    
for i_token in tokens:
    answerwords2int[i_token] = len(answerwords2int) + 1

# %%
# Create the inverse dictionary of answerwords2int
answerints2word = {i_index: i_word for i_word, i_index in answerwords2int.items()}

# %%
# Take a look at answerints2word
answerints2word
# Out:
# {0: 'can',
#  1: 'we',
#  2: 'make',
#  3: 'this',
#  4: 'quick',
#  5: 'and',
#  6: 'andrew',
#  7: 'barrett',
#  8: 'are',
#  9: 'having',
#  10: 'an',
#  11: 'incredibly',
#  12: 'public',
#  13: 'break',
#  14: 'up',
#  15: 'on',
#  16: 'the',
#  17: 'again',
#  18: 'well',
#  19: 'i',
#  20: 'thought',
#  21: 'would',
#  22: 'start',
#  23: 'with',
#  24: 'if',
#  25: 'that',
#  26: 'is',
#  27: 'okay',
#  28: 'you',
#  29: 'not',
#  30: 'part',
#  31: 'please',
#  32: 'asking',
#  33: 'me',
#  34: 'out',
#  35: 'so',
#  36: 'cute',
#  37: 'what',
#  38: 'your',
#  39: 'name',
#  40: 'no',
#  41: 'it',
#  42: 'my',
#  43: 'fault',
#  44: 'did',
#  45: 'have',
#  46: 'a',
#  47: 'proper',
#  48: 'introduction',
#  49: 'cameron',
#  50: 'thing',
#  51: 'm',
#  52: 'at',
#  53: 'mercy',
#  54: 'of',
#  55: 'particularly',
#  56: 'hideous',
#  57: 'breed',
#  58: 'loser',
#  59: 'sister',
#  60: 'cannot',
#  61: 'date',
#  62: 'until',
#  63: 'she',
#  64: 'does',
#  65: 'why',
#  66: 'mystery',
#  67: 'used',
#  68: 'to',
#  69: 'be',
#  70: 'really',
#  71: 'popular',
#  72: 'when',
#  73: 'started',
#  74: 'high',
#  75: 'school',
#  76: 'then',
#  77: 'was',
#  78: 'just',
#  79: 'like',
#  80: 'got',
#  81: 'sick',
#  82: 'or',
#  83: 'something',
#  84: 'gosh',
#  85: 'only',
#  86: 'could',
#  87: 'find',
#  88: 'kat',
#  89: 'boyfriend',
#  90: 'c',
#  91: 'ma',
#  92: 'head',
#  93: 'right',
#  94: 'see',
#  95: 'ready',
#  96: 'for',
#  97: 'do',
#  98: 'want',
#  99: 'know',
#  100: 'how',
#  101: 'say',
#  102: 'though',
#  103: 'useful',
#  104: 'things',
#  105: 'where',
#  106: 'good',
#  107: 'stores',
#  108: 'much',
#  109: 'champagne',
#  110: 'cost',
#  111: 'stuff',
#  112: 'chat',
#  113: 'never',
#  114: 'in',
#  115: 'life',
#  116: 'had',
#  117: 'point',
#  118: 'someone',
#  119: 'because',
#  120: 'such',
#  121: 'nice',
#  122: 'one',
#  123: 'our',
#  124: 'little',
#  125: 'plan',
#  126: 'there',
#  127: 'mind',
#  128: 'word',
#  129: 'as',
#  130: 'gentleman',
#  131: 'get',
#  132: 'hair',
#  133: 'look',
#  134: 'sure',
#  135: 'go',
#  136: 'but',
#  137: 'unless',
#  138: 'goes',
#  139: 'lesbian',
#  140: 'found',
#  141: 'picture',
#  142: 'her',
#  143: 'pretty',
#  144: 'same',
#  145: 'sex',
#  146: 'kind',
#  147: 'guy',
#  148: 'likes',
#  149: 'ones',
#  150: 'hi',
#  151: 'fun',
#  152: 'tonight',
#  153: 'looked',
#  154: 'back',
#  155: 'party',
#  156: 'always',
#  157: 'seemed',
#  158: 'occupied',
#  159: 'all',
#  160: 'says',
#  161: 'any',
#  162: 'lighter',
#  163: 'going',
#  164: 'extra',
#  165: 'listen',
#  166: 'crap',
#  167: 'endless',
#  168: 'blonde',
#  169: 'boring',
#  170: 'myself',
#  171: 'figured',
#  172: 'eventually',
#  173: 'real',
#  174: 'kidding',
#  175: 'sometimes',
#  176: 'become',
#  177: 'quit',
#  178: 'wow',
#  179: 'they',
#  180: 'change',
#  181: 'he',
#  182: 'here',
#  183: 'who',
#  184: 'great',
#  185: 'practically',
#  186: 'proposed',
#  187: 'mean',
#  188: 'dr',
#  189: 'exactly',
#  190: 'relevant',
#  191: 'conversation',
#  192: 'dry',
#  193: 'bianca',
#  194: 'think',
#  195: 'dating',
#  196: 'joey',
#  197: 'include',
#  198: 'door',
#  199: 'opening',
#  200: 'coat',
#  201: 'holding',
#  202: 'wonder',
#  203: 'guys',
#  204: 'supposed',
#  205: 'actually',
#  206: 'home',
#  207: 'twenty',
#  208: 'minutes',
#  209: 're',
#  210: 'prom',
#  211: 'more',
#  212: 's',
#  213: 'saturday',
#  214: 'yeah',
#  215: 've',
#  216: 'tube',
#  217: 'sock',
#  218: 'gig',
#  219: 'huge',
#  220: 'ad',
#  221: 'queen',
#  222: 'harry',
#  223: 'next',
#  224: 'week',
#  225: 'neat',
#  226: 'hey',
#  227: 'sweet',
#  228: 'cheeks',
#  229: 'talk',
#  230: 'about',
#  231: 'been',
#  232: 'potential',
#  233: 'smack',
#  234: 'way',
#  235: 'oh',
#  236: 'god',
#  237: 'becoming',
#  238: 'normal',
#  239: 'means',
#  240: 'playing',
#  241: 'club',
#  242: 'skunk',
#  243: 'might',
#  244: 'bothering',
#  245: 'ask',
#  246: 'night',
#  247: 'ruining',
#  248: 'will',
#  249: 'forget',
#  250: 'completely',
#  251: 'wretched',
#  252: 'even',
#  253: 'shakespeare',
#  254: 'maybe',
#  255: 'heard',
#  256: 'him',
#  257: 'need',
#  258: 'tell',
#  259: 'act',
#  260: 'too',
#  261: 'totally',
#  262: 'hate',
#  263: 'sit',
#  264: 'susie',
#  265: 'care',
#  266: 'firm',
#  267: 'believer',
#  268: 'doing',
#  269: 'own',
#  270: 'reasons',
#  271: 'else',
#  272: 'told',
#  273: 'went',
#  274: 'month',
#  275: 'total',
#  276: 'babe',
#  277: 'now',
#  278: 'different',
#  279: 'story',
#  280: 'said',
#  281: 'everyone',
#  282: 'after',
#  283: 'swore',
#  284: 'anything',
#  285: 'since',
#  286: 'except',
#  287: 'display',
#  288: 'wanted',
#  289: 'let',
#  290: 'stupid',
#  291: 'enough',
#  292: 'repeat',
#  293: 'mistakes',
#  294: 'guess',
#  295: 'protecting',
#  296: 'keep',
#  297: 'locked',
#  298: 'away',
#  299: 'dark',
#  300: 'experience',
#  301: 'experiences',
#  302: 'trust',
#  303: 'people',
#  304: 'beautiful',
#  305: 'last',
#  306: 'set',
#  307: 'damage',
#  308: 'send',
#  309: 'therapy',
#  310: 'forever',
#  311: 'woman',
#  312: 'complete',
#  313: 'fruit',
#  314: 'loop',
#  315: 'patrick',
#  316: 'upset',
#  317: 'daddy',
#  318: 'boy',
#  319: 'starts',
#  320: 'end',
#  321: 'discussion',
#  322: 'neither',
#  323: 'sleep',
#  324: 'must',
#  325: 'were',
#  326: 'attempting',
#  327: 'small',
#  328: 'study',
#  329: 'group',
#  330: 'friends',
#  331: 'otherwise',
#  332: 'known',
#  333: 'expect',
#  334: 'starting',
#  335: 'wear',
#  336: 'belly',
#  337: 'before',
#  338: 'promise',
#  339: 'boys',
#  340: 'present',
#  341: 'discuss',
#  342: 'tomorrow',
#  343: 'has',
#  344: 'hot',
#  345: 'rod',
#  346: 'bend',
#  347: 'rules',
#  348: 'whatever',
#  349: 'missing',
#  350: 'pleasure',
#  351: 'fan',
#  352: 'pre',
#  353: 'button',
#  354: 'ring',
#  355: 'couple',
#  356: 'minors',
#  357: 'come',
#  358: 'girls',
#  359: 'tall',
#  360: 'decent',
#  361: 'body',
#  362: 'other',
#  363: 'kinda',
#  364: 'short',
#  365: 'new',
#  366: 'which',
#  367: 'dakota',
#  368: 'from',
#  369: 'north',
#  370: 'live',
#  371: 'by',
#  372: 'cows',
#  373: 'many',
#  374: 'old',
#  375: 'thirty',
#  376: 'two',
#  377: 'girl',
#  378: 'burn',
#  379: 'pine',
#  380: 'bred',
#  381: 'their',
#  382: 'mothers',
#  383: 'liked',
#  384: 'them',
#  385: 'gene',
#  386: 'pool',
#  387: 'rarely',
#  388: 'shit',
#  389: 'eating',
#  390: 'french',
#  391: 'mom',
#  392: 'canada',
#  393: 'signed',
#  394: 'chance',
#  395: 'minor',
#  396: 'encounter',
#  397: 'teach',
#  398: 'charm',
#  399: 'falls',
#  400: 'love',
#  401: 'makes',
#  402: 'seems',
#  403: 'danger',
#  404: 'criminal',
#  405: 'lit',
#  406: 'state',
#  407: 'fire',
#  408: 'serious',
#  409: 'man',
#  410: 'whacked',
#  411: 'sold',
#  412: 'his',
#  413: 'liver',
#  414: 'black',
#  415: 'market',
#  416: 'buy',
#  417: 'reputation',
#  418: 'strictly',
#  419: 'list',
#  420: 'side',
#  421: 'hated',
#  422: 'those',
#  423: 'involved',
#  424: 'golden',
#  425: 'opportunity',
#  426: 'case',
#  427: 'wide',
#  428: 'blow',
#  429: 'bent',
#  430: 'number',
#  431: 'hates',
#  432: 'lung',
#  433: 'cancer',
#  434: 'issue',
#  435: 'favorite',
#  436: 'uncle',
#  437: 'ears',
#  438: 'already',
#  439: 'extremely',
#  440: 'unfortunate',
#  441: 'maneuver',
#  442: 'hell',
#  443: 'picks',
#  444: 'carries',
#  445: 'while',
#  446: 'talking',
#  447: 'making',
#  448: 'progress',
#  449: 'humiliated',
#  450: 'sacrifice',
#  451: 'yourself',
#  452: 'dignity',
#  453: 'score',
#  454: 'non',
#  455: 'prison',
#  456: 'movie',
#  457: 'type',
#  458: 'food',
#  459: 'angry',
#  460: 'music',
#  461: 'rock',
#  462: 'busy',
#  463: 'thousand',
#  464: 'direct',
#  465: 'quote',
#  466: 'makin',
#  467: 'kissed',
#  468: 'worst',
#  469: 'over',
#  470: 'reading',
#  471: 'noticed',
#  472: 'big',
#  473: 'spread',
#  474: 'elbow',
#  475: 'tough',
#  476: 'ya',
#  477: 'leave',
#  478: 'alone',
#  479: 'legs',
#  480: 'rack',
#  481: 'money',
#  482: 'take',
#  483: 'verona',
#  484: 'pick',
#  485: 'tab',
#  486: 'pay',
#  487: 'some',
#  488: 'gets',
#  489: 'catch',
#  490: 'bucks',
#  491: 'negotiation',
#  492: 'fifty',
#  493: 'results',
#  494: 'watching',
#  495: 'bitch',
#  496: 'trash',
#  497: 'car',
#  498: 'count',
#  499: 'price',
#  500: 'hundred',
#  501: 'time',
#  502: 'limo',
#  503: 'flowers',
#  504: 'another',
#  505: 'lost',
#  506: 'nope',
#  507: 'came',
#  508: 'run',
#  509: 'idea',
#  510: 'interested',
#  511: 'insane',
#  512: 'purpose',
#  513: 'hear',
#  514: 'uh',
#  515: 'friend',
#  516: 'better',
#  517: 'fuck',
#  518: 'heavily',
#  519: 'invested',
#  520: 'random',
#  521: 'pat',
#  522: 'gone',
#  523: 'year',
#  524: 'porn',
#  525: 'movies',
#  526: 'incapable',
#  527: 'interesting',
#  528: 'eat',
#  529: 'starving',
#  530: 'very',
#  531: 'slow',
#  532: 'die',
#  533: 'realize',
#  534: 'men',
#  535: 'fine',
#  536: 'institution',
#  537: 'lacking',
#  538: 'killing',
#  539: 'william',
#  540: 'beyond',
#  541: 'scope',
#  542: 'teenage',
#  543: 'far',
#  544: 'past',
#  545: 'daytime',
#  546: 'show',
#  547: 'entering',
#  548: 'world',
#  549: 'expensive',
#  550: 'foul',
#  551: 'fit',
#  552: 'sarah',
#  553: 'lawrence',
#  554: 'insists',
#  555: 'male',
#  556: 'golf',
#  557: 'team',
#  558: 'proven',
#  559: 'appreciate',
#  560: 'efforts',
#  561: 'toward',
#  562: 'death',
#  563: 'matter',
#  564: 'work',
#  565: 'officially',
#  566: 'opposed',
#  567: 'social',
#  568: 'activity',
#  569: 'choice',
#  570: 'done',
#  571: 'favor',
#  572: 'imagine',
#  573: 'commercial',
#  574: 'dates',
#  575: 'sound',
#  576: 'betty',
#  577: 'pissed',
#  578: 'off',
#  579: 'archie',
#  580: 'taking',
#  581: 'veronica',
#  582: 'dress',
#  583: 'anyway',
#  584: 'looking',
#  585: 'wrong',
#  586: 'perspective',
#  587: 'statement',
#  588: 'seen',
#  589: 'asked',
#  590: 'meet',
#  591: 'sweating',
#  592: 'pig',
#  593: 'attention',
#  594: 'friday',
#  595: 'places',
#  596: '7',
#  597: 'eleven',
#  598: 'warrant',
#  599: 'strong',
#  600: 'emotion',
#  601: 'spend',
#  602: 'dollar',
#  603: 'track',
#  604: 'flat',
#  605: 'beer',
#  606: 'eyes',
#  607: 'hand',
#  608: 'ass',
#  609: 'covered',
#  610: 'vomit',
#  611: 'following',
#  612: 'saw',
#  613: 'huh',
#  614: 'excuse',
#  615: 'these',
#  616: 'kill',
#  617: 'getting',
#  618: 'trashed',
#  619: 'lie',
#  620: 'down',
#  621: 'awhile',
#  622: 'use',
#  623: 'words',
#  624: 'needs',
#  625: 'affection',
#  626: 'blind',
#  627: 'hatred',
#  628: 'deal',
#  629: 'tequila',
#  630: 'seem',
#  631: 'don',
#  632: 't',
#  633: 'cool',
#  634: 'laid',
#  635: 'above',
#  636: 'wake',
#  637: 'control',
#  638: 'jail',
#  639: 'should',
#  640: 'band',
#  641: 'father',
#  642: 'approve',
#  643: 'dad',
#  644: 'pain',
#  645: 'wants',
#  646: 'feminine',
#  647: 'copy',
#  648: 'poetry',
#  649: 'still',
#  650: 'panties',
#  651: 'twist',
#  652: 'minute',
#  653: 'effect',
#  654: 'whatsoever',
#  655: 'left',
#  656: 'dickhead',
#  657: 'afraid',
#  658: 'heights',
#  659: 'mon',
#  660: 'bad',
#  661: 'put',
#  662: 'foot',
#  663: 'stayin',
#  664: 'climb',
#  665: 'family',
#  666: 'ridiculous',
#  667: 'win',
#  668: 'respect',
#  669: 'piss',
#  670: 'call',
#  671: 'soft',
#  672: 'knew',
#  673: 'acting',
#  674: 'yes',
#  675: 'disappointed',
#  676: 'disappoint',
#  677: 'screwed',
#  678: 'duck',
#  679: 'true',
#  680: 'knows',
#  681: 'sexy',
#  682: 'self',
#  683: 'assured',
#  684: 'anyone',
#  685: 'ever',
#  686: 'request',
#  687: 'command',
#  688: 'create',
#  689: 'drama',
#  690: 'rumor',
#  691: 'motive',
#  692: 'answer',
#  693: 'question',
#  694: 'convicted',
#  695: 'grandmother',
#  696: 'adorable',
#  697: 'wait',
#  698: 'paid',
#  699: 'person',
#  700: 'truly',
#  701: 'payment',
#  702: 'bonus',
#  703: 'sleeping',
#  704: 'bought',
#  705: 'besides',
#  706: 'cash',
#  707: 'asshole',
#  708: 'burger',
#  709: 'burnt',
#  710: 'object',
#  711: 'torture',
#  712: 'decided',
#  713: '0',
#  714: 'whose',
#  715: 'diary',
#  716: 'devoted',
#  717: 'tips',
#  718: 'insurance',
#  719: 'cover',
#  720: 'pms',
#  721: 'agree',
#  722: 'decisions',
#  723: 'parent',
#  724: 'eighteen',
#  725: 'forty',
#  726: 'five',
#  727: 'full',
#  728: 'sperm',
#  729: 'understand',
#  730: 'hip',
#  731: 'dance',
#  732: 'parts',
#  733: 'beat',
#  734: 'fathers',
#  735: 'admit',
#  736: 'daughters',
#  737: 'capable',
#  738: 'running',
#  739: 'lives',
#  740: 'us',
#  741: 'play',
#  742: 'few',
#  743: 'years',
#  744: 'able',
#  745: 'watch',
#  746: 'game',
#  747: 'ms',
#  748: 'opinion',
#  749: 'terrorist',
#  750: 'action',
#  751: 'compared',
#  752: 'choices',
#  753: 'expression',
#  754: 'today',
#  755: 'events',
#  756: 'quite',
#  757: 'bobby',
#  758: 'retrieval',
#  759: 'operation',
#  760: 'maintain',
#  761: 'kicked',
#  762: 'himself',
#  763: 'balls',
#  764: 'merely',
#  765: 'am',
#  766: 'feel',
#  767: 'tired',
#  768: 'breathing',
#  769: 'pictures',
#  770: 'situation',
#  771: 'major',
#  772: 'jones',
#  773: 'speak',
#  774: 'pure',
#  775: 'than',
#  776: 'help',
#  777: 'wild',
#  778: 'beast',
#  779: 'telling',
#  780: 'prefer',
#  781: 'simply',
#  782: 'alternative',
#  783: 'law',
#  784: 'allows',
#  785: 'cozy',
#  786: 'thy',
#  787: 'force',
#  788: 'missed',
#  789: 'exposed',
#  790: 'lunch',
#  791: 'feeling',
#  792: 'touch',
#  793: 'flu',
#  794: 'driving',
#  795: 'slightly',
#  796: 'psychotic',
#  797: 'microwave',
#  798: 'jesus',
#  799: 'grab',
#  800: 'sandwich',
#  801: 'women',
#  802: 'rather',
#  803: 'pirate',
#  804: 'british',
#  805: 'rear',
#  806: 'admiral',
#  807: 'kiss',
#  808: 'honey',
#  809: 'happened',
#  810: 'absolutely',
#  811: 'heat',
#  812: 'las',
#  813: 'water',
#  814: 'barrels',
#  815: 'listening',
#  816: 'chicken',
#  817: 'ah',
#  818: 'harm',
#  819: 'devil',
#  820: 'child',
#  821: 'land',
#  822: 'three',
#  823: 'weeks',
#  824: 'ago',
#  825: 'near',
#  826: 'asia',
#  827: 'sailing',
#  828: 'west',
#  829: 'voyage',
#  830: 'six',
#  831: 'seven',
#  832: 'unfortunately',
#  833: 'colon',
#  834: 'precisely',
#  835: 'opinions',
#  836: 'familiar',
#  837: 'senor',
#  838: 'experienced',
#  839: 'captain',
#  840: 'concern',
#  841: 'crew',
#  842: 'willing',
#  843: 'conscience',
#  844: 'loss',
#  845: 'upon',
#  846: 'judgment',
#  847: 'settle',
#  848: 'journey',
#  849: 'risk',
#  850: 'prove',
#  851: 'possible',
#  852: 'others',
#  853: 'trade',
#  854: 'excellency',
#  855: 'according',
#  856: 'marco',
#  857: 'polo',
#  858: 'kingdom',
#  859: 'china',
#  860: 'richest',
#  861: 'buildings',
#  862: 'gold',
#  863: 'interests',
#  864: 'intended',
#  865: 'believe',
#  866: 'waited',
#  867: 'considered',
#  868: 'reason',
#  869: 'proposition',
#  870: 'ours',
#  871: 'try',
#  872: 'convince',
#  873: 'king',
#  874: 'absurd',
#  875: 'notions',
#  876: 'easy',
#  877: 'rid',
#  878: 'sanchez',
#  879: 'tragedy',
#  880: 'waste',
#  881: 'given',
#  882: 'marry',
#  883: 'leaving',
#  884: 'argue',
#  885: 'perhaps',
#  886: 'meant',
#  887: 'swear',
#  888: 'usually',
#  889: 'taken',
#  890: 'took',
#  891: 'everything',
#  892: 'stay',
#  893: 'soon',
#  894: 'islands',
#  895: 'forgive',
#  896: 'positions',
#  897: 'may',
#  898: 'whom',
#  899: 'de',
#  900: 'letters',
#  901: 'appointment',
#  902: 'sea',
#  903: 'hope',
#  904: 'mainland',
#  905: 'holy',
#  906: 'saints',
#  907: 'heaven',
#  908: 'explore',
#  909: 'asks',
#  910: 'visit',
#  911: 'address',
#  912: 'remember',
#  913: 'beginning',
#  914: 'yet',
#  915: 'remind',
#  916: 'position',
#  917: 'bargain',
#  918: 'ambitious',
#  919: 'ambition',
#  920: 'virtue',
#  921: 'among',
#  922: 'rest',
#  923: 'sin',
#  924: 'nature',
#  925: 'ending',
#  926: 'summer',
#  927: 'trees',
#  928: 'filled',
#  929: 'defend',
#  930: 'lack',
#  931: 'contact',
#  932: 'administration',
#  933: 'judge',
#  934: 'dear',
#  935: 'special',
#  936: 'talent',
#  937: 'guards',
#  938: 'nothing',
#  939: 'dreamer',
#  940: 'towers',
#  941: 'cuba',
#  942: 'tribe',
#  943: 'island',
#  944: 'first',
#  945: 'chief',
#  946: 'thank',
#  947: 'thousands',
#  948: 'bring',
#  949: 'also',
#  950: 'medicine',
#  951: 'peace',
#  952: 'understands',
#  953: 'diego',
#  954: 'bright',
#  955: 'brothers',
#  956: 'raised',
#  957: 'together',
#  958: 'manage',
#  959: 'wish',
#  960: 'sail',
#  961: 'certain',
#  962: 'ocean',
#  963: 'ignorance',
#  964: 'leagues',
#  965: 'canary',
#  966: 'jew',
#  967: 'dead',
#  968: 'passion',
#  969: 'carried',
#  970: 'being',
#  971: 'eternity',
#  972: 'give',
#  973: 'despair',
#  974: 'longer',
#  975: 'lies',
#  976: 'et',
#  977: 'son',
#  978: 'betrayed',
#  979: 'saying',
#  980: 'lied',
#  981: 'long',
#  982: 'follow',
#  983: 'frightening',
#  984: 'believed',
#  985: 'suppose',
#  986: 'both',
#  987: 'disagree',
#  988: 'worlds',
#  989: 'council',
#  990: 'tells',
#  991: 'honor',
#  992: 'fool',
#  993: 'ignore',
#  994: 'freely',
#  995: 'accept',
#  996: 'thinks',
#  997: 'thoughts',
#  998: 'without',
#  999: 'nor',
#  ...}

# %%
# Add <EOS> to the end of each answers;  <EOS> is used for decoding part of our seq2seq which we start the process of decoding after recieving <EOS>
for index in range(len(answers_preprocessed)):
    answers_preprocessed[index] += " <EOS>"

# %%
# Take a look at answers_preprocessed
answers_preprocessed[:5]
# Out:
# ['well  i thought we would start with pronunciation  if that is okay with you  <EOS>',
#  'not the hacking and gagging and spitting part   please  <EOS>',
#  'okay    then how  bout we try out some french cuisine   saturday   night  <EOS>',
#  'forget it  <EOS>',
#  'cameron  <EOS>']

# %%
# Translate all the questions & answers into integer
# And replace all the words that were filtered out by <OUT>
questions_to_int = []
for i_question in tqdm(questions_preprocessed):
    ints = []
    for i_word in i_question.split():
        if i_word not in questionwords2int:
            ints.append(questionwords2int["<OUT>"])
        else:
            ints.append(questionwords2int[i_word])
    questions_to_int.append(ints)
            
answers_to_int = []
for i_answer in tqdm(answers_preprocessed):
    ints = []
    for i_word in i_answer.split():
        if i_word not in answerwords2int:
            ints.append(answerwords2int["<OUT>"])
        else:
            ints.append(answerwords2int[i_word])
    answers_to_int.append(ints)
# Out:
# 100%|██████████| 221616/221616 [00:02<00:00, 91214.64it/s]
# 100%|██████████| 221616/221616 [00:02<00:00, 92291.36it/s]

# %%
# Take a look at questions_to_int
questions_to_int[:5]
# Out:
# [[0,
#   1,
#   2,
#   3,
#   4,
#   8795,
#   8795,
#   5,
#   6,
#   7,
#   8,
#   9,
#   10,
#   11,
#   8795,
#   12,
#   13,
#   14,
#   15,
#   16,
#   8795,
#   17],
#  [18, 19, 20, 1, 21, 22, 23, 8795, 24, 25, 26, 27, 23, 28],
#  [29, 16, 8795, 5, 8795, 5, 8795, 30, 31],
#  [28, 8, 32, 33, 34, 25, 26, 35, 36, 37, 26, 38, 39, 17],
#  [40, 40, 41, 26, 42, 43, 1, 44, 29, 45, 46, 47, 48]]

# %%
# Take a look at answers_to_int
answers_to_int[:5]
# Out:
# [[18, 19, 20, 1, 21, 22, 23, 8795, 24, 25, 26, 27, 23, 28, 8794],
#  [29, 16, 8795, 5, 8795, 5, 8795, 30, 31, 8794],
#  [27, 76, 100, 1509, 1, 871, 34, 487, 390, 8795, 213, 246, 8794],
#  [249, 41, 8794],
#  [49, 8794]]

# %%
# Sort the questions & answers by the length of questions
# And remove the long texts (longer than 25 words)
sorted_clean_questions = []
sorted_clean_answers = []

for i_length in range(1, 25 + 1):
    for i in enumerate(questions_to_int):
        if len(i[1]) == i_length:
            sorted_clean_questions.append(questions_to_int[i[0]])
            sorted_clean_answers.append(answers_to_int[i[0]])

# %%
# Take a look at sorted_clean_questions; At start the lenfth is 1 and it get larger at the end
sorted_clean_questions
# Out:
# [[49],
#  [65],
#  [126],
#  [150],
#  [136],
#  [40],
#  [178],
#  [40],
#  [183],
#  [184],
#  [225],
#  [37],
#  [65],
#  [136],
#  [65],
#  [113],
#  [134],
#  [298],
#  [214],
#  [37],
#  [226],
#  [183],
#  [27],
#  [65],
#  [183],
#  [8795],
#  [462],
#  [254],
#  [183],
#  [193],
#  [8795],
#  [8795],
#  [674],
#  [100],
#  [8795],
#  [8795],
#  [37],
#  [40],
#  [37],
#  [8795],
#  [150],
#  [93],
#  [37],
#  [37],
#  [8795],
#  [641],
#  [40],
#  [40],
#  [947],
#  [833],
#  [1116],
#  [40],
#  [235],
#  [72],
#  [214],
#  [40],
#  [143],
#  [1250],
#  [214],
#  [1108],
#  [1108],
#  [1108],
#  [1108],
#  [214],
#  [338],
#  [152],
#  [27],
#  [95],
#  [674],
#  [37],
#  [1134],
#  [1244],
#  [1483],
#  [1062],
#  [1489],
#  [214],
#  [1528],
#  [37],
#  [37],
#  [214],
#  [1576],
#  [1576],
#  [1576],
#  [1576],
#  [1576],
#  [1576],
#  [27],
#  [674],
#  [70],
#  [674],
#  [235],
#  [100],
#  [1606],
#  [1576],
#  [1576],
#  [1576],
#  [8795],
#  [1576],
#  [1576],
#  [70],
#  [1644],
#  [679],
#  [1766],
#  [214],
#  [39],
#  [214],
#  [1210],
#  [214],
#  [1328],
#  [214],
#  [18],
#  [126],
#  [37],
#  [65],
#  [1815],
#  [1746],
#  [214],
#  [1823],
#  [214],
#  [214],
#  [1796],
#  [226],
#  [1142],
#  [72],
#  [183],
#  [214],
#  [1796],
#  [1794],
#  [1796],
#  [214],
#  [1796],
#  [91],
#  [150],
#  [388],
#  [8795],
#  [2071],
#  [8795],
#  [400],
#  [8795],
#  [8795],
#  [514],
#  [189],
#  [514],
#  [1746],
#  [2100],
#  [8795],
#  [1490],
#  [1796],
#  [2266],
#  [37],
#  [2272],
#  [1328],
#  [8795],
#  [2292],
#  [2296],
#  [1135],
#  [1138],
#  [37],
#  [214],
#  [65],
#  [1518],
#  [1796],
#  [2488],
#  [2505],
#  [40],
#  [27],
#  [1796],
#  [27],
#  [1796],
#  [674],
#  [40],
#  [40],
#  [674],
#  [40],
#  [37],
#  [1796],
#  [40],
#  [37],
#  [40],
#  [35],
#  [37],
#  [1677],
#  [643],
#  [8795],
#  [2604],
#  [2604],
#  [37],
#  [183],
#  [214],
#  [610],
#  [2670],
#  [674],
#  [8795],
#  [613],
#  [35],
#  [8795],
#  [740],
#  [214],
#  [18],
#  [1578],
#  [1500],
#  [284],
#  [613],
#  [37],
#  [2796],
#  [65],
#  [2800],
#  [183],
#  [183],
#  [40],
#  [674],
#  [235],
#  [214],
#  [2874],
#  [214],
#  [235],
#  [70],
#  [2297],
#  [214],
#  [214],
#  [37],
#  [214],
#  [8795],
#  [214],
#  [40],
#  [674],
#  [674],
#  [674],
#  [674],
#  [643],
#  [2916],
#  [40],
#  [938],
#  [27],
#  [613],
#  [613],
#  [35],
#  [254],
#  [2932],
#  [214],
#  [214],
#  [481],
#  [1607],
#  [100],
#  [0],
#  [37],
#  [8795],
#  [1823],
#  [8795],
#  [938],
#  [703],
#  [214],
#  [214],
#  [2982],
#  [2986],
#  [8795],
#  [2811],
#  [183],
#  [2818],
#  [613],
#  [183],
#  [481],
#  [214],
#  [2604],
#  [391],
#  [2604],
#  [317],
#  [65],
#  [967],
#  [2148],
#  [100],
#  [674],
#  [40],
#  [1410],
#  [3121],
#  [1347],
#  [37],
#  [122],
#  [136],
#  [8795],
#  [388],
#  [37],
#  [8795],
#  [8795],
#  [1023],
#  [2015],
#  [3178],
#  [2015],
#  [1439],
#  [2015],
#  [2015],
#  [1439],
#  [306],
#  [277],
#  [3182],
#  [254],
#  [1766],
#  [3220],
#  [3220],
#  [8795],
#  [134],
#  [214],
#  [37],
#  [674],
#  [8795],
#  [40],
#  [2015],
#  [1439],
#  [2859],
#  [1439],
#  [674],
#  [8795],
#  [150],
#  [674],
#  [1766],
#  [1766],
#  [674],
#  [674],
#  [182],
#  [674],
#  [938],
#  [938],
#  [65],
#  [388],
#  [214],
#  [37],
#  [3038],
#  [916],
#  [37],
#  [3496],
#  [2251],
#  [35],
#  [1023],
#  [1033],
#  [297],
#  [3548],
#  [1746],
#  [2504],
#  [522],
#  [3587],
#  [8795],
#  [674],
#  [40],
#  [105],
#  [235],
#  [65],
#  [37],
#  [37],
#  [37],
#  [2112],
#  [1023],
#  [449],
#  [105],
#  [277],
#  [674],
#  [65],
#  [105],
#  [40],
#  [37],
#  [528],
#  [674],
#  [674],
#  [40],
#  [674],
#  [3626],
#  [8795],
#  [3626],
#  [37],
#  [854],
#  [70],
#  [8795],
#  [152],
#  [478],
#  [37],
#  [3652],
#  [226],
#  [3652],
#  [3366],
#  [8795],
#  [8795],
#  [70],
#  [674],
#  [3663],
#  [70],
#  [674],
#  [1053],
#  [3673],
#  [674],
#  [674],
#  [3631],
#  [641],
#  [105],
#  [674],
#  [37],
#  [8795],
#  [18],
#  [3729],
#  [3680],
#  [3626],
#  [37],
#  [674],
#  [40],
#  [3131],
#  [70],
#  [817],
#  [674],
#  [37],
#  [183],
#  [37],
#  [1607],
#  [674],
#  [674],
#  [674],
#  [674],
#  [189],
#  [3593],
#  [3593],
#  [3593],
#  [35],
#  [105],
#  [18],
#  [37],
#  [674],
#  [674],
#  [189],
#  [674],
#  [105],
#  [3836],
#  [8795],
#  [674],
#  [674],
#  [3184],
#  [37],
#  [674],
#  [37],
#  [1936],
#  [1692],
#  [1461],
#  [1680],
#  [3862],
#  [674],
#  [284],
#  [27],
#  [136],
#  [37],
#  [40],
#  [40],
#  [40],
#  [40],
#  [40],
#  [40],
#  [40],
#  [3862],
#  [3858],
#  [674],
#  [674],
#  [1823],
#  [3184],
#  [27],
#  [1796],
#  [93],
#  [214],
#  [8795],
#  [125],
#  [1823],
#  [214],
#  [3184],
#  [37],
#  [37],
#  [3245],
#  [3245],
#  [674],
#  [1796],
#  [674],
#  [40],
#  [235],
#  [1135],
#  [3326],
#  [214],
#  [214],
#  [3994],
#  [235],
#  [1746],
#  [33],
#  [1949],
#  [18],
#  [40],
#  [37],
#  [277],
#  [674],
#  [18],
#  [974],
#  [235],
#  [674],
#  [674],
#  [3995],
#  [674],
#  [810],
#  [40],
#  [65],
#  [674],
#  [40],
#  [674],
#  [18],
#  [613],
#  [674],
#  [100],
#  [887],
#  [2970],
#  [506],
#  [1355],
#  [226],
#  [37],
#  [37],
#  [100],
#  [1135],
#  [2863],
#  [304],
#  [3241],
#  [18],
#  [8795],
#  [4114],
#  [37],
#  [35],
#  [339],
#  [214],
#  [8795],
#  [4138],
#  [37],
#  [2863],
#  [8795],
#  [2297],
#  [37],
#  [4196],
#  [2874],
#  [674],
#  [1746],
#  [70],
#  [70],
#  [70],
#  [106],
#  [4055],
#  [1023],
#  [25],
#  [4248],
#  [674],
#  [121],
#  [2091],
#  [674],
#  [65],
#  [315],
#  [674],
#  [70],
#  [4271],
#  [315],
#  [37],
#  [8795],
#  [1395],
#  [72],
#  [674],
#  [315],
#  [183],
#  [315],
#  [2054],
#  [527],
#  [1135],
#  [65],
#  [18],
#  [37],
#  [18],
#  [214],
#  [183],
#  [40],
#  [1149],
#  [8795],
#  [1541],
#  [4345],
#  [235],
#  [37],
#  [40],
#  [938],
#  [631],
#  [37],
#  [5],
#  [4301],
#  [674],
#  [3757],
#  [3757],
#  [136],
#  [37],
#  [938],
#  [65],
#  [2569],
#  [37],
#  [4397],
#  [184],
#  [37],
#  [4397],
#  [40],
#  [4397],
#  [4397],
#  [37],
#  [27],
#  [37],
#  [37],
#  [1796],
#  [633],
#  [1054],
#  [37],
#  [4395],
#  [3307],
#  [633],
#  [4397],
#  [2297],
#  [501],
#  [37],
#  [235],
#  [65],
#  [37],
#  [674],
#  [1847],
#  [674],
#  [674],
#  [674],
#  [674],
#  [674],
#  [8795],
#  [37],
#  [134],
#  [37],
#  [65],
#  [65],
#  [183],
#  [3587],
#  [674],
#  [8795],
#  [8795],
#  [8795],
#  [674],
#  [93],
#  [150],
#  [184],
#  [65],
#  [70],
#  [1257],
#  [1397],
#  [1977],
#  [4657],
#  [414],
#  [562],
#  [400],
#  [4658],
#  [924],
#  [4659],
#  [3028],
#  [400],
#  [903],
#  [400],
#  [3111],
#  [400],
#  [28],
#  [4345],
#  [183],
#  [28],
#  [752],
#  [1607],
#  [136],
#  [4485],
#  [4663],
#  [3287],
#  [674],
#  [136],
#  [8795],
#  [4663],
#  [4765],
#  [511],
#  [65],
#  [105],
#  [37],
#  [5],
#  [2546],
#  [1796],
#  [8795],
#  [2546],
#  [106],
#  [674],
#  [214],
#  [65],
#  [674],
#  [70],
#  [4831],
#  [2603],
#  [1678],
#  [8795],
#  [530],
#  [183],
#  [2627],
#  [214],
#  [1746],
#  [226],
#  [3],
#  [95],
#  [4399],
#  [4873],
#  [613],
#  [8795],
#  [226],
#  [150],
#  [27],
#  [8795],
#  [150],
#  [150],
#  [674],
#  [37],
#  [8795],
#  [4908],
#  [2065],
#  [1028],
#  [37],
#  [214],
#  [40],
#  [214],
#  [4399],
#  [37],
#  [8795],
#  [643],
#  [27],
#  [4949],
#  [4016],
#  [631],
#  [303],
#  [214],
#  [183],
#  [214],
#  [1242],
#  [183],
#  [674],
#  [33],
#  [2285],
#  [4051],
#  [214],
#  [214],
#  [31],
#  [8795],
#  [1904],
#  [65],
#  [5026],
#  [128],
#  [189],
#  [8795],
#  [1796],
#  [1796],
#  [1746],
#  [1462],
#  [40],
#  [214],
#  [40],
#  [8795],
#  [1378],
#  [2078],
#  [37],
#  [5],
#  [961],
#  [40],
#  [113],
#  [2834],
#  [674],
#  [3631],
#  [674],
#  [183],
#  [487],
#  [8795],
#  [105],
#  [65],
#  [93],
#  [5283],
#  [1328],
#  [65],
#  [179],
#  [18],
#  [65],
#  [254],
#  [8795],
#  [214],
#  [674],
#  [65],
#  [3294],
#  [37],
#  [5295],
#  [37],
#  [214],
#  [40],
#  [1410],
#  [37],
#  [70],
#  [828],
#  [1242],
#  [100],
#  [697],
#  [1328],
#  [214],
#  [35],
#  [674],
#  [674],
#  [65],
#  [5367],
#  [631],
#  [248],
#  [40],
#  [214],
#  [724],
#  [70],
#  [1347],
#  [70],
#  [5378],
#  [27],
#  [70],
#  [27],
#  [70],
#  [643],
#  [977],
#  [643],
#  [37],
#  [235],
#  [8795],
#  [70],
#  [1796],
#  [674],
#  [2874],
#  [674],
#  [391],
#  [674],
#  [37],
#  [8795],
#  [93],
#  [1796],
#  [106],
#  [5],
#  [93],
#  [93],
#  [40],
#  [35],
#  [72],
#  [19],
#  [8795],
#  [2468],
#  [674],
#  [674],
#  [674],
#  [674],
#  [674],
#  [674],
#  [674],
#  [8795],
#  [8795],
#  [8795],
#  [37],
#  [37],
#  [37],
#  [535],
#  [40],
#  [175],
#  [65],
#  [37],
#  [28],
#  [40],
#  [40],
#  [37],
#  [37],
#  [2570],
#  [348],
#  [65],
#  [1746],
#  [8795],
#  [8795],
#  [674],
#  [226],
#  [150],
#  [226],
#  [214],
#  [134],
#  [516],
#  [37],
#  [8795],
#  [1135],
#  [613],
#  [1523],
#  [5467],
#  [226],
#  [226],
#  [214],
#  [37],
#  [65],
#  [5536],
#  [633],
#  [5538],
#  [5527],
#  [214],
#  [5527],
#  [8795],
#  [8795],
#  [8795],
#  [5527],
#  [5527],
#  [40],
#  [40],
#  [5537],
#  [674],
#  [8795],
#  [5473],
#  [214],
#  [65],
#  [106],
#  [105],
#  [562],
#  [65],
#  [40],
#  [72],
#  [214],
#  [214],
#  [214],
#  [674],
#  [223],
#  [1210],
#  [8795],
#  [8795],
#  [1135],
#  [481],
#  [1904],
#  [214],
#  [506],
#  [674],
#  [183],
#  [214],
#  [8795],
#  [1135],
#  [33],
#  [35],
#  [214],
#  [967],
#  [214],
#  [37],
#  [79],
#  [4345],
#  [37],
#  [660],
#  [1746],
#  [414],
#  [674],
#  [40],
#  [18],
#  [8795],
#  [37],
#  [8795],
#  [304],
#  [207],
#  [150],
#  [674],
#  [3684],
#  [37],
#  [656],
#  [93],
#  [17],
#  [506],
#  [674],
#  [674],
#  [5626],
#  [40],
#  [37],
#  [27],
#  [27],
#  [674],
#  [65],
#  [134],
#  [674],
#  [674],
#  [134],
#  [214],
#  [70],
#  [37],
#  [5615],
#  [5617],
#  [37],
#  [126],
#  [40],
#  [37],
#  [674],
#  [65],
#  [8795],
#  [5437],
#  [8795],
#  [214],
#  [40],
#  [214],
#  [37],
#  [37],
#  [134],
#  [1796],
#  [643],
#  [93],
#  ...]

# %%
# Take a look at sorted_clean_answers
sorted_clean_answers
# Out:
# [[16,
#   50,
#   26,
#   49,
#   19,
#   51,
#   52,
#   16,
#   53,
#   54,
#   46,
#   55,
#   56,
#   57,
#   54,
#   58,
#   42,
#   59,
#   19,
#   60,
#   61,
#   62,
#   63,
#   64,
#   8794],
#  [8795,
#   66,
#   63,
#   67,
#   68,
#   69,
#   70,
#   71,
#   72,
#   63,
#   73,
#   74,
#   75,
#   76,
#   41,
#   77,
#   78,
#   79,
#   63,
#   80,
#   81,
#   54,
#   41,
#   82,
#   83,
#   8794],
#  [105, 8794],
#  [1506, 79, 104, 1525, 34, 152, 613, 8794],
#  [28, 156, 231, 3, 6310, 8794],
#  [27, 28, 8, 163, 68, 257, 68, 1263, 100, 68, 619, 8794],
#  [289, 740, 135, 8794],
#  [28, 243, 98, 68, 194, 230, 41, 8794],
#  [196, 8794],
#  [21, 28, 127, 617, 33, 46, 1490, 49, 8794],
#  [42,
#   2547,
#   160,
#   19,
#   215,
#   80,
#   46,
#   106,
#   1107,
#   52,
#   970,
#   16,
#   8795,
#   147,
#   223,
#   523,
#   8794],
#  [114, 8795, 96, 46, 274, 8794],
#  [181, 77, 79, 46, 275, 276, 8794],
#  [282,
#   25,
#   19,
#   283,
#   19,
#   21,
#   113,
#   97,
#   284,
#   78,
#   119,
#   281,
#   271,
#   77,
#   268,
#   41,
#   5,
#   19,
#   45,
#   29,
#   285,
#   286,
#   96,
#   8795,
#   212,
#   155,
#   5,
#   42,
#   8795,
#   8795,
#   8795,
#   287,
#   8794],
#  [119, 63, 248, 4540, 384, 298, 8794],
#  [8795, 358, 122, 359, 360, 361, 16, 362, 122, 363, 364, 5, 8795, 8794],
#  [76, 135, 131, 142, 8794],
#  [38, 59, 182, 8794],
#  [37, 97, 28, 194, 8794],
#  [46, 500, 490, 46, 61, 8794],
#  [8, 28, 505, 8794],
#  [539, 181, 589, 33, 68, 590, 256, 182, 8794],
#  [19, 51, 535, 19, 51, 8794],
#  [119, 76, 19, 21, 45, 68, 22, 580, 34, 358, 183, 79, 33, 8794],
#  [8795, 8794],
#  [19, 262, 256, 8794],
#  [325, 28, 114, 638, 8794],
#  [40, 28, 325, 29, 8794],
#  [193, 8794],
#  [40, 2457, 136, 28, 8, 59, 26, 998, 19, 99, 281, 148, 142, 5, 159, 136, 8794],
#  [8795, 8794],
#  [8795, 19, 294, 118, 649, 343, 142, 650, 114, 46, 651, 8794],
#  [19,
#   97,
#   29,
#   79,
#   68,
#   97,
#   37,
#   303,
#   333,
#   76,
#   179,
#   333,
#   41,
#   159,
#   16,
#   501,
#   5,
#   179,
#   131,
#   675,
#   72,
#   28,
#   180,
#   8794],
#  [28, 113, 675, 33, 8794],
#  [16, 678, 8794],
#  [19, 99, 16, 524, 1187, 212, 46, 619, 8794],
#  [40, 122, 271, 680, 8794],
#  [40, 37, 8794],
#  [25,
#   26,
#   105,
#   19,
#   77,
#   305,
#   523,
#   63,
#   21,
#   113,
#   5129,
#   478,
#   42,
#   5150,
#   1547,
#   19,
#   2620,
#   23,
#   142,
#   19,
#   77,
#   29,
#   114,
#   638,
#   19,
#   97,
#   29,
#   99,
#   8795,
#   8795,
#   5,
#   19,
#   215,
#   113,
#   5144,
#   23,
#   46,
#   7220,
#   377,
#   19,
#   1485,
#   46,
#   523,
#   1479,
#   223,
#   68,
#   42,
#   6366,
#   15,
#   16,
#   5606,
#   494,
#   1010,
#   54,
#   1544,
#   320,
#   54,
#   279,
#   8794],
#  [40, 19, 865, 8795, 495, 26, 16, 4576, 67, 1983, 2321, 8794],
#  [633, 769, 28, 46, 351, 8794],
#  [88, 46, 351, 260, 8794],
#  [348, 16, 442, 41, 26, 28, 8, 1374, 126, 1370, 68, 101, 8794],
#  [106, 291, 8794],
#  [28, 8, 29, 1909, 8794],
#  [126, 324, 69, 46, 6051, 68, 25, 362, 962, 8794],
#  [40, 8794],
#  [40,
#   19,
#   45,
#   866,
#   260,
#   981,
#   2737,
#   260,
#   1875,
#   277,
#   28,
#   333,
#   33,
#   68,
#   482,
#   159,
#   16,
#   4227,
#   445,
#   28,
#   482,
#   16,
#   3737,
#   40,
#   19,
#   248,
#   29,
#   69,
#   38,
#   5954,
#   8794],
#  [65, 8794],
#  [1355,
#   159,
#   54,
#   28,
#   28,
#   159,
#   306,
#   14,
#   5787,
#   1196,
#   15,
#   37,
#   28,
#   113,
#   477,
#   16,
#   1383,
#   54,
#   38,
#   4570,
#   135,
#   34,
#   87,
#   34,
#   37,
#   16,
#   548,
#   26,
#   230,
#   5,
#   76,
#   258,
#   33,
#   83,
#   19,
#   0,
#   165,
#   68,
#   8794],
#  [97,
#   28,
#   370,
#   478,
#   19,
#   215,
#   231,
#   114,
#   615,
#   1068,
#   285,
#   16,
#   8795,
#   86,
#   1,
#   1347,
#   52,
#   38,
#   1117,
#   19,
#   86,
#   482,
#   46,
#   1155,
#   337,
#   19,
#   135,
#   1045,
#   1110,
#   8794],
#  [37, 230, 154, 206, 8794],
#  [41, 77, 42, 1166, 29, 412, 8794],
#  [342, 52, 790, 8794],
#  [90, 4965, 28, 98, 68, 135, 68, 1109, 75, 182, 2, 451, 103, 8794],
#  [44, 28, 258, 256, 28, 44, 8794],
#  [1250, 8794],
#  [254,
#   28,
#   97,
#   29,
#   265,
#   230,
#   25,
#   1251,
#   8795,
#   1252,
#   19,
#   215,
#   116,
#   114,
#   621,
#   8794],
#  [37, 21, 38, 1299, 194, 54, 25, 8794],
#  [1108, 8794],
#  [1108, 8794],
#  [1108, 8794],
#  [27, 8794],
#  [18, 25, 26, 184, 8794],
#  [19,
#   338,
#   1,
#   248,
#   229,
#   28,
#   248,
#   69,
#   184,
#   28,
#   248,
#   69,
#   535,
#   135,
#   1360,
#   78,
#   572,
#   25,
#   514,
#   78,
#   133,
#   1045,
#   16,
#   1363,
#   5,
#   572,
#   28,
#   8,
#   446,
#   68,
#   33,
#   8794],
#  [28, 338, 8794],
#  [94, 28, 1368, 106, 1369, 8794],
#  [296, 384, 34, 54, 42, 234, 8794],
#  [31, 1432, 740, 357, 15, 1042, 8794],
#  [3275, 79, 4870, 96, 2249, 1097, 8794],
#  [19, 51, 8795, 28, 45, 1258, 1264, 377, 46, 1095, 377, 8794],
#  [674,
#   337,
#   1,
#   607,
#   114,
#   16,
#   223,
#   1465,
#   19,
#   661,
#   8795,
#   15,
#   41,
#   5,
#   42,
#   1244,
#   26,
#   163,
#   68,
#   1028,
#   1482,
#   371,
#   8795,
#   8795,
#   8794],
#  [40, 28, 8, 16, 1483, 28, 8, 3832, 19, 765, 1476, 750, 8794],
#  [2040, 2040, 8794],
#  [37, 8, 28, 268, 182, 8794],
#  [7784, 28, 45, 80, 1393, 93, 8794],
#  [97, 29, 428, 38, 5015, 8794],
#  [25, 26, 65, 181, 77, 35, 1531, 181, 77, 1614, 740, 8794],
#  [126,
#   77,
#   46,
#   311,
#   19,
#   194,
#   63,
#   288,
#   68,
#   229,
#   68,
#   740,
#   63,
#   153,
#   2199,
#   235,
#   388,
#   235,
#   40,
#   8794],
#  [254, 28, 0, 69, 412, 1323, 114, 8794],
#  [19, 51, 657, 19, 215, 85, 80, 46, 742, 208, 136, 19, 21, 400, 68, 8794],
#  [63, 26, 1500, 8794],
#  [18,
#   19,
#   985,
#   179,
#   45,
#   231,
#   9,
#   46,
#   1318,
#   54,
#   1657,
#   23,
#   487,
#   54,
#   16,
#   3272,
#   8794],
#  [100, 44, 179, 958, 68, 97, 25, 998, 161, 3096, 8794],
#  [19, 51, 1135, 188, 8795, 136, 19, 51, 70, 29, 52, 4105, 68, 341, 3, 8794],
#  [1, 8, 1254, 68, 131, 126, 19, 903, 1, 0, 8794],
#  [27, 357, 15, 620, 8794],
#  [18,
#   19,
#   80,
#   16,
#   3003,
#   15,
#   42,
#   2888,
#   14,
#   8795,
#   68,
#   8795,
#   8221,
#   376,
#   823,
#   337,
#   1,
#   655,
#   8794],
#  [674, 8794],
#  [2970,
#   19,
#   3094,
#   1469,
#   16,
#   1595,
#   2341,
#   52,
#   1604,
#   637,
#   5,
#   159,
#   179,
#   86,
#   258,
#   33,
#   77,
#   25,
#   179,
#   21,
#   4368,
#   16,
#   8795,
#   8221,
#   8795,
#   96,
#   16,
#   362,
#   822,
#   136,
#   29,
#   1154,
#   5,
#   3056,
#   29,
#   1172,
#   1251,
#   8794],
#  [674, 28, 324, 45, 255, 16, 8795, 25, 273, 1378, 1497, 8795, 1070, 34, 8794],
#  [78,
#   245,
#   1606,
#   41,
#   26,
#   8795,
#   179,
#   243,
#   296,
#   83,
#   368,
#   740,
#   136,
#   179,
#   21,
#   113,
#   296,
#   284,
#   368,
#   1606,
#   8794],
#  [674, 8794],
#  [674, 19, 912, 28, 8795, 41, 19, 80, 1154, 230, 16, 144, 501, 8794],
#  [44, 179, 45, 161, 1602, 96, 3, 8794],
#  [18, 37, 26, 41, 8794],
#  [18, 41, 26, 3646, 136, 24, 28, 98, 68, 65, 97, 29, 28, 8794],
#  [649, 28, 70, 97, 29, 865, 41, 97, 28, 8794],
#  [18,
#   16,
#   85,
#   1580,
#   8795,
#   54,
#   16,
#   1604,
#   8,
#   105,
#   8,
#   1,
#   163,
#   37,
#   248,
#   1,
#   97,
#   72,
#   1,
#   131,
#   126,
#   72,
#   8,
#   1,
#   1064,
#   154,
#   5,
#   65,
#   8,
#   1,
#   163,
#   8794],
#  [674,
#   18,
#   96,
#   122,
#   50,
#   3237,
#   28,
#   1356,
#   16,
#   1709,
#   159,
#   28,
#   0,
#   131,
#   26,
#   46,
#   4612,
#   366,
#   8795,
#   25,
#   16,
#   1356,
#   2777,
#   8,
#   8795,
#   34,
#   54,
#   1662,
#   8794],
#  [756,
#   2642,
#   1,
#   45,
#   116,
#   487,
#   530,
#   1831,
#   4523,
#   1885,
#   25,
#   46,
#   756,
#   408,
#   8795,
#   343,
#   1156,
#   34,
#   52,
#   8795,
#   83,
#   8795,
#   54,
#   10,
#   5747,
#   1173,
#   26,
#   3,
#   114,
#   1603,
#   37,
#   343,
#   809,
#   8794],
#  [123, 1751, 501, 26, 8795, 1025, 26, 25, 679, 8794],
#  [1606, 1070, 159, 6605, 1768, 1762, 8794],
#  [19, 98, 68, 484, 14, 42, 497, 8794],
#  [8795, 8794],
#  [1210, 8794],
#  [254, 28, 516, 45, 46, 414, 1452, 8794],
#  [19, 0, 1808, 1805, 136, 28, 80, 68, 131, 33, 1312, 182, 944, 8794],
#  [41, 26, 16, 85, 234, 28, 8, 163, 68, 131, 1805, 8794],
#  [41, 1506, 79, 28, 704, 41, 578, 122, 54, 16, 955, 8794],
#  [41,
#   26,
#   46,
#   981,
#   1107,
#   136,
#   1804,
#   67,
#   68,
#   1850,
#   1851,
#   182,
#   46,
#   742,
#   743,
#   154,
#   19,
#   255,
#   256,
#   229,
#   230,
#   41,
#   8794],
#  [324, 69, 1804, 212, 377, 8794],
#  [1243, 80, 487, 8795, 8795, 8794],
#  [1821, 212, 15, 16, 1567, 8794],
#  [18, 28, 80, 68, 735, 1, 357, 46, 981, 234, 8794],
#  [40,
#   1657,
#   1823,
#   136,
#   165,
#   985,
#   19,
#   892,
#   46,
#   7266,
#   105,
#   44,
#   28,
#   131,
#   16,
#   509,
#   25,
#   28,
#   86,
#   489,
#   33,
#   8794],
#  [8795, 8795, 28, 705, 8795, 38, 1105, 8794],
#  [214, 8794],
#  [871,
#   29,
#   68,
#   131,
#   38,
#   608,
#   1107,
#   68,
#   1960,
#   1,
#   80,
#   291,
#   967,
#   1953,
#   15,
#   3,
#   122,
#   8794],
#  [136,
#   25,
#   26,
#   37,
#   28,
#   101,
#   230,
#   159,
#   54,
#   740,
#   159,
#   16,
#   8795,
#   1,
#   8,
#   156,
#   16,
#   149,
#   1093,
#   14,
#   72,
#   28,
#   258,
#   41,
#   8794],
#  [150, 41, 26, 33, 8794],
#  [1464, 14, 8794],
#  [37, 97, 28, 98, 8794],
#  [19, 60, 131, 41, 62, 2043, 2044, 8794],
#  [16, 2131, 2132, 16, 2103, 970, 38, 2178, 8794],
#  [226, 2124, 1553, 182, 8794],
#  [226, 2124, 19, 51, 1792, 159, 1974, 182, 8794],
#  [28, 8, 29, 25, 660, 357, 15, 1, 248, 131, 28, 68, 46, 1094, 8794],
#  [28, 8, 16, 8795, 8795, 19, 99, 114, 3, 2137, 2138, 8794],
#  [45, 28, 1554, 451, 957, 8794],
#  [28, 124, 8795, 1457, 8794],
#  [97,
#   29,
#   28,
#   685,
#   245,
#   33,
#   96,
#   504,
#   50,
#   114,
#   42,
#   115,
#   17,
#   28,
#   45,
#   1089,
#   38,
#   1223,
#   1090,
#   23,
#   38,
#   269,
#   2002,
#   8794],
#  [64, 41, 131, 161, 516, 82, 37, 8794],
#  [37, 26, 41, 8794],
#  [19, 985, 25, 239, 150, 8794],
#  [235, 236, 8794],
#  [29, 1875, 68, 87, 28, 78, 982, 16, 1012, 8794],
#  [674, 136, 400, 26, 29, 16, 8795, 128, 182, 951, 26, 8794],
#  [8795, 8794],
#  [106, 97, 28, 99, 100, 1, 101, 2, 400, 8794],
#  [8795, 8795, 8794],
#  [136,
#   19,
#   97,
#   29,
#   99,
#   400,
#   19,
#   51,
#   79,
#   46,
#   2292,
#   4549,
#   68,
#   1293,
#   362,
#   303,
#   212,
#   739,
#   136,
#   113,
#   68,
#   45,
#   122,
#   54,
#   42,
#   269,
#   8794],
#  [28, 99, 28, 86, 1341, 118, 23, 3, 3226, 106, 50, 41, 26, 29, 1982, 8794],
#  [28, 8, 2142, 8794],
#  [697, 82, 259, 8794],
#  [42,
#   1906,
#   1702,
#   1444,
#   26,
#   1541,
#   944,
#   245,
#   1219,
#   1368,
#   19,
#   97,
#   29,
#   79,
#   8795,
#   2239,
#   8794],
#  [68, 3833, 8795, 8794],
#  [2251, 41, 26, 33, 165, 530, 2264, 8794],
#  [41, 343, 68, 69, 3, 234, 96, 277, 41, 248, 29, 69, 981, 8794],
#  [63, 26, 159, 19, 215, 80, 63, 26, 16, 85, 2269, 8794],
#  [37, 28, 94, 26, 37, 19, 80, 2273, 8794],
#  [19, 51, 779, 28, 8794],
#  [1309, 680, 284, 8794],
#  [24, 41, 26, 29, 256, 126, 26, 40, 628, 8794],
#  [105, 8, 16, 801, 8794],
#  [944, 104, 944, 28, 243, 98, 68, 745, 3, 1702, 2298, 8794],
#  [214, 183, 26, 3, 8794],
#  [19, 99, 37, 28, 44, 8794],
#  [100, 108, 44, 181, 486, 28, 8794],
#  [119, 1, 8, 163, 126, 8794],
#  [18,
#   182,
#   212,
#   16,
#   628,
#   1518,
#   3,
#   50,
#   19,
#   51,
#   15,
#   93,
#   277,
#   343,
#   83,
#   68,
#   97,
#   23,
#   2397,
#   2398,
#   111,
#   25,
#   26,
#   411,
#   1510,
#   16,
#   2399,
#   8795,
#   8794],
#  [636, 14, 2412, 38, 3257, 3969, 152, 8794],
#  [183, 26, 3, 114, 16, 2291, 183, 26, 181, 8794],
#  [1067,
#   25,
#   26,
#   105,
#   181,
#   73,
#   412,
#   2506,
#   1289,
#   181,
#   77,
#   46,
#   106,
#   409,
#   8795,
#   129,
#   10,
#   8795,
#   136,
#   25,
#   77,
#   83,
#   181,
#   8795,
#   181,
#   288,
#   68,
#   69,
#   8795,
#   8794],
#  [24,
#   28,
#   325,
#   68,
#   328,
#   41,
#   28,
#   21,
#   94,
#   16,
#   1351,
#   2515,
#   298,
#   28,
#   21,
#   94,
#   16,
#   1126,
#   179,
#   0,
#   741,
#   8794],
#  [42, 2497, 113, 2526, 23, 481, 2055, 1644, 29, 706, 8794],
#  [19, 51, 182, 8794],
#  [308,
#   41,
#   68,
#   33,
#   1236,
#   16,
#   2533,
#   2341,
#   79,
#   1,
#   2534,
#   40,
#   1000,
#   911,
#   28,
#   2535,
#   3,
#   14,
#   159,
#   371,
#   451,
#   8794],
#  [1678, 2268, 2266, 2298, 182, 8794],
#  [1796, 1678, 8795, 42, 39, 212, 2574, 772, 19, 51, 46, 406, 8795, 2369, 8794],
#  [18,
#   19,
#   51,
#   611,
#   14,
#   15,
#   38,
#   1693,
#   2386,
#   3613,
#   726,
#   1410,
#   1195,
#   500,
#   1008,
#   4554,
#   1679,
#   606,
#   168,
#   132,
#   4943,
#   3442,
#   4789,
#   8795,
#   349,
#   4654,
#   8795,
#   8795,
#   46,
#   2314,
#   25,
#   26,
#   100,
#   63,
#   26,
#   4987,
#   26,
#   3,
#   1337,
#   1340,
#   8794],
#  [63, 78, 157, 2551, 8794],
#  [2555, 2556, 8795, 230, 46, 523, 282, 2386, 1075, 8794],
#  [28, 639, 69, 8794],
#  [41,
#   26,
#   29,
#   70,
#   42,
#   1117,
#   136,
#   41,
#   26,
#   29,
#   876,
#   96,
#   33,
#   68,
#   306,
#   2568,
#   16,
#   1807,
#   1329,
#   30,
#   54,
#   33,
#   1251,
#   94,
#   19,
#   99,
#   46,
#   124,
#   230,
#   349,
#   2263,
#   72,
#   1393,
#   508,
#   179,
#   1589,
#   156,
#   477,
#   46,
#   2550,
#   41,
#   26,
#   2569,
#   179,
#   98,
#   68,
#   101,
#   2570,
#   8794],
#  [1678,
#   8795,
#   41,
#   26,
#   2574,
#   97,
#   28,
#   912,
#   19,
#   77,
#   126,
#   46,
#   742,
#   823,
#   824,
#   32,
#   230,
#   38,
#   1693,
#   8794],
#  [181, 2582, 142, 5, 5, 5, 181, 2332, 142, 181, 1080, 142, 14, 23, 8795, 8794],
#  [16, 2601, 28, 60, 94, 451, 114, 41, 8794],
#  [28, 8, 412, 59, 93, 8794],
#  [41,
#   577,
#   578,
#   46,
#   1131,
#   54,
#   1088,
#   855,
#   68,
#   2613,
#   179,
#   2633,
#   256,
#   620,
#   8795,
#   256,
#   1033,
#   8794],
#  [72, 643, 212, 8795, 8795, 79, 8215, 41, 26, 2641, 159, 931, 1974, 8794],
#  [357, 15, 2913, 181, 248, 29, 1341, 28, 181, 624, 740, 986, 8794],
#  [41,
#   26,
#   16,
#   1787,
#   28,
#   45,
#   231,
#   2194,
#   14,
#   96,
#   19,
#   288,
#   28,
#   68,
#   45,
#   41,
#   96,
#   38,
#   1691,
#   8794],
#  [530, 1932, 8794],
#  [285, 72, 8, 28, 120, 46, 1892, 8795, 8794],
#  [19, 215, 80, 68, 135, 8794],
#  [2650, 1, 45, 80, 68, 131, 68, 6313, 337, 41, 26, 260, 1395, 8794],
#  [235,
#   181,
#   77,
#   3,
#   3285,
#   147,
#   19,
#   1028,
#   230,
#   183,
#   79,
#   1089,
#   412,
#   1393,
#   119,
#   179,
#   44,
#   29,
#   98,
#   68,
#   508,
#   16,
#   858,
#   16,
#   234,
#   181,
#   20,
#   179,
#   639,
#   8794],
#  [25,
#   239,
#   179,
#   8,
#   163,
#   68,
#   972,
#   33,
#   16,
#   2944,
#   68,
#   16,
#   386,
#   35,
#   19,
#   0,
#   2665,
#   14,
#   72,
#   19,
#   51,
#   570,
#   8794],
#  [3790, 8794],
#  [19,
#   51,
#   29,
#   1204,
#   19,
#   2114,
#   8795,
#   46,
#   1131,
#   5,
#   24,
#   254,
#   78,
#   254,
#   118,
#   82,
#   487,
#   50,
#   1089,
#   142,
#   19,
#   21,
#   79,
#   68,
#   513,
#   230,
#   41,
#   8794],
#  [366, 26, 16, 122, 1, 45, 68, 1077, 230, 8794],
#  [35, 179, 1101, 14, 23, 28, 260, 8794],
#  [19, 243, 45, 46, 977, 79, 28, 25, 28, 8794],
#  [35,
#   159,
#   54,
#   46,
#   1225,
#   412,
#   85,
#   977,
#   2741,
#   34,
#   54,
#   75,
#   69,
#   8795,
#   447,
#   2742,
#   79,
#   46,
#   8795,
#   46,
#   173,
#   8795,
#   97,
#   8795,
#   5,
#   8795,
#   8795,
#   16,
#   2740,
#   2743,
#   2744,
#   16,
#   2745,
#   8795,
#   601,
#   16,
#   8795,
#   8795,
#   8795,
#   951,
#   8794],
#  [2214,
#   79,
#   41,
#   6611,
#   670,
#   368,
#   46,
#   327,
#   8795,
#   1727,
#   8795,
#   943,
#   5,
#   8795,
#   122,
#   8795,
#   76,
#   938,
#   8794],
#  [8795, 5, 19, 0, 482, 16, 6809, 620, 8795, 41, 1378, 16, 2404, 5, 8794],
#  [165, 513, 25, 8794],
#  [19, 51, 23, 28, 28, 28, 8794],
#  [37, 26, 163, 15, 114, 182, 7505, 37, 8794],
#  [25,
#   26,
#   1500,
#   2746,
#   8795,
#   996,
#   179,
#   0,
#   2158,
#   16,
#   2719,
#   2751,
#   35,
#   1,
#   0,
#   1419,
#   8795,
#   2351,
#   8794],
#  [41,
#   26,
#   851,
#   19,
#   86,
#   8795,
#   122,
#   54,
#   16,
#   2760,
#   2767,
#   2768,
#   68,
#   16,
#   8795,
#   35,
#   41,
#   21,
#   206,
#   15,
#   16,
#   8795,
#   72,
#   181,
#   2769,
#   368,
#   16,
#   2770,
#   8794],
#  [41, 248, 69, 159, 93, 1, 8, 374, 330, 8794],
#  [24,
#   1,
#   86,
#   131,
#   1281,
#   16,
#   8795,
#   622,
#   123,
#   8795,
#   254,
#   1,
#   86,
#   1080,
#   16,
#   2719,
#   2351,
#   8794],
#  [38, 515, 77, 68, 3796, 105, 181, 77, 8794],
#  [19,
#   45,
#   8795,
#   28,
#   68,
#   1000,
#   23,
#   33,
#   1272,
#   23,
#   3413,
#   362,
#   8795,
#   96,
#   328,
#   1,
#   248,
#   5292,
#   28,
#   5,
#   16,
#   852,
#   4212,
#   8795,
#   8795,
#   68,
#   8795,
#   114,
#   123,
#   1653,
#   8795,
#   8794],
#  [28, 25, 28, 243, 69, 46, 28, 124, 28, 28, 5077, 28, 8794],
#  [2817, 2818, 16, 2819, 2374, 183, 80, 1107, 1322, 2332, 256, 8794],
#  [28, 99, 1823, 8795, 16, 1211, 19, 564, 23, 8794],
#  [181,
#   1243,
#   140,
#   34,
#   179,
#   116,
#   68,
#   131,
#   877,
#   54,
#   256,
#   5,
#   1823,
#   248,
#   131,
#   1099,
#   8794],
#  [535, 19, 248, 257, 46, 2841, 8795, 28, 0, 1066, 41, 8794],
#  [28, 243, 69, 516, 578, 2846, 129, 18, 129, 8795, 68, 78, 135, 96, 16, 8794],
#  [28, 243, 29, 616, 41, 8794],
#  [28,
#   729,
#   37,
#   19,
#   51,
#   979,
#   19,
#   98,
#   46,
#   2861,
#   46,
#   967,
#   122,
#   29,
#   46,
#   2871,
#   82,
#   8795,
#   8794],
#  [8795, 371, 16, 1977, 2876, 8794],
#  [2879, 1407, 8795, 68, 357, 34, 54, 365, 2880, 285, 2881, 8795, 8794],
#  [179, 280, 8794],
#  [16, 85, 1319, 1727, 33, 5, 25, 8795, 15, 1245, 26, 1369, 388, 1369, 8794],
#  [3, 234, 8794],
#  [105, 44, 28, 131, 16, 1006, 8794],
#  [612, 256, 97, 41, 8794],
#  [2818, 134, 129, 442, 248, 29, 69, 2868, 41, 17, 8794],
#  [34, 54, 3, 1093, 1127, 3, 1127, 1868, 1224, 2046, 114, 16, 3228, 1868, 8794],
#  [133, 422, 1393, 8, 649, 2905, 82, 1846, 179, 8, 649, 34, 8794],
#  [40, 37, 8794],
#  [798, 65, 8794],
#  [25, 26, 159, 28, 80, 68, 101, 674, 8794],
#  [63,
#   248,
#   29,
#   69,
#   182,
#   96,
#   46,
#   1037,
#   1859,
#   194,
#   28,
#   0,
#   1323,
#   41,
#   25,
#   981,
#   8794],
#  [105,
#   97,
#   28,
#   333,
#   68,
#   697,
#   96,
#   142,
#   2800,
#   2913,
#   23,
#   16,
#   362,
#   1393,
#   26,
#   29,
#   106,
#   291,
#   8794],
#  [19, 51, 1146, 28, 8, 182, 0, 28, 892, 96, 46, 445, 8794],
#  [2917, 42, 641, 41, 26, 412, 8794],
#  [37, 97, 28, 98, 76, 8794],
#  [28, 60, 45, 938, 2840, 1, 257, 790, 1702, 2920, 8794],
#  [535, 8794],
#  [52,
#   16,
#   75,
#   2927,
#   114,
#   412,
#   2928,
#   1380,
#   1341,
#   487,
#   1393,
#   19,
#   51,
#   163,
#   68,
#   1785,
#   412,
#   608,
#   8794],
#  [19, 171, 28, 438, 255, 8794],
#  [181,
#   101,
#   284,
#   230,
#   16,
#   8795,
#   19,
#   1182,
#   68,
#   972,
#   256,
#   2890,
#   21,
#   29,
#   995,
#   41,
#   8794],
#  [28, 5, 2827, 2828, 8794],
#  [105, 26, 2840, 8794],
#  [63, 26, 2946, 14, 487, 343, 29, 63, 8794],
#  [19, 51, 1135, 230, 37, 19, 280, 8794],
#  [1823, 64, 29, 257, 481, 8794],
#  [194, 179, 8, 1108, 8794],
#  [19, 97, 29, 99, 96, 1896, 212, 2912, 8794],
#  [401, 33, 2188, 41, 77, 142, 1872, 54, 33, 19, 1308, 8795, 8794],
#  [16, 1925, 41, 1506, 79, 41, 26, 8795, 585, 82, 83, 8794],
#  [25,
#   2972,
#   311,
#   996,
#   63,
#   0,
#   2980,
#   2840,
#   578,
#   5,
#   477,
#   33,
#   478,
#   79,
#   3,
#   19,
#   51,
#   211,
#   775,
#   577,
#   2962,
#   19,
#   51,
#   46,
#   1218,
#   1131,
#   211,
#   775,
#   577,
#   19,
#   231,
#   25,
#   2981,
#   5,
#   19,
#   99,
#   16,
#   1319,
#   3,
#   26,
#   278,
#   8794],
#  [16, 362, 147, 8794],
#  [46,
#   3717,
#   114,
#   564,
#   5,
#   2134,
#   8795,
#   28,
#   248,
#   946,
#   33,
#   96,
#   3,
#   122,
#   1974,
#   6597,
#   1125,
#   578,
#   25,
#   1245,
#   8794],
#  [28, 40, 106, 8795, 8794],
#  [28, 912, 2962, 8795, 8794],
#  [19,
#   1215,
#   15,
#   142,
#   63,
#   116,
#   16,
#   2967,
#   2254,
#   1542,
#   97,
#   29,
#   1827,
#   142,
#   129,
#   108,
#   129,
#   33,
#   366,
#   26,
#   65,
#   19,
#   972,
#   142,
#   16,
#   2254,
#   8794],
#  [2982, 8794],
#  [28, 5, 33, 8794],
#  [938,
#   114,
#   16,
#   1093,
#   1304,
#   68,
#   1490,
#   29,
#   46,
#   1093,
#   50,
#   42,
#   1304,
#   42,
#   481,
#   42,
#   1778,
#   1886,
#   8794],
#  [2811, 8794],
#  [214,
#   2987,
#   133,
#   19,
#   77,
#   1826,
#   119,
#   343,
#   126,
#   231,
#   284,
#   15,
#   1245,
#   114,
#   2955,
#   230,
#   46,
#   2926,
#   2622,
#   23,
#   46,
#   147,
#   1820,
#   2818,
#   2817,
#   2818,
#   8794],
#  [2818, 8794],
#  [40, 388, 8794],
#  [16, 246, 337, 16, 2868, 8794],
#  [2840, 19, 77, 2323, 54, 617, 46, 1063, 254, 28, 0, 776, 33, 8794],
#  [183,
#   21,
#   486,
#   256,
#   25,
#   146,
#   54,
#   481,
#   29,
#   16,
#   3000,
#   179,
#   80,
#   381,
#   269,
#   203,
#   8795,
#   8794],
#  [19, 262, 68, 676, 28, 136, 19, 97, 29, 194, 41, 809, 8794],
#  [391, 78, 3, 1222, 972, 41, 46, 922, 8794],
#  [674, 934, 8794],
#  [317, 8794],
#  [2604, 19, 8794],
#  [119, 41, 26, 42, 1280, 8794],
#  [100, 373, 852, 1089, 8794],
#  [161, 54, 740, 8794],
#  [8795,
#   8795,
#   41,
#   26,
#   16,
#   85,
#   1117,
#   28,
#   516,
#   131,
#   8795,
#   620,
#   126,
#   1695,
#   137,
#   54,
#   1282,
#   28,
#   21,
#   802,
#   69,
#   46,
#   8795,
#   775,
#   46,
#   8795,
#   8794],
#  [65, 97, 28, 1864, 41, 8794],
#  [101, 83, 934, 8794],
#  [3121, 8794],
#  [822, 8794],
#  [28, 248, 97, 41, 8794],
#  [19, 2631, 28, 5, 19, 2631, 142, 8794],
#  [136, 8794],
#  [376, 822, 135, 8794],
#  [1023, 8794],
#  [100, 981, 212, 41, 231, 285, 28, 3168, 1023, 8794],
#  [19, 78, 959, 41, 77, 25, 3459, 8794],
#  [8795, 8794],
#  [1023, 8794],
#  [28, 516, 482, 3, 8794],
#  [3178, 8794],
#  [25, 26, 29, 1580, 277, 2015, 1, 45, 68, 229, 8794],
#  [1439, 31, 28, 8, 78, 447, 104, 4246, 96, 451, 8794],
#  [29, 277, 2015, 8794],
#  [1439,
#   19,
#   97,
#   29,
#   99,
#   65,
#   28,
#   80,
#   15,
#   3,
#   1688,
#   19,
#   97,
#   29,
#   99,
#   37,
#   28,
#   8,
#   1254,
#   68,
#   850,
#   8794],
#  [1439, 8794],
#  [2015, 37, 26, 163, 15, 8794],
#  [277, 8794],
#  [8795, 8794],
#  [183,
#   21,
#   865,
#   25,
#   2015,
#   3201,
#   77,
#   1222,
#   46,
#   3202,
#   15,
#   16,
#   3203,
#   3204,
#   508,
#   8794],
#  [3182, 37, 8, 28, 979, 8794],
#  [28, 0, 97, 41, 368, 14, 182, 839, 8794],
#  [25, 64, 29, 2, 1608, 292, 2236, 8794],
#  [25, 26, 29, 851, 8794],
#  [0, 19, 1870, 256, 8794],
#  [181, 26, 46, 318, 1458, 8794],
#  [97, 28, 79, 41, 72, 8795, 7512, 15, 412, 154, 2925, 8794],
#  [25,
#   26,
#   93,
#   3231,
#   277,
#   40,
#   122,
#   212,
#   163,
#   68,
#   1341,
#   28,
#   5,
#   40,
#   122,
#   343,
#   68,
#   99,
#   37,
#   26,
#   585,
#   23,
#   28,
#   8794],
#  [41, 26, 46, 2377, 68, 590, 28, 1023, 19, 51, 836, 23, 159, 38, 564, 8794],
#  [3183, 28, 8, 2660, 183, 26, 114, 687, 54, 3, 1048, 8794],
#  [159,
#   93,
#   137,
#   19,
#   0,
#   131,
#   159,
#   615,
#   303,
#   68,
#   46,
#   1103,
#   1234,
#   19,
#   60,
#   252,
#   69,
#   134,
#   54,
#   2194,
#   381,
#   739,
#   277,
#   26,
#   126,
#   684,
#   271,
#   15,
#   2143,
#   183,
#   0,
#   821,
#   3,
#   2108,
#   8794],
#  [1439, 8794],
#  [19,
#   507,
#   206,
#   1331,
#   5,
#   140,
#   38,
#   2550,
#   19,
#   294,
#   28,
#   886,
#   96,
#   33,
#   68,
#   1028,
#   41,
#   1368,
#   2015,
#   19,
#   215,
#   80,
#   68,
#   229,
#   68,
#   28,
#   8794],
#  [5, 46, 124, 1836, 8794],
#  [674, 8794],
#  [19, 288, 28, 68, 99, 277, 19, 51, 530, 3297, 8794],
#  [19, 194, 35, 136, 19, 215, 113, 588, 41, 35, 8795, 8794],
#  [19, 51, 3278, 8794],
#  [235, 3202, 42, 2497, 26, 530, 81, 0, 28, 97, 83, 31, 8794],
#  [613, 8794],
#  [613, 8794],
#  [126, 26, 46, 124, 377, 15, 2143, 183, 26, 3315, 5, 8794],
#  [19, 51, 3330, 8795, 5, 3, 26, 1329, 8795, 2576, 2577, 1111, 1112, 8794],
#  [97, 41, 8794],
#  [18,
#   126,
#   26,
#   46,
#   50,
#   230,
#   1816,
#   230,
#   970,
#   1322,
#   212,
#   1153,
#   28,
#   97,
#   96,
#   1014,
#   362,
#   5,
#   362,
#   303,
#   212,
#   347,
#   97,
#   29,
#   187,
#   388,
#   41,
#   26,
#   16,
#   347,
#   306,
#   14,
#   1727,
#   16,
#   376,
#   54,
#   28,
#   25,
#   26,
#   159,
#   25,
#   3785,
#   729,
#   27,
#   18,
#   42,
#   515,
#   5,
#   1153,
#   77,
#   1107,
#   305,
#   246,
#   5,
#   19,
#   51,
#   282,
#   16,
#   8795,
#   25,
#   44,
#   41,
#   129,
#   42,
#   1153,
#   19,
#   51,
#   32,
#   28,
#   68,
#   668,
#   33,
#   5,
#   776,
#   33,
#   87,
#   256,
#   8794],
#  [938, 8794],
#  [639, 29, 1, 5292, 381, 1905, 2514, 8794],
#  [31, 19, 324, 131, 34, 182, 8794],
#  [3347, 8795, 8794],
#  [1986,
#   96,
#   28,
#   28,
#   80,
#   256,
#   114,
#   986,
#   54,
#   412,
#   18,
#   37,
#   1,
#   8795,
#   3452,
#   68,
#   129,
#   3354,
#   8794],
#  [226,
#   133,
#   1,
#   45,
#   332,
#   8795,
#   285,
#   285,
#   63,
#   77,
#   8795,
#   114,
#   25,
#   3461,
#   14,
#   114,
#   472,
#   1970,
#   912,
#   28,
#   5,
#   3462,
#   3463,
#   16,
#   3464,
#   35,
#   1875,
#   33,
#   5,
#   3460,
#   325,
#   3465,
#   8795,
#   34,
#   54,
#   123,
#   132,
#   96,
#   46,
#   224,
#   8794],
#  [916, 8794],
#  [60, 2665, 14, 8794],
#  [19,
#   51,
#   70,
#   16,
#   85,
#   122,
#   3494,
#   68,
#   2716,
#   3039,
#   16,
#   1048,
#   583,
#   865,
#   33,
#   19,
#   21,
#   780,
#   29,
#   68,
#   19,
#   897,
#   69,
#   8795,
#   136,
#   19,
#   51,
#   29,
#   290,
#   8794],
#  [63, 26, 1033, 179, 1065, 142, 182, 5, 28, 99, 41, 8794],
#  [433,
#   1250,
#   179,
#   649,
#   45,
#   29,
#   7469,
#   25,
#   122,
#   8795,
#   8795,
#   8795,
#   8795,
#   124,
#   8795,
#   6437,
#   40,
#   2326,
#   8794],
#  [35, 76, 16, 8795, 3529, 8795, 620, 8794],
#  [674, 3477, 8794],
#  [5747,
#   136,
#   41,
#   1506,
#   79,
#   159,
#   54,
#   384,
#   469,
#   52,
#   16,
#   8795,
#   1122,
#   8795,
#   90,
#   1510,
#   16,
#   1162,
#   3089,
#   8794],
#  [1323, 154, 8794],
#  [97, 29, 69, 981, 3548, 8794],
#  [514, 37, 26, 223, 8794],
#  [78, 2504, 25, 26, 516, 775, 2970, 52, 1311, 8794],
#  [28, 187, 967, 8794],
#  [615, 8795, 1644, 99, 106, 460, 72, 179, 513, 41, 8794],
#  [106, 1495, 8794],
#  [26, 126, 46, 30, 96, 33, 8794],
#  [100, 97, 28, 99, 8794],
#  [114, 46, 8795, 8794],
#  [46, 3589, 8795, 8794],
#  [1506, 5, 936, 97, 29, 156, 135, 957, 8795, 8794],
#  [16, 1496, 8794],
#  [97, 29, 1827, 8794],
#  [19,
#   1667,
#   63,
#   26,
#   16,
#   8795,
#   114,
#   25,
#   1112,
#   126,
#   60,
#   69,
#   161,
#   362,
#   868,
#   28,
#   21,
#   882,
#   118,
#   79,
#   25,
#   8794],
#  [235,
#   1023,
#   674,
#   181,
#   26,
#   230,
#   68,
#   2,
#   16,
#   468,
#   3292,
#   54,
#   412,
#   115,
#   487,
#   124,
#   8795,
#   3600,
#   26,
#   1254,
#   68,
#   2905,
#   256,
#   1045,
#   1496,
#   19,
#   99,
#   42,
#   977,
#   181,
#   26,
#   260,
#   3459,
#   68,
#   94,
#   16,
#   3601,
#   5,
#   126,
#   26,
#   40,
#   122,
#   126,
#   183,
#   70,
#   3602,
#   96,
#   256,
#   8794],
#  [38, 977, 26, 10, 8795, 3604, 8795, 3605, 8794],
#  [100,
#   108,
#   8795,
#   765,
#   19,
#   68,
#   8795,
#   368,
#   28,
#   16,
#   211,
#   2123,
#   19,
#   3973,
#   28,
#   16,
#   211,
#   28,
#   482,
#   8794],
#  [19, 98, 68, 135, 154, 68, 3595, 8794],
#  [674, 8794],
#  [65, 8794],
#  [19, 766, 585, 19, 766, 585, 970, 182, 8794],
#  [1, 8, 114, 16, 3618, 54, 16, 8795, 54, 8795, 8794],
#  [78, 101, 41, 28, 248, 94, 41, 26, 530, 408, 3140, 8795, 3140, 8795, 8794],
#  [8795, 19, 51, 3625, 8794],
#  [674, 8794],
#  [528, 42, 817, 8794],
#  [18, 97, 29, 97, 25, 17, 8794],
#  [674, 8794],
#  [19, 400, 28, 19, 400, 28, 8794],
#  [37, 100, 0, 28, 69, 35, 169, 2495, 8794],
#  [40,
#   41,
#   26,
#   93,
#   181,
#   639,
#   513,
#   19,
#   51,
#   81,
#   68,
#   562,
#   54,
#   41,
#   1,
#   60,
#   97,
#   284,
#   93,
#   96,
#   28,
#   0,
#   1,
#   8794],
#  [674, 42, 400, 8794],
#  [38, 641, 26, 967, 8794],
#  [3131, 100, 0, 19, 776, 28, 8794],
#  [42,
#   2497,
#   26,
#   46,
#   3297,
#   409,
#   1023,
#   181,
#   21,
#   69,
#   3643,
#   24,
#   181,
#   672,
#   19,
#   21,
#   357,
#   8794],
#  [674, 8794],
#  [478, 8794],
#  [37, 96, 8794],
#  [639,
#   1,
#   892,
#   182,
#   41,
#   26,
#   46,
#   1692,
#   1536,
#   19,
#   400,
#   615,
#   8795,
#   325,
#   179,
#   182,
#   4095,
#   19,
#   44,
#   29,
#   1931,
#   384,
#   19,
#   985,
#   19,
#   77,
#   260,
#   2157,
#   8794],
#  [3652, 8794],
#  [226, 8794],
#  [3652, 8794],
#  [8795, 8794],
#  [28, 60, 69, 3592, 3593, 8794],
#  [41,
#   26,
#   120,
#   10,
#   3642,
#   96,
#   740,
#   68,
#   45,
#   28,
#   182,
#   3592,
#   3593,
#   5,
#   96,
#   8795,
#   8794],
#  [817, 277, 182, 63, 1159, 8794],
#  [28, 438, 8795, 10, 3596, 368, 3593, 8794],
#  [18, 126, 41, 26, 8794],
#  [129,
#   46,
#   563,
#   54,
#   1603,
#   122,
#   54,
#   42,
#   269,
#   3673,
#   46,
#   530,
#   1087,
#   3616,
#   272,
#   33,
#   63,
#   77,
#   2887,
#   18,
#   8794],
#  [8795, 1053, 1471, 114, 16, 1282, 54, 16, 144, 3717, 8794],
#  [44, 1, 3954, 114, 16, 320, 96, 3680, 82, 3180, 8794],
#  [674, 8794],
#  [674, 8794],
#  [100, 373, 8794],
#  [97, 29, 1077, 19, 51, 29, 1919, 182, 68, 69, 46, 3715, 8794],
#  [4669,
#   19,
#   51,
#   446,
#   68,
#   412,
#   1053,
#   38,
#   1053,
#   19,
#   959,
#   68,
#   2594,
#   85,
#   122,
#   50,
#   25,
#   28,
#   183,
#   8,
#   16,
#   641,
#   54,
#   740,
#   159,
#   86,
#   397,
#   123,
#   2326,
#   16,
#   7364,
#   179,
#   2267,
#   68,
#   734,
#   41,
#   26,
#   29,
#   96,
#   938,
#   25,
#   16,
#   2131,
#   8795,
#   990,
#   740,
#   3642,
#   38,
#   641,
#   5,
#   1090,
#   25,
#   38,
#   1025,
#   897,
#   69,
#   981,
#   845,
#   16,
#   1653,
#   8794],
#  [182, 114, 412, 1842, 179, 346, 256, 93, 469, 8794],
#  [8, 28, 3592, 3593, 8794],
#  [179,
#   248,
#   69,
#   698,
#   96,
#   371,
#   46,
#   184,
#   2279,
#   82,
#   1172,
#   183,
#   3671,
#   68,
#   3796,
#   8795,
#   4562,
#   8794],
#  [8795, 8795, 8795, 8795, 8794],
#  [8795, 3723, 8795, 8794],
#  [19,
#   258,
#   28,
#   19,
#   2309,
#   14,
#   46,
#   5593,
#   114,
#   8795,
#   305,
#   224,
#   2843,
#   662,
#   981,
#   8795,
#   14,
#   68,
#   830,
#   5269,
#   78,
#   79,
#   46,
#   2270,
#   351,
#   41,
#   26,
#   46,
#   2102,
#   8794],
#  [54, 1282, 37, 271, 97, 28, 194, 179, 773, 182, 8794],
#  [661, 41, 620, 8794],
#  [37, 16, 8795, 37, 21, 28, 194, 8794],
#  [0, 19, 94, 41, 8794],
#  [65, 29, 8794],
#  [3,
#   26,
#   3592,
#   3593,
#   42,
#   934,
#   16,
#   1087,
#   409,
#   3592,
#   8795,
#   1144,
#   68,
#   397,
#   123,
#   8795,
#   105,
#   26,
#   63,
#   8794],
#  [8795, 8795, 8795, 8794],
#  [46, 1932, 124, 5496, 136, 41, 8795, 487, 106, 104, 8794],
#  [19, 113, 672, 25, 460, 79, 25, 77, 851, 8794],
#  [19, 51, 260, 1087, 68, 69, 35, 81, 8794],
#  [16, 409, 181, 26, 182, 8794],
#  [46, 407, 366, 113, 3113, 1261, 122, 310, 8794],
#  [357, 289, 740, 3120, 8794],
#  [35, 277, 46, 395, 3002, 8794],
#  [1463,
#   3658,
#   1231,
#   733,
#   334,
#   15,
#   1247,
#   8795,
#   8795,
#   46,
#   8795,
#   1933,
#   220,
#   8795,
#   3776,
#   5,
#   3779,
#   3658,
#   3779,
#   733,
#   1202,
#   91,
#   3777,
#   8795,
#   3776,
#   8795,
#   8795,
#   46,
#   8795,
#   1933,
#   220,
#   8795,
#   3776,
#   97,
#   28,
#   45,
#   25,
#   8794],
#  [3779,
#   3658,
#   1231,
#   733,
#   3156,
#   8795,
#   8795,
#   46,
#   8795,
#   1933,
#   220,
#   8795,
#   3776,
#   8795,
#   8795,
#   46,
#   8795,
#   1933,
#   220,
#   8795,
#   3776,
#   8794],
#  [76, 289, 33, 513, 41, 159, 54, 41, 16, 1218, 50, 368, 16, 913, 277, 8794],
#  [76, 65, 2035, 64, 41, 45, 68, 69, 114, 3680, 8794],
#  [179,
#   262,
#   42,
#   460,
#   41,
#   8795,
#   384,
#   16,
#   85,
#   575,
#   3788,
#   729,
#   26,
#   8795,
#   8795,
#   5,
#   8795,
#   8795,
#   5,
#   8795,
#   368,
#   182,
#   68,
#   8795,
#   3789,
#   3789,
#   3789,
#   3789,
#   3789,
#   3789,
#   3789,
#   3789,
#   284,
#   271,
#   26,
#   8795,
#   8794],
#  [546,
#   384,
#   122,
#   527,
#   8795,
#   5,
#   179,
#   3790,
#   8795,
#   8795,
#   8795,
#   3788,
#   8,
#   3746,
#   3791,
#   5,
#   28,
#   98,
#   384,
#   68,
#   933,
#   42,
#   460,
#   8794],
#  [3663,
#   85,
#   3596,
#   0,
#   97,
#   3,
#   114,
#   46,
#   741,
#   24,
#   211,
#   775,
#   122,
#   699,
#   3722,
#   52,
#   16,
#   144,
#   501,
#   41,
#   26,
#   78,
#   3792,
#   40,
#   122,
#   0,
#   729,
#   46,
#   128,
#   136,
#   23,
#   460,
#   23,
#   460,
#   28,
#   0,
#   45,
#   207,
#   8795,
#   159,
#   446,
#   52,
#   1222,
#   5,
#   41,
#   26,
#   29,
#   3792,
#   41,
#   26,
#   46,
#   2078,
#   3793,
#   26,
#   29,
#   25,
#   3712,
#   8794],
#  [114, 16, 1024, 54, 236, 25, 26, 46, 923, 8794],
#  [182, 114, 3595, 8794],
#  [19, 3124, 41, 26, 29, 260, 836, 8794],
#  [412,
#   1262,
#   572,
#   41,
#   16,
#   3823,
#   159,
#   3595,
#   1479,
#   126,
#   412,
#   3824,
#   3593,
#   212,
#   124,
#   3824,
#   114,
#   16,
#   1359,
#   5,
#   3002,
#   114,
#   25,
#   3825,
#   460,
#   46,
#   3826,
#   460,
#   8795,
#   34,
#   469,
#   384,
#   159,
#   46,
#   184,
#   2758,
#   54,
#   562,
#   8795,
#   2758,
#   96,
#   8795,
#   3593,
#   8795,
#   371,
#   412,
#   716,
#   515,
#   8795,
#   8795,
#   37,
#   8795,
#   37,
#   3827,
#   37,
#   968,
#   114,
#   16,
#   460,
#   8795,
#   343,
#   231,
#   3828,
#   371,
#   236,
#   52,
#   305,
#   5,
#   236,
#   3829,
#   68,
#   165,
#   8795,
#   8795,
#   68,
#   1347,
#   41,
#   19,
#   52,
#   16,
#   320,
#   96,
#   1222,
#   2052,
#   52,
#   256,
#   97,
#   28,
#   729,
#   97,
#   28,
#   8794],
#  [16,
#   85,
#   50,
#   25,
#   2646,
#   33,
#   77,
#   16,
#   4346,
#   538,
#   100,
#   64,
#   122,
#   97,
#   25,
#   100,
#   64,
#   122,
#   616,
#   46,
#   409,
#   41,
#   26,
#   122,
#   50,
#   68,
#   1288,
#   230,
#   41,
#   41,
#   26,
#   530,
#   278,
#   72,
#   28,
#   45,
#   68,
#   97,
#   41,
#   23,
#   38,
#   269,
#   2002,
#   8794],
#  [3593, 26, 1443, 46, 365, 3596, 10, 3180, 3596, 8794],
#  [181, 26, 3835, 25, 741, 68, 460, 8794],
#  [28, 324, 69, 1031, 8794],
#  [113, 127, 8794],
#  [16, 3644, 343, 881, 256, 1713, 8794],
#  [19, 248, 670, 342, 8794],
#  [37, 44, 181, 101, 8794],
#  [179,
#   325,
#   1806,
#   126,
#   325,
#   40,
#   3872,
#   40,
#   3857,
#   3858,
#   16,
#   1218,
#   3355,
#   26,
#   1294,
#   16,
#   1165,
#   54,
#   37,
#   205,
#   809,
#   14,
#   126,
#   8794],
#  [19, 4459, 41, 136, 41, 26, 83, 68, 97, 8794],
#  [46, 3859, 8794],
#  [28, 45, 29, 3885, 38, 790, 8794],
#  [19,
#   51,
#   408,
#   28,
#   97,
#   29,
#   99,
#   33,
#   5,
#   19,
#   99,
#   938,
#   230,
#   28,
#   1,
#   45,
#   46,
#   2078,
#   1543,
#   8794],
#  [1692, 8794],
#  [1461, 8794],
#  [1680, 8794],
#  [16, 2968, 8794],
#  [674, 8794],
#  [248, 28, 69, 182, 114, 230, 2295, 208, 8794],
#  [258, 33, 25, 41, 26, 3646, 54, 33, 68, 69, 8795, 8794],
#  [19, 215, 655, 422, 1917, 96, 28, 8794],
#  [1419, 469, 8794],
#  [1, 116, 10, 2891, 181, 26, 970, 3646, 8794],
#  [40, 37, 8794],
#  [18, 159, 93, 76, 69, 25, 234, 182, 2098, 3, 8794],
#  [16,
#   1094,
#   248,
#   69,
#   3900,
#   1368,
#   21,
#   28,
#   79,
#   46,
#   141,
#   1079,
#   68,
#   133,
#   52,
#   1,
#   45,
#   487,
#   1680,
#   1932,
#   8795,
#   8794],
#  [93, 8794],
#  [40, 37, 8794],
#  [3899, 45, 28, 685, 231, 8795, 3901, 230, 16, 1350, 5, 3902, 8794],
#  [19, 20, 29, 8794],
#  [2631, 499, 16, 362, 3245, 25, 3919, 28, 8794],
#  [277,
#   1,
#   45,
#   78,
#   881,
#   28,
#   46,
#   143,
#   599,
#   8795,
#   35,
#   871,
#   68,
#   131,
#   487,
#   922,
#   277,
#   2631,
#   499,
#   248,
#   94,
#   68,
#   38,
#   624,
#   922,
#   277,
#   8794],
#  [133,
#   188,
#   3853,
#   19,
#   99,
#   19,
#   215,
#   231,
#   8795,
#   136,
#   1823,
#   77,
#   3047,
#   1609,
#   19,
#   612,
#   256,
#   46,
#   409,
#   60,
#   97,
#   25,
#   68,
#   118,
#   23,
#   412,
#   3930,
#   2002,
#   8794],
#  [106, 8794],
#  [3184, 8794],
#  [28, 8, 29, 9, 46, 106, 501, 8, 28, 8794],
#  [1706, 1, 8794],
#  [121, 68, 94, 28, 8794],
#  [585, 8794],
#  [46, 8795, 8794],
#  [8795, 44, 29, 8795, 8794],
#  [289, 740, 78, 296, 1971, 8794],
#  [214, 8794],
#  [105, 8, 1, 163, 8794],
#  [37, 8794],
#  [3184,
#   277,
#   19,
#   99,
#   3,
#   897,
#   69,
#   1875,
#   96,
#   28,
#   136,
#   19,
#   45,
#   68,
#   3036,
#   28,
#   8794],
#  [28, 2201, 5, 277, 28, 1706, 3966, 16, 3962, 8794],
#  [165, 68, 33, 482, 38, 269, 115, 3184, 41, 26, 123, 85, 394, 8794],
#  [16,
#   2692,
#   16,
#   3970,
#   54,
#   3971,
#   41,
#   26,
#   159,
#   679,
#   482,
#   38,
#   269,
#   115,
#   2554,
#   3184,
#   1432,
#   33,
#   8794],
#  [131, 34, 54, 182, 1823, 8794],
#  [3975,
#   26,
#   16,
#   409,
#   28,
#   2332,
#   114,
#   16,
#   6923,
#   1,
#   20,
#   41,
#   1407,
#   28,
#   44,
#   29,
#   94,
#   256,
#   129,
#   181,
#   26,
#   46,
#   2882,
#   616,
#   5,
#   649,
#   143,
#   5321,
#   8794],
#  [3978, 8795, 5, 8795, 8795, 8, 182, 68, 94, 28, 1094, 8794],
#  [235, 8794],
#  [136, 19, 0, 811, 487, 14, 96, 28, 24, 28, 21, 79, 8794],
#  [343, 1702, 3854, 280, 284, 3224, 16, 2628, 15, 16, 8795, 8794],
#  [214, 181, 248, 45, 46, 475, 501, 2323, 14, 46, 3992, 1298, 96, 3, 122, 8794],
#  [182, 212, 207, 726, 463, 8794],
#  [289, 33, 45, 1008, 490, 8794],
#  [214, 8794],
#  [28, 729, 8794],
#  [1322, 324, 69, 114, 106, 4018, 181, 77, 8795, 1090, 8795, 8794],
#  [970, 478, 23, 28, 343, 156, 570, 3, 68, 33, 28, 99, 25, 8794],
#  [348, 41, 26, 25, 401, 28, 120, 46, 7099, 23, 801, 8794],
#  [18, 37, 8794],
#  [19, 98, 68, 69, 825, 28, 8794],
#  [97, 29, 28, 99, 19, 215, 231, 1466, 230, 28, 96, 743, 8794],
#  [674, 277, 8794],
#  [19, 51, 3641, 1135, 19, 21, 1650, 159, 230, 28, 19, 51, 35, 1135, 934, 8794],
#  [97,
#   29,
#   28,
#   249,
#   25,
#   19,
#   51,
#   649,
#   16,
#   92,
#   409,
#   1378,
#   182,
#   260,
#   277,
#   1,
#   248,
#   131,
#   16,
#   2083,
#   2939,
#   96,
#   342,
#   246,
#   28,
#   5,
#   19,
#   8,
#   163,
#   34,
#   957,
#   100,
#   26,
#   25,
#   8794],
#  [19, 45, 29, 80, 161, 365, 1742, 96, 384, 3, 1495, 1251, 8794],
#  [235,
#   40,
#   41,
#   26,
#   29,
#   96,
#   28,
#   28,
#   8,
#   85,
#   163,
#   68,
#   131,
#   1115,
#   1678,
#   3997,
#   5,
#   19,
#   8,
#   163,
#   68,
#   135,
#   15,
#   16,
#   4807,
#   8794],
#  [3995,
#   19,
#   51,
#   163,
#   68,
#   2308,
#   78,
#   129,
#   893,
#   129,
#   16,
#   1412,
#   2614,
#   2,
#   159,
#   16,
#   1740,
#   248,
#   28,
#   8794],
#  [1702, 3993, 8794],
#  [674, 8794],
#  [131, 1678, 3997, 15, 16, 1356, 8794],
#  [41, 26, 412, 115, 718, 481, 28, 99, 8794],
#  [18,
#   482,
#   42,
#   128,
#   96,
#   41,
#   5,
#   97,
#   29,
#   871,
#   41,
#   41,
#   26,
#   4080,
#   24,
#   41,
#   325,
#   487,
#   362,
#   311,
#   19,
#   86,
#   1656,
#   142,
#   136,
#   282,
#   159,
#   28,
#   60,
#   4081,
#   46,
#   1412,
#   212,
#   606,
#   34,
#   277,
#   0,
#   28,
#   8794],
#  [357, 182, 808, 8794],
#  [46,
#   515,
#   54,
#   1154,
#   214,
#   70,
#   412,
#   1090,
#   77,
#   3641,
#   81,
#   5,
#   63,
#   77,
#   1051,
#   21,
#   28,
#   865,
#   41,
#   8794],
#  [235, 28, 194, 19, 51, 1806, 8794],
#  [159, 93, 19, 51, 1806, 97, 29, 249, 28, 1469, 33, 46, 4084, 8794],
#  [18, 181, 77, 447, 400, 68, 142, 8794],
#  [37, 501, 44, 3326, 1679, 131, 114, 8794],
#  [37, 501, 44, 28, 131, 114, 8794],
#  [101,
#   1,
#   1785,
#   1045,
#   46,
#   1412,
#   1,
#   4869,
#   1,
#   8,
#   16,
#   4113,
#   3432,
#   1822,
#   303,
#   8,
#   163,
#   68,
#   69,
#   2323,
#   16,
#   4113,
#   3432,
#   1822,
#   26,
#   126,
#   10,
#   4167,
#   3432,
#   1822,
#   100,
#   357,
#   1,
#   113,
#   255,
#   54,
#   16,
#   4167,
#   3432,
#   1822,
#   35,
#   303,
#   8,
#   1254,
#   68,
#   2492,
#   25,
#   34,
#   1872,
#   54,
#   4886,
#   381,
#   1761,
#   8794],
#  [19, 887, 8794],
#  [18, 1322, 516, 135, 258, 16, 1355, 8795, 8794],
#  [76, 19, 400, 41, 8794],
#  [179, 280, 119, 16, 2549, 325, 1224, 96, 16, 1112, 54, 16, 4122, 8794],
#  [1412, 7713, 7385, 16, 844, 52, 492, 463, 1413, 8794],
#  [165, 181, 26, 42, 2987, 5, 19, 97, 29, 98, 68, 22, 1657, 8794],
#  [28, 476, 6460, 54, 4382, 8795, 182, 7672, 7672, 8794],
#  [19,
#   194,
#   19,
#   612,
#   28,
#   5476,
#   371,
#   16,
#   1191,
#   198,
#   78,
#   129,
#   19,
#   77,
#   1064,
#   114,
#   16,
#   154,
#   8794],
#  [97, 29, 289, 41, 1684, 17, 8794],
#  [65,
#   8,
#   29,
#   1,
#   16,
#   4113,
#   3432,
#   1822,
#   19,
#   187,
#   126,
#   26,
#   822,
#   4113,
#   955,
#   5,
#   85,
#   376,
#   3432,
#   955,
#   182,
#   8794],
#  [277, 16, 122, 501, 122, 54, 740, 1159, 14, 23, 10, 509, 8794],
#  [46, 3601, 8794],
#  [19, 51, 2323, 8794],
#  [189, 119, 3, 26, 46, 1007, 8794],
#  [235,
#   28,
#   8,
#   114,
#   2907,
#   1,
#   8,
#   29,
#   1816,
#   161,
#   211,
#   4114,
#   28,
#   258,
#   2546,
#   4113,
#   105,
#   5,
#   72,
#   68,
#   1271,
#   8794],
#  [105, 26, 4114, 3432, 8794],
#  [72, 45, 28, 685, 332, 374, 409, 4154, 29, 68, 69, 1286, 52, 1386, 8794],
#  [135, 206, 2211, 179, 8, 29, 163, 68, 1313, 40, 211, 4105, 339, 8794],
#  [46, 1007, 1017, 16, 4111, 37, 16, 442, 325, 1, 2323, 8794],
#  [1, 8, 78, 535, 946, 28, 1023, 8794],
#  [1, 99, 91, 277, 1, 80, 68, 131, 28, 68, 2211, 8795, 8794],
#  [1386,
#   114,
#   16,
#   4179,
#   680,
#   41,
#   77,
#   28,
#   183,
#   8795,
#   2546,
#   1,
#   8,
#   159,
#   35,
#   3297,
#   54,
#   28,
#   4114,
#   5,
#   29,
#   46,
#   2573,
#   2822,
#   212,
#   231,
#   411,
#   68,
#   16,
#   4111,
#   285,
#   28,
#   8,
#   1386,
#   212,
#   1193,
#   8794],
#  [325, 28, 1434, 15, 4088, 33, 72, 28, 1204, 8795, 8794],
#  [4114, 37, 8, 28, 2323, 126, 8, 4185, 4186, 5, 8795, 159, 469, 3, 4179, 8794],
#  [2297, 37, 8794],
#  [24, 28, 97, 29, 94, 41, 41, 26, 29, 173, 8794],
#  [19, 248, 1930, 15, 16, 234, 8794],
#  [28,
#   116,
#   159,
#   422,
#   4199,
#   126,
#   35,
#   19,
#   21,
#   194,
#   16,
#   164,
#   534,
#   325,
#   114,
#   1161,
#   368,
#   16,
#   4199,
#   1779,
#   8794],
#  [16, 372, 116, 46, 2900, 368, 46, 2822, 78, 726, 3138, 34, 54, 1161, 8794],
#  [19,
#   21,
#   78,
#   129,
#   893,
#   616,
#   28,
#   4114,
#   3432,
#   136,
#   2330,
#   28,
#   1382,
#   14,
#   260,
#   108,
#   54,
#   42,
#   501,
#   8794],
#  [19, 903, 19, 51, 29, 970, 260, 1042, 8794],
#  [97, 29, 229, 230, 41, 108, 102, 8794],
#  [40,
#   41,
#   26,
#   29,
#   42,
#   350,
#   68,
#   45,
#   68,
#   477,
#   42,
#   2143,
#   1536,
#   68,
#   357,
#   68,
#   3,
#   8795,
#   1852,
#   54,
#   4141,
#   68,
#   4212,
#   65,
#   114,
#   16,
#   39,
#   54,
#   159,
#   25,
#   26,
#   905,
#   28,
#   60,
#   630,
#   68,
#   8795,
#   46,
#   742,
#   3459,
#   4213,
#   368,
#   381,
#   4214,
#   124,
#   8795,
#   35,
#   25,
#   19,
#   897,
#   1233,
#   16,
#   2243,
#   4111,
#   25,
#   3,
#   1446,
#   343,
#   685,
#   588,
#   8794],
#  [832,
#   29,
#   1023,
#   46,
#   1822,
#   54,
#   2976,
#   4218,
#   2228,
#   68,
#   3071,
#   256,
#   368,
#   16,
#   8795,
#   29,
#   85,
#   343,
#   3,
#   4219,
#   4220,
#   368,
#   16,
#   362,
#   4213,
#   16,
#   8795,
#   1702,
#   4211,
#   8795,
#   77,
#   1257,
#   1339,
#   1497,
#   16,
#   1564,
#   8794],
#  [1023, 8794],
#  [37, 26, 25, 8794],
#  [235, 25, 19, 248, 289, 8795, 1930, 8794],
#  [674, 8794],
#  [4248, 28, 8, 195, 10, 707, 8794],
#  [28, 79, 41, 126, 97, 29, 28, 8794],
#  [484, 33, 14, 8794],
#  [3, 26, 8795, 8794],
#  [119,
#   28,
#   45,
#   68,
#   477,
#   1037,
#   10,
#   4263,
#   52,
#   16,
#   3190,
#   68,
#   489,
#   16,
#   787,
#   54,
#   16,
#   8795,
#   4257,
#   19,
#   51,
#   617,
#   34,
#   54,
#   182,
#   105,
#   26,
#   38,
#   8795,
#   8794],
#  [674, 8794],
#  [938, 8794],
#  [42, 515, 272, 33, 19, 639, 254, 252, 131, 46, 1063, 8794],
#  [674, 1676, 8794],
#  [37, 8795, 19, 248, 670, 28, 8794],
#  [41, 26, 46, 1093, 8795, 54, 227, 2319, 1616, 8794],
#  [4647,
#   674,
#   19,
#   99,
#   41,
#   26,
#   46,
#   124,
#   1395,
#   136,
#   26,
#   41,
#   851,
#   68,
#   4074,
#   46,
#   1133,
#   96,
#   376,
#   52,
#   2091,
#   82,
#   2091,
#   375,
#   885,
#   8794],
#  [8795, 1915, 1135, 161, 2175, 8794],
#  [282, 830, 8794],
#  [26, 25, 16, 4310, 1824, 1746, 97, 29, 335, 25, 4311, 17, 8794],
#  [4312, 4313, 4314, 10, 8794],
#  [1329, 4252, 8795, 8794],
#  [0, 28, 948, 1702, 8794],
#  [674, 315, 8794],
#  [8, 28, 1701, 684, 19, 187, 1257, 8794],
#  [2054, 37, 8794],
#  [78, 101, 40, 8794],
#  [19, 51, 1045, 18, 1467, 5, 8795, 1067, 8794],
#  [28, 194, 19, 51, 1916, 28, 194, 159, 2342, 8, 1916, 8794],
#  [26,
#   29,
#   41,
#   666,
#   1064,
#   159,
#   16,
#   234,
#   14,
#   182,
#   136,
#   28,
#   99,
#   179,
#   70,
#   8,
#   16,
#   1407,
#   8794],
#  [235,
#   60,
#   19,
#   51,
#   657,
#   8795,
#   54,
#   8795,
#   8795,
#   165,
#   19,
#   215,
#   70,
#   80,
#   68,
#   135,
#   19,
#   248,
#   235,
#   1896,
#   19,
#   248,
#   670,
#   28,
#   8794],
#  [3265, 4286, 8794],
#  [97, 28, 45, 161, 4254, 82, 8795, 19, 21, 482, 46, 8795, 8794],
#  [40, 19, 51, 27, 8794],
#  [1702, 8795, 46, 1397, 54, 1799, 8795, 8794],
#  [100, 374, 8, 28, 8794],
#  [18,
#   19,
#   215,
#   116,
#   46,
#   1875,
#   501,
#   617,
#   10,
#   4346,
#   8795,
#   46,
#   4347,
#   4348,
#   160,
#   181,
#   612,
#   256,
#   52,
#   46,
#   4349,
#   126,
#   136,
#   19,
#   1215,
#   41,
#   34,
#   5,
#   37,
#   809,
#   26,
#   181,
#   8795,
#   46,
#   8795,
#   8795,
#   96,
#   3265,
#   35,
#   8794],
#  [77, 181, 423, 52, 159, 97, 28, 194, 114, 8795, 82, 4350, 4351, 8794],
#  [19,
#   99,
#   41,
#   2214,
#   79,
#   46,
#   4352,
#   693,
#   136,
#   114,
#   365,
#   4353,
#   19,
#   99,
#   3,
#   2214,
#   79,
#   46,
#   4352,
#   693,
#   136,
#   305,
#   274,
#   19,
#   97,
#   29,
#   99,
#   24,
#   28,
#   45,
#   255,
#   230,
#   3,
#   136,
#   46,
#   1087,
#   8795,
#   77,
#   1074,
#   4195,
#   5,
#   1594,
#   23,
#   8795,
#   46,
#   1087,
#   8795,
#   377,
#   5,
#   4354,
#   4355,
#   8795,
#   23,
#   2795,
#   361,
#   732,
#   8794],
#  [116, 412, 1206, 231, 8795, 8794],
#  [303, 78, 4359, 8794],
#  [35, 28, 1313, 34, 182, 46, 1131, 8794],
#  [25, 26, 29, 16, 1337, 19, 215, 4368, 8794],
#  [19, 215, 4376, 256, 8794],
#  [674, 5, 181, 8795, 41, 102, 52, 944, 181, 86, 29, 69, 134, 8794],
#  [18, 64, 4301, 45, 10, 4029, 8794],
#  [773, 14, 357, 15, 8794],
#  [131,
#   46,
#   1802,
#   1127,
#   3757,
#   28,
#   45,
#   80,
#   46,
#   3220,
#   1959,
#   25,
#   26,
#   37,
#   26,
#   4378,
#   28,
#   28,
#   45,
#   80,
#   68,
#   131,
#   38,
#   259,
#   957,
#   19,
#   248,
#   776,
#   28,
#   8794],
#  [44, 29, 28, 910, 16, 4398, 8794],
#  [2612, 77, 1089, 305, 246, 8794],
#  [938, 8794],
#  [912, 8795, 4427, 8794],
#  [24, 19, 21, 2620, 620, 126, 254, 3, 21, 29, 215, 809, 8794],
#  [65, 64, 29, 181, 245, 740, 68, 412, 155, 181, 26, 113, 252, 1147, 28, 8794],
#  [19,
#   99,
#   28,
#   194,
#   19,
#   51,
#   260,
#   3514,
#   68,
#   256,
#   136,
#   649,
#   19,
#   765,
#   1839,
#   68,
#   4395,
#   5,
#   28,
#   8,
#   16,
#   1983,
#   4319,
#   699,
#   114,
#   42,
#   115,
#   19,
#   51,
#   163,
#   154,
#   68,
#   16,
#   8795,
#   1117,
#   65,
#   639,
#   19,
#   69,
#   538,
#   170,
#   8794],
#  [133, 52, 33, 19, 51, 163, 68, 180, 8794],
#  [19,
#   99,
#   28,
#   28,
#   8,
#   163,
#   68,
#   508,
#   154,
#   68,
#   564,
#   93,
#   282,
#   1798,
#   19,
#   98,
#   42,
#   807,
#   277,
#   8794],
#  [97, 29, 1, 45, 161, 8795, 8794],
#  [29,
#   79,
#   256,
#   26,
#   41,
#   68,
#   97,
#   46,
#   50,
#   79,
#   25,
#   998,
#   779,
#   28,
#   28,
#   8,
#   29,
#   1976,
#   38,
#   1870,
#   15,
#   256,
#   8,
#   28,
#   8794],
#  [214, 150, 946, 28, 96, 1701, 33, 8794],
#  [42, 515, 42, 1407, 515, 2612, 77, 1089, 114, 8795, 2421, 8794],
#  [37, 21, 179, 685, 97, 96, 28, 8794],
#  [184,
#   184,
#   1,
#   257,
#   68,
#   1152,
#   46,
#   1131,
#   54,
#   1372,
#   111,
#   114,
#   1191,
#   54,
#   16,
#   198,
#   8794],
#  [98, 68, 69, 46, 30, 54, 1646, 8794],
#  [181, 26, 1224, 3619, 260, 289, 740, 97, 430, 726, 8794],
#  [4397,
#   4395,
#   4396,
#   19,
#   51,
#   2237,
#   28,
#   5,
#   38,
#   515,
#   0,
#   357,
#   14,
#   182,
#   1,
#   45,
#   1098,
#   487,
#   2244,
#   8795,
#   114,
#   4442,
#   8795,
#   19,
#   21,
#   400,
#   68,
#   546,
#   384,
#   68,
#   28,
#   8794],
#  [21, 28, 79, 46, 4254, 82, 83, 8794],
#  [119,
#   181,
#   77,
#   46,
#   4084,
#   5,
#   19,
#   421,
#   256,
#   131,
#   38,
#   92,
#   34,
#   54,
#   25,
#   2292,
#   3992,
#   14,
#   68,
#   16,
#   173,
#   548,
#   16,
#   211,
#   181,
#   8795,
#   33,
#   16,
#   3008,
#   19,
#   273,
#   119,
#   24,
#   970,
#   8795,
#   886,
#   970,
#   79,
#   256,
#   294,
#   25,
#   26,
#   65,
#   19,
#   51,
#   146,
#   54,
#   8795,
#   252,
#   277,
#   44,
#   29,
#   8795,
#   42,
#   8795,
#   420,
#   29,
#   134,
#   19,
#   252,
#   45,
#   122,
#   8794],
#  [680, 19, 51, 8795, 16, 4449, 289, 740, 1565, 68, 4066, 8794],
#  [78, 97, 41, 8794],
#  [28, 99, 42, 39, 8794],
#  [214, 19, 1935, 41, 96, 2195, 54, 8795, 8795, 368, 16, 8795, 8795, 68, 8794],
#  [2297, 8794],
#  [19,
#   156,
#   2345,
#   24,
#   46,
#   318,
#   19,
#   383,
#   685,
#   140,
#   34,
#   181,
#   21,
#   508,
#   181,
#   21,
#   194,
#   19,
#   77,
#   8795,
#   8794],
#  [501,
#   7852,
#   343,
#   46,
#   2205,
#   3758,
#   3988,
#   2649,
#   114,
#   4395,
#   212,
#   306,
#   3015,
#   1734,
#   25,
#   949,
#   1382,
#   34,
#   8795,
#   8795,
#   8795,
#   4394,
#   114,
#   365,
#   4503,
#   366,
#   239,
#   8795,
#   26,
#   34,
#   8795,
#   8795,
#   4394,
#   8795,
#   26,
#   34,
#   4394,
#   5,
#   8795,
#   114,
#   365,
#   628,
#   3941,
#   26,
#   34,
#   161,
#   54,
#   615,
#   595,
#   86,
#   45,
#   46,
#   3382,
#   82,
#   159,
#   54,
#   384,
#   41,
#   26,
#   79,
#   46,
#   46,
#   8795,
#   314,
#   1,
#   0,
#   135,
#   68,
#   487,
#   782,
#   1170,
#   1117,
#   25,
#   1527,
#   2210,
#   303,
#   1028,
#   131,
#   384,
#   5,
#   740,
#   1089,
#   136,
#   284,
#   472,
#   291,
#   96,
#   3,
#   26,
#   46,
#   723,
#   54,
#   82,
#   46,
#   8795,
#   68,
#   83,
#   4395,
#   212,
#   80,
#   46,
#   1553,
#   114,
#   8794],
#  [181,
#   26,
#   80,
#   4066,
#   3100,
#   14,
#   181,
#   26,
#   80,
#   4409,
#   15,
#   3015,
#   54,
#   4321,
#   181,
#   26,
#   1289,
#   3,
#   8795,
#   3098,
#   96,
#   4421,
#   289,
#   740,
#   622,
#   41,
#   8794],
#  [4397,
#   37,
#   24,
#   8795,
#   8039,
#   1322,
#   5219,
#   16,
#   1974,
#   265,
#   52,
#   1410,
#   46,
#   51,
#   5,
#   990,
#   384,
#   230,
#   41,
#   8794],
#  [63,
#   1469,
#   68,
#   2564,
#   19,
#   280,
#   19,
#   77,
#   1285,
#   10,
#   159,
#   8795,
#   63,
#   280,
#   76,
#   357,
#   206,
#   78,
#   68,
#   101,
#   150,
#   366,
#   19,
#   156,
#   97,
#   72,
#   1,
#   1189,
#   41,
#   26,
#   1522,
#   24,
#   19,
#   97,
#   29,
#   8794],
#  [181,
#   26,
#   231,
#   8795,
#   16,
#   4449,
#   285,
#   1,
#   8795,
#   15,
#   181,
#   26,
#   46,
#   2454,
#   1360,
#   289,
#   740,
#   1565,
#   68,
#   4066,
#   8794],
#  [1355, 37, 189, 97, 28, 97, 52, 8795, 8794],
#  [182, 45, 3, 0, 54, 4362, 212, 8795, 3982, 8794],
#  [69, 2886, 8794],
#  [69, 2886, 8794],
#  [69, 2886, 8794],
#  [289,
#   33,
#   915,
#   28,
#   25,
#   119,
#   54,
#   16,
#   8795,
#   1143,
#   28,
#   243,
#   300,
#   8795,
#   52,
#   4531,
#   54,
#   4402,
#   8795,
#   8794],
#  [69, 2886, 8794],
#  [37, 8794],
#  [4541, 4157, 8795, 28, 99, 179, 3275, 79, 8795, 8794],
#  [97, 19, 2, 28, 4578, 8794],
#  [97, 19, 2, 28, 4578, 3278, 28, 99, 68, 28, 765, 19, 8795, 3081, 8794],
#  [1, 45, 80, 46, 1094, 212, 901, 10, 2089, 1094, 212, 901, 8794],
#  [19, 51, 1135, 25, 3533, 14, 38, 608, 116, 68, 532, 8794],
#  [28, 99, 183, 8794],
#  [25, 26, 29, 16, 234, 68, 131, 1360, 114, 115, 8794],
#  [41, 26, 46, 1675, 181, 77, 29, 211, 8795, 8794],
#  [19,
#   0,
#   1930,
#   179,
#   3162,
#   33,
#   1773,
#   507,
#   34,
#   54,
#   142,
#   18,
#   5,
#   76,
#   179,
#   5,
#   19,
#   8794],
#  [105, 44, 28, 1263, 68, 1541, 8794],
#  [289, 3, 69, 46, 8795, 68, 28, 159, 25, 3, 2542, 248, 29, 1060, 1633, 8794],
#  [18,
#   282,
#   46,
#   742,
#   743,
#   1,
#   80,
#   2367,
#   54,
#   4626,
#   188,
#   2089,
#   19,
#   98,
#   28,
#   68,
#   590,
#   38,
#   977,
#   8794],
#  [179, 8, 8795, 902, 3781, 8794],
#  [1796,
#   4632,
#   19,
#   51,
#   38,
#   641,
#   188,
#   2089,
#   19,
#   45,
#   46,
#   977,
#   19,
#   45,
#   46,
#   977,
#   281,
#   19,
#   45,
#   46,
#   977,
#   3123,
#   4632,
#   3,
#   248,
#   159,
#   69,
#   1172,
#   8794],
#  [100, 26, 4519, 8794],
#  [119, 28, 2228, 68, 2128, 4519, 2389, 212, 8795, 8794],
#  [1023,
#   4653,
#   8795,
#   19,
#   77,
#   584,
#   96,
#   83,
#   4249,
#   101,
#   46,
#   8795,
#   8795,
#   114,
#   4654,
#   8794],
#  [54,
#   1282,
#   3804,
#   3311,
#   4655,
#   68,
#   38,
#   198,
#   15,
#   4239,
#   620,
#   38,
#   8795,
#   96,
#   4656,
#   8795,
#   8794],
#  [1977, 8794],
#  [92, 8794],
#  [414, 8794],
#  [562, 8794],
#  [400, 8794],
#  [562, 8794],
#  [2389, 8794],
#  [4659, 8794],
#  [3028, 8794],
#  [400, 8794],
#  [903, 8794],
#  [400, 8794],
#  [3111, 8794],
#  [400, 8794],
#  [4679, 8794],
#  [45, 1, 1147, 8794],
#  [1506, 79, 2859, 4663, 8794],
#  [756, 2642, 41, 86, 45, 231, 28, 8794],
#  [1676, 4686, 674, 1, 16, 679, 2460, 1400, 16, 8795, 1475, 8794],
#  [19, 248, 113, 882, 28, 8794],
#  [28,
#   325,
#   530,
#   1986,
#   1410,
#   4061,
#   68,
#   16,
#   2561,
#   19,
#   140,
#   28,
#   282,
#   19,
#   2898,
#   298,
#   368,
#   1023,
#   4653,
#   1090,
#   1065,
#   28,
#   182,
#   29,
#   33,
#   28,
#   639,
#   946,
#   8794],
#  [97, 29, 1827, 182, 212, 46, 1933, 8794],
#  [28,
#   248,
#   289,
#   33,
#   99,
#   24,
#   28,
#   87,
#   25,
#   221,
#   183,
#   26,
#   114,
#   257,
#   54,
#   3599,
#   248,
#   29,
#   28,
#   8794],
#  [1678, 4662, 8794],
#  [68, 616, 33, 8794],
#  [72, 19, 97, 29, 41, 1159, 620, 68, 122, 50, 1678, 4662, 302, 8794],
#  [235,
#   5,
#   371,
#   16,
#   234,
#   19,
#   194,
#   41,
#   26,
#   230,
#   501,
#   28,
#   80,
#   877,
#   54,
#   25,
#   4701,
#   15,
#   38,
#   4747,
#   8794],
#  [5,
#   28,
#   45,
#   46,
#   365,
#   6297,
#   181,
#   64,
#   98,
#   28,
#   68,
#   133,
#   4052,
#   181,
#   990,
#   33,
#   28,
#   8,
#   530,
#   304,
#   8794],
#  [100, 44, 28, 294, 8794],
#  [3361, 1600, 4766, 8794],
#  [183, 680, 24, 188, 1676, 26, 93, 28, 639, 745, 34, 8794],
#  [63, 897, 871, 68, 616, 28, 8794],
#  [114, 38, 759, 8794],
#  [28, 8, 174, 8794],
#  [6137, 3432, 6137, 8794],
#  [28, 2411, 142, 5, 19, 248, 972, 28, 706, 8794],
#  [1702, 8795, 8794],
#  [159,
#   93,
#   19,
#   248,
#   135,
#   14,
#   126,
#   5,
#   482,
#   265,
#   54,
#   3,
#   170,
#   28,
#   133,
#   1973,
#   977,
#   135,
#   87,
#   451,
#   487,
#   1068,
#   8794],
#  [469, 182, 4775, 114, 16, 8795, 8794],
#  [1342, 25, 26, 530, 4249, 8794],
#  [184, 277, 37, 97, 28, 98, 68, 97, 230, 41, 8794],
#  [3,
#   343,
#   231,
#   756,
#   46,
#   246,
#   182,
#   212,
#   46,
#   20,
#   65,
#   97,
#   29,
#   1,
#   135,
#   206,
#   5,
#   972,
#   123,
#   1807,
#   732,
#   46,
#   8795,
#   8794],
#  [119, 19, 51, 577, 578, 277, 972, 33, 38, 706, 8794],
#  [19, 44, 29, 99, 28, 325, 1045, 25, 8794],
#  [214, 19, 94, 28, 8, 93, 90, 659, 289, 740, 155, 8794],
#  [159, 93, 183, 6043, 8794],
#  [235, 40, 8794],
#  [19, 51, 4838, 8794],
#  [93, 114, 126, 1829, 8794],
#  [90,
#   659,
#   131,
#   16,
#   1813,
#   114,
#   46,
#   2884,
#   1,
#   516,
#   661,
#   8795,
#   34,
#   54,
#   1421,
#   8794],
#  [2627, 8794],
#  [42, 2627, 8794],
#  [146, 54, 10, 707, 77, 29, 181, 8794],
#  [4399, 94, 476, 152, 8794],
#  [226, 8794],
#  [214, 260, 954, 8794],
# ...
#   29,
#   1541,
#   828,
#   828,
#   77,
#   29,
#   1107,
#   4361,
#   280,
#   181,
#   77,
#   1381,
#   1609,
#   371,
#   46,
#   8795,
#   3544,
#   5,
#   5295,
#   113,
#   612,
#   16,
#   361,
#   8794],
#  [189,
#   118,
#   183,
#   26,
#   29,
#   423,
#   183,
#   26,
#   128,
#   60,
#   69,
#   4376,
#   28,
#   85,
#   289,
#   384,
#   94,
#   37,
#   28,
#   98,
#   384,
#   68,
#   94,
#   28,
#   2,
#   384,
#   865,
#   35,
#   72,
#   16,
#   501,
#   1159,
#   179,
#   45,
#   261,
#   704,
#   1045,
#   38,
#   4176,
#   54,
#   755,
#   8794],
#  [37,
#   4361,
#   280,
#   16,
#   457,
#   54,
#   203,
#   28,
#   97,
#   29,
#   766,
#   3105,
#   163,
#   68,
#   323,
#   1378,
#   25,
#   26,
#   37,
#   5295,
#   280,
#   230,
#   5282,
#   68,
#   16,
#   4048,
#   8794],
#  [35, 44, 19, 8794],
#  [106, 78, 447, 134, 8794],
#  [131, 114, 8794],
#  [831,
#   203,
#   37,
#   77,
#   41,
#   28,
#   280,
#   28,
#   325,
#   78,
#   334,
#   68,
#   865,
#   19,
#   77,
#   29,
#   16,
#   147,
#   303,
#   280,
#   8794],
#  [543,
#   129,
#   19,
#   51,
#   1744,
#   348,
#   28,
#   44,
#   114,
#   16,
#   544,
#   0,
#   892,
#   114,
#   16,
#   544,
#   8794],
#  [1309, 612, 136, 19, 97, 29, 194, 35, 8794],
#  [98, 1828, 8794],
#  [5283,
#   181,
#   26,
#   129,
#   660,
#   129,
#   828,
#   5,
#   1,
#   986,
#   99,
#   41,
#   277,
#   19,
#   60,
#   97,
#   41,
#   119,
#   19,
#   51,
#   2451,
#   14,
#   136,
#   1,
#   131,
#   16,
#   852,
#   68,
#   135,
#   1272,
#   8794],
#  [37, 8794],
#  [62,
#   1,
#   1000,
#   68,
#   1709,
#   5,
#   8795,
#   0,
#   3451,
#   38,
#   2005,
#   68,
#   16,
#   8795,
#   114,
#   3330,
#   828,
#   212,
#   361,
#   8794],
#  [2504,
#   879,
#   122,
#   54,
#   422,
#   1707,
#   2091,
#   339,
#   1525,
#   114,
#   182,
#   3944,
#   255,
#   181,
#   80,
#   34,
#   27,
#   8794],
#  [3647, 3362, 5295, 212, 414, 8794],
#  [19, 99, 142, 436, 330, 54, 16, 665, 8794],
#  [235, 182, 93, 182, 1220, 5367, 1, 325, 29, 2016, 28, 914, 8794],
#  [3,
#   1161,
#   26,
#   891,
#   46,
#   409,
#   86,
#   245,
#   96,
#   5,
#   24,
#   19,
#   325,
#   68,
#   320,
#   14,
#   182,
#   19,
#   21,
#   2290,
#   170,
#   1986,
#   136,
#   16,
#   1603,
#   26,
#   19,
#   51,
#   29,
#   95,
#   68,
#   320,
#   14,
#   2609,
#   8794],
#  [631, 8794],
#  [37, 16, 442, 8, 28, 268, 3, 26, 42, 377, 1154, 8794],
#  [188, 5369, 41, 26, 106, 68, 94, 28, 42, 2178, 5370, 8794],
#  [38,
#   1090,
#   507,
#   114,
#   230,
#   822,
#   114,
#   16,
#   3433,
#   142,
#   5728,
#   2752,
#   142,
#   15,
#   1635,
#   54,
#   38,
#   641,
#   77,
#   15,
#   1421,
#   114,
#   5381,
#   28,
#   325,
#   4943,
#   46,
#   224,
#   1331,
#   136,
#   126,
#   325,
#   40,
#   4624,
#   41,
#   77,
#   46,
#   2078,
#   2284,
#   277,
#   38,
#   641,
#   77,
#   1135,
#   68,
#   2631,
#   41,
#   136,
#   41,
#   77,
#   29,
#   16,
#   4938,
#   96,
#   16,
#   534,
#   68,
#   69,
#   114,
#   16,
#   1536,
#   96,
#   8795,
#   76,
#   35,
#   19,
#   60,
#   94,
#   129,
#   41,
#   21,
#   45,
#   231,
#   108,
#   278,
#   116,
#   181,
#   231,
#   126,
#   5,
#   25,
#   26,
#   16,
#   173,
#   279,
#   54,
#   100,
#   28,
#   325,
#   4943,
#   8794],
#  [41, 26, 29, 46, 311, 41, 26, 46, 2897, 40, 122, 685, 5982, 142, 8794],
#  [19,
#   51,
#   2091,
#   25,
#   239,
#   72,
#   19,
#   51,
#   724,
#   28,
#   248,
#   69,
#   5371,
#   5,
#   72,
#   19,
#   51,
#   5371,
#   28,
#   248,
#   85,
#   69,
#   5372,
#   8794],
#  [28,
#   8,
#   1986,
#   68,
#   131,
#   1410,
#   623,
#   34,
#   54,
#   384,
#   114,
#   1459,
#   136,
#   24,
#   28,
#   325,
#   68,
#   1837,
#   1236,
#   16,
#   6115,
#   28,
#   21,
#   513,
#   384,
#   4511,
#   16,
#   1983,
#   3681,
#   390,
#   422,
#   8795,
#   229,
#   230,
#   891,
#   3693,
#   525,
#   4278,
#   891,
#   136,
#   5386,
#   8794],
#  [179, 325, 8795, 16, 2984, 8795, 16, 6848, 8795, 16, 8795, 8794],
#  [21,
#   29,
#   619,
#   68,
#   28,
#   5,
#   179,
#   45,
#   80,
#   159,
#   28,
#   0,
#   528,
#   8795,
#   28,
#   0,
#   528,
#   46,
#   1131,
#   60,
#   28,
#   8794],
#  [1154,
#   212,
#   1220,
#   5,
#   8795,
#   19,
#   97,
#   98,
#   28,
#   68,
#   477,
#   5378,
#   136,
#   19,
#   98,
#   68,
#   477,
#   23,
#   28,
#   28,
#   194,
#   3,
#   1161,
#   26,
#   260,
#   327,
#   96,
#   28,
#   18,
#   41,
#   26,
#   260,
#   327,
#   96,
#   46,
#   409,
#   54,
#   42,
#   919,
#   19,
#   60,
#   94,
#   1919,
#   182,
#   46,
#   1974,
#   974,
#   8794],
#  [27, 8794],
#  [700, 19, 612, 41, 114, 16, 2404, 8794],
#  [5,
#   1047,
#   1974,
#   19,
#   1096,
#   256,
#   46,
#   3346,
#   1047,
#   1974,
#   76,
#   19,
#   80,
#   81,
#   5,
#   77,
#   34,
#   96,
#   46,
#   355,
#   54,
#   823,
#   5,
#   72,
#   19,
#   273,
#   154,
#   126,
#   28,
#   99,
#   37,
#   181,
#   280,
#   8794],
#  [679, 279, 8794],
#  [977, 8794],
#  [0, 1, 229, 8794],
#  [37, 8794],
#  [19, 51, 1254, 68, 2, 46, 8795, 182, 8794],
#  [136,
#   28,
#   8,
#   585,
#   19,
#   97,
#   99,
#   28,
#   52,
#   1311,
#   371,
#   417,
#   1220,
#   5367,
#   368,
#   8795,
#   94,
#   19,
#   51,
#   205,
#   3808,
#   68,
#   46,
#   318,
#   368,
#   8795,
#   631,
#   499,
#   181,
#   77,
#   46,
#   742,
#   743,
#   4167,
#   775,
#   28,
#   8794],
#  [179, 8, 38, 435, 4658, 8794],
#  [126, 26, 46, 1131, 54, 8795, 19, 97, 29, 98, 68, 676, 42, 2159, 8794],
#  [19, 77, 29, 2016, 28, 8794],
#  [620, 16, 2328, 15, 16, 93, 16, 198, 4082, 28, 45, 68, 70, 1419, 41, 8794],
#  [2874, 37, 8794],
#  [100,
#   26,
#   25,
#   851,
#   19,
#   187,
#   28,
#   871,
#   68,
#   245,
#   256,
#   46,
#   693,
#   5,
#   3002,
#   41,
#   26,
#   504,
#   122,
#   54,
#   412,
#   1742,
#   28,
#   60,
#   3597,
#   101,
#   28,
#   99,
#   256,
#   8794],
#  [674, 8794],
#  [1, 248, 1347, 76, 8794],
#  [28, 255, 37, 19, 280, 19, 51, 5400, 19, 215, 231, 4803, 14, 96, 823, 8794],
#  [68, 2361, 5413, 16, 1412, 368, 16, 805, 8794],
#  [28, 0, 94, 65, 41, 26, 2953, 8794],
#  [19,
#   20,
#   28,
#   86,
#   972,
#   740,
#   16,
#   5414,
#   3,
#   1495,
#   2367,
#   54,
#   69,
#   123,
#   1002,
#   2072,
#   8794],
#  [5, 8794],
#  [5,
#   37,
#   28,
#   187,
#   368,
#   16,
#   913,
#   798,
#   0,
#   19,
#   514,
#   27,
#   129,
#   1,
#   101,
#   114,
#   5437,
#   0,
#   19,
#   1080,
#   46,
#   981,
#   279,
#   364,
#   27,
#   8795,
#   26,
#   42,
#   124,
#   1226,
#   286,
#   63,
#   26,
#   29,
#   136,
#   1,
#   101,
#   1226,
#   3,
#   26,
#   96,
#   28,
#   8794],
#  [1, 516, 745, 256, 181, 26, 1466, 8794],
#  [19,
#   765,
#   4324,
#   181,
#   26,
#   4324,
#   3363,
#   181,
#   26,
#   10,
#   4324,
#   4955,
#   3674,
#   19,
#   78,
#   8795,
#   1272,
#   19,
#   51,
#   29,
#   35,
#   106,
#   181,
#   401,
#   33,
#   133,
#   79,
#   46,
#   5809,
#   181,
#   6347,
#   33,
#   19,
#   97,
#   29,
#   187,
#   181,
#   6347,
#   33,
#   8794],
#  [93, 35, 19, 0, 101, 181, 6347, 33, 35, 8794],
#  [35,
#   19,
#   357,
#   68,
#   2992,
#   23,
#   362,
#   5070,
#   68,
#   2,
#   1724,
#   19,
#   590,
#   3,
#   2215,
#   368,
#   8795,
#   19,
#   258,
#   256,
#   54,
#   28,
#   5,
#   816,
#   5,
#   16,
#   1681,
#   182,
#   1,
#   8,
#   8794],
#  [19, 612, 28, 1792, 126, 371, 16, 5191, 8794],
#  [19,
#   45,
#   615,
#   514,
#   63,
#   8126,
#   68,
#   28,
#   72,
#   19,
#   77,
#   46,
#   124,
#   377,
#   42,
#   641,
#   116,
#   615,
#   304,
#   374,
#   4585,
#   79,
#   19,
#   97,
#   29,
#   99,
#   16,
#   128,
#   79,
#   96,
#   494,
#   514,
#   96,
#   494,
#   16,
#   5758,
#   8794],
#  [8795, 181, 116, 615, 8795, 181, 343, 1532, 368, 16, 1007, 8794],
#  [661,
#   16,
#   1093,
#   8795,
#   620,
#   258,
#   8795,
#   258,
#   256,
#   661,
#   41,
#   620,
#   82,
#   19,
#   51,
#   163,
#   68,
#   2,
#   256,
#   8794],
#  [93, 27, 106, 8794],
#  [19,
#   78,
#   60,
#   87,
#   46,
#   3550,
#   16,
#   5420,
#   54,
#   16,
#   1248,
#   19,
#   215,
#   153,
#   1076,
#   37,
#   26,
#   16,
#   1452,
#   96,
#   3484,
#   1135,
#   25,
#   26,
#   46,
#   290,
#   1135,
#   3,
#   26,
#   1607,
#   26,
#   29,
#   41,
#   8794],
#  [19, 51, 143, 2157, 8, 28, 8794],
#  [19, 187, 5418, 19, 215, 80, 46, 1248, 23, 5418, 8794],
#  [19, 1417, 37, 230, 33, 765, 19, 100, 28, 4187, 8794],
#  [106, 82, 639, 19, 773, 5421, 8794],
#  [97, 28, 982, 82, 639, 19, 773, 5421, 8794],
#  [8795, 8794],
#  [1511, 1681, 1511, 1681, 8794],
#  [674, 19, 99, 8794],
#  [19, 51, 163, 68, 69, 81, 105, 26, 16, 8794],
#  [1464, 14, 45, 28, 80, 38, 5430, 8794],
#  [19, 280, 19, 97, 29, 45, 161, 8794],
#  [41, 26, 2197, 54, 38, 1421, 8794],
#  [27, 1, 248, 29, 229, 230, 41, 8794],
#  [175, 366, 8794],
#  [18,
#   41,
#   26,
#   78,
#   25,
#   16,
#   20,
#   1254,
#   68,
#   398,
#   14,
#   10,
#   8795,
#   114,
#   1191,
#   54,
#   46,
#   311,
#   82,
#   478,
#   96,
#   25,
#   563,
#   401,
#   33,
#   98,
#   68,
#   532,
#   8794],
#  [28, 8794],
#  [19, 80, 37, 19, 698, 96, 8794],
#  [45, 28, 116, 161, 337, 8794],
#  [8, 28, 2199, 8794],
#  [16, 4553, 16, 377, 23, 327, 606, 16, 122, 114, 38, 8795, 8794],
#  [19, 97, 29, 99, 65, 19, 280, 41, 19, 51, 1135, 8794],
#  [28, 44, 29, 2902, 33, 2468, 8795, 8794],
#  [19, 51, 1135, 8794],
#  [19, 51, 29, 32, 28, 68, 882, 33, 8794],
#  [100, 97, 28, 98, 68, 486, 8794],
#  [235, 1096, 33, 46, 22, 8794],
#  [674, 8794],
#  [19, 257, 68, 514, 8794],
#  [226,
#   28,
#   77,
#   29,
#   52,
#   5454,
#   564,
#   136,
#   25,
#   8795,
#   5455,
#   14,
#   52,
#   16,
#   2399,
#   972,
#   33,
#   38,
#   206,
#   911,
#   903,
#   28,
#   97,
#   29,
#   127,
#   33,
#   4023,
#   469,
#   8794],
#  [226, 8794],
#  [28, 8, 29, 16, 8795, 8, 28, 8794],
#  [263, 620, 409, 257, 46, 605, 8794],
#  [8795, 289, 740, 131, 5468, 306, 14, 182, 8794],
#  [214, 8794],
#  [615, 534, 28, 14, 1510, 100, 28, 289, 384, 97, 476, 79, 25, 8794],
#  [239,
#   476,
#   8795,
#   35,
#   159,
#   3,
#   8795,
#   2,
#   33,
#   194,
#   15,
#   3373,
#   3373,
#   5489,
#   16,
#   8795,
#   54,
#   16,
#   8795,
#   409,
#   5490,
#   5491,
#   15,
#   461,
#   15,
#   16,
#   8795,
#   487,
#   2557,
#   114,
#   8795,
#   28,
#   99,
#   16,
#   279,
#   8794],
#  [1506, 79, 28, 99, 46, 2172, 8794],
#  [19,
#   97,
#   29,
#   4821,
#   25,
#   28,
#   1775,
#   230,
#   183,
#   19,
#   194,
#   28,
#   1775,
#   230,
#   28,
#   187,
#   5467,
#   5467,
#   8795,
#   681,
#   124,
#   1600,
#   5503,
#   79,
#   28,
#   101,
#   19,
#   60,
#   2338,
#   28,
#   14,
#   23,
#   25,
#   19,
#   80,
#   376,
#   358,
#   122,
#   8,
#   29,
#   114,
#   1161,
#   16,
#   362,
#   122,
#   5400,
#   35,
#   28,
#   15,
#   38,
#   269,
#   8794],
#  [135, 245, 256, 8794],
#  [19,
#   97,
#   29,
#   94,
#   65,
#   1,
#   80,
#   68,
#   619,
#   1509,
#   41,
#   72,
#   28,
#   5,
#   19,
#   99,
#   3,
#   8,
#   29,
#   163,
#   68,
#   564,
#   8794],
#  [226, 8794],
#  [28, 97, 29, 80, 68, 131, 14, 136, 19, 80, 68, 135, 8794],
#  [78, 230, 284, 28, 99, 41, 0, 69, 1932, 82, 29, 78, 258, 33, 83, 8794],
#  [905, 388, 5468, 28, 8, 46, 1316, 461, 3946, 8794],
#  [41,
#   26,
#   29,
#   8795,
#   5,
#   16,
#   85,
#   234,
#   28,
#   8,
#   163,
#   68,
#   1347,
#   1418,
#   23,
#   41,
#   26,
#   68,
#   546,
#   41,
#   68,
#   256,
#   5,
#   445,
#   181,
#   26,
#   2052,
#   28,
#   0,
#   2756,
#   41,
#   620,
#   412,
#   1782,
#   8794],
#  [1903, 608, 671, 2008, 8794],
#  [28, 159, 93, 28, 27, 8794],
#  [159, 93, 100, 26, 16, 365, 1153, 8794],
#  [972, 740, 46, 13, 8794],
#  [19, 248, 131, 256, 96, 28, 5527, 8794],
#  [24, 28, 8, 163, 68, 972, 33, 46, 1875, 501, 697, 2046, 8794],
#  [8795, 2897, 2396, 4671, 8795, 3401, 8795, 8795, 5543, 5281, 8794],
#  [106, 530, 106, 8794],
#  [19, 248, 1070, 41, 34, 8794],
#  [1464, 14, 8794],
#  [46, 742, 208, 3569, 1, 243, 45, 1863, 256, 8794],
#  [289, 740, 135, 256, 944, 8794],
#  [29, 277, 409, 27, 29, 277, 564, 23, 33, 8794],
#  [19, 97, 29, 99, 8794],
#  [670, 96, 776, 8794],
#  [10, 2046, 699, 46, 8795, 46, 8795, 28, 33, 211, 28, 8794],
#  [29, 114, 25, 1828, 8794],
#  [20, 28, 672, 38, 234, 1378, 299, 8795, 1329, 8794],
#  [181, 26, 288, 114, 4515, 179, 98, 256, 944, 76, 1, 0, 45, 256, 8794],
#  [181,
#   248,
#   87,
#   34,
#   28,
#   890,
#   33,
#   19,
#   51,
#   8795,
#   181,
#   248,
#   616,
#   740,
#   159,
#   54,
#   740,
#   28,
#   97,
#   29,
#   1323,
#   46,
#   394,
#   8794],
#  [2609, 8794],
#  [19, 51, 657, 25, 26, 46, 124, 34, 54, 42, 8794],
#  [119,
#   371,
#   16,
#   1231,
#   1974,
#   54,
#   8795,
#   161,
#   2220,
#   25,
#   45,
#   8795,
#   8795,
#   8795,
#   972,
#   3956,
#   68,
#   8795,
#   8795,
#   79,
#   3296,
#   883,
#   46,
#   2786,
#   1048,
#   16,
#   1048,
#   8795,
#   8794],
#  [72, 97, 28, 1808, 38, 1475, 8794],
#  [342, 181, 160, 8794],
#  [8795,
#   182,
#   3224,
#   16,
#   8795,
#   28,
#   3282,
#   15,
#   1127,
#   8795,
#   8795,
#   212,
#   8795,
#   25,
#   16,
#   85,
#   8795,
#   8795,
#   25,
#   8795,
#   212,
#   80,
#   26,
#   16,
#   5050,
#   1707,
#   28,
#   516,
#   131,
#   15,
#   41,
#   8794],
#  [3, 26, 8795, 8, 28, 478, 8794],
#  [63, 26, 29, 23, 28, 8794],
#  [97, 28, 45, 83, 1017, 5585, 8794],
#  [5570,
#   8795,
#   8795,
#   8795,
#   3572,
#   3440,
#   5489,
#   8795,
#   4620,
#   4549,
#   68,
#   2498,
#   350,
#   96,
#   981,
#   4576,
#   8795,
#   8794],
#  [1107, 54, 1210, 31, 8794],
#  [8795, 8794],
#  [8795, 8794],
#  [226, 41, 26, 27, 19, 79, 68, 5590, 35, 100, 8, 28, 268, 8794],
#  [40, 19, 80, 46, 1248, 8794],
#  [1904, 28, 97, 29, 508, 129, 1695, 129, 28, 67, 68, 8794],
#  [38, 127, 1532, 5284, 25, 5592, 33, 8794],
#  [28, 8, 163, 68, 69, 469, 16, 2392, 8794],
#  [0, 19, 357, 114, 8794],
#  [16, 377, 25, 64, 29, 133, 79, 25, 377, 8794],
#  [19, 51, 23, 16, 1480, 8321, 54, 8795, 5596, 8794],
#  [1135, 8794],
#  [226, 97, 38, 1127, 136, 97, 29, 6307, 1154, 613, 8794],
#  [5, 183, 97, 19, 135, 68, 230, 28, 8794],
#  [35, 19, 51, 46, 1852, 54, 3272, 622, 33, 8794],
#  [19, 51, 1135, 8794],
#  [235, 8794],
#  [25, 26, 504, 50, 19, 60, 97, 8794],
#  [19, 97, 29, 99, 19, 194, 19, 788, 83, 8794],
#  [19, 51, 29, 134, 26, 126, 46, 3028, 8794],
#  [45, 28, 685, 1179, 38, 1206, 8794],
#  [25, 487, 54, 16, 1267, 1378, 182, 8, 211, 4549, 76, 33, 8794],
#  [3940, 2713, 28, 21, 516, 131, 114, 182, 8795, 212, 1792, 96, 28, 8794],
#  [414, 8794],
#  [31, 8794],
#  [8795,
#   8795,
#   54,
#   16,
#   35,
#   1469,
#   8795,
#   2999,
#   2480,
#   8795,
#   54,
#   16,
#   8795,
#   2480,
#   8795,
#   8795,
#   54,
#   16,
#   6446,
#   8794],
#  [136, 114, 38, 5610, 25, 26, 46, 849, 8794],
#  [24, 63, 26, 16, 2292, 1227, 8794],
#  [159,
#   8795,
#   1337,
#   26,
#   970,
#   3490,
#   1045,
#   38,
#   8795,
#   1666,
#   10,
#   8795,
#   8795,
#   19,
#   865,
#   5,
#   46,
#   3371,
#   469,
#   3336,
#   8795,
#   26,
#   970,
#   8795,
#   8794],
#  [37, 2232, 8794],
#  [1154, 212, 1989, 3156, 5559, 8794],
#  [1746, 8794],
#  [37, 26, 38, 1248, 8794],
#  [674, 8794],
#  [19,
#   77,
#   2010,
#   24,
#   28,
#   243,
#   776,
#   33,
#   19,
#   19,
#   630,
#   68,
#   45,
#   505,
#   42,
#   8795,
#   1390,
#   54,
#   991,
#   2354,
#   1378,
#   182,
#   8794],
#  [946, 4673, 8794],
#  [19,
#   51,
#   1135,
#   5,
#   479,
#   479,
#   4089,
#   5,
#   132,
#   18,
#   26,
#   29,
#   181,
#   5,
#   8795,
#   129,
#   18,
#   8794],
#  [46, 1971, 4613, 737, 54, 3384, 3055, 46, 656, 8794],
#  [19,
#   672,
#   41,
#   35,
#   2851,
#   28,
#   131,
#   15,
#   46,
#   1933,
#   5,
#   337,
#   28,
#   99,
#   41,
#   28,
#   8,
#   34,
#   182,
#   114,
#   16,
#   1799,
#   8795,
#   2421,
#   998,
#   46,
#   1729,
#   366,
#   3741,
#   740,
#   68,
#   182,
#   1340,
#   17,
#   8794],
#  [105, 8, 28, 1919, 16, 1429, 3951, 8794],
#  [18, 25, 3225, 891, 131, 16, 517, 298, 368, 33, 19, 187, 41, 8794],
#  [5, 25, 26, 41, 8794],
#  [19, 97, 29, 45, 68, 482, 46, 2701, 114, 38, 1573, 1048, 8794],
#  [5626, 5627, 28, 116, 256, 135, 154, 135, 154, 8794],
#  [946, 4673, 8794],
#  [65, 64, 41, 113, 564, 34, 28, 5, 534, 8794],
#  [41,
#   113,
#   1227,
#   34,
#   119,
#   19,
#   51,
#   1045,
#   479,
#   5,
#   5628,
#   5,
#   132,
#   170,
#   25,
#   26,
#   65,
#   35,
#   19,
#   2190,
#   14,
#   23,
#   203,
#   183,
#   8,
#   530,
#   106,
#   584,
#   136,
#   252,
#   211,
#   8795,
#   775,
#   19,
#   765,
#   24,
#   28,
#   0,
#   141,
#   25,
#   277,
#   24,
#   28,
#   248,
#   614,
#   33,
#   19,
#   45,
#   68,
#   135,
#   87,
#   504,
#   1616,
#   1586,
#   8795,
#   1127,
#   105,
#   487,
#   147,
#   1820,
#   5539,
#   1942,
#   779,
#   33,
#   100,
#   5629,
#   412,
#   1496,
#   26,
#   8794],
#  [277, 289, 740, 482, 16, 1778, 154, 5, 131, 83, 68, 528, 8794],
#  [37, 96, 8794],
#  [19, 97, 29, 98, 68, 69, 478, 8794],
#  [19, 44, 29, 99, 25, 8794],
#  [19, 79, 41, 8794],
#  [28,
#   370,
#   114,
#   5639,
#   16,
#   85,
#   234,
#   114,
#   82,
#   34,
#   54,
#   38,
#   1117,
#   26,
#   371,
#   2108,
#   5,
#   28,
#   45,
#   1788,
#   357,
#   620,
#   182,
#   96,
#   458,
#   5,
#   4125,
#   5,
#   68,
#   87,
#   46,
#   2178,
#   8794],
#  [114, 16, 1304, 8794],
#  [348, 28, 376, 98, 24, 28, 45, 80, 16, 501, 19, 215, 80, 16, 8795, 8794],
#  [674,
#   70,
#   4357,
#   179,
#   98,
#   37,
#   179,
#   194,
#   179,
#   60,
#   45,
#   144,
#   23,
#   203,
#   25,
#   26,
#   65,
#   1386,
#   26,
#   1971,
#   1378,
#   182,
#   3149,
#   578,
#   28,
#   60,
#   45,
#   33,
#   6245,
#   8794],
#  [3090, 5, 5647, 19, 3855, 52, 16, 320, 8794],
#  [19, 51, 1135, 8794],
#  [4540, 33, 65, 97, 29, 28, 28, 290, 977, 54, 46, 495, 8794],
#  [5680, 8794],
#  [1746, 8794],
#  [94,
#   19,
#   60,
#   258,
#   384,
#   25,
#   19,
#   60,
#   685,
#   289,
#   384,
#   99,
#   41,
#   401,
#   381,
#   115,
#   18,
#   2642,
#   46,
#   2516,
#   19,
#   60,
#   289,
#   25,
#   1684,
#   28,
#   729,
#   8794],
#  [938, 8794],
#  [19, 215, 80, 68, 135, 277, 8794],
#  [119, 181, 26, 3829, 34, 52, 1463, 41, 26, 46, 787, 8794],
#  [183, 622, 68, 269, 41, 8794],
#  [72, 44, 1, 131, 41, 368, 384, 8794],
#  [1796, 41, 26, 8795, 5672, 8794],
#  [41, 26, 35, 327, 8794],
#  [100,
#   97,
#   28,
#   131,
#   1236,
#   422,
#   8795,
#   18,
#   28,
#   8,
#   93,
#   8795,
#   37,
#   26,
#   16,
#   5674,
#   8795,
#   8794],
#  [235, 674, 41, 21, 1188, 616, 256, 8794],
#  [2150, 944, 8795, 25, 77, 1839, 8794],
#  [46, 1447, 46, 5677, 885, 114, 16, 5663, 8794],
#  [18,
#   25,
#   26,
#   184,
#   76,
#   3238,
#   286,
#   41,
#   78,
#   3955,
#   68,
#   33,
#   19,
#   97,
#   29,
#   99,
#   105,
#   19,
#   370,
#   19,
#   51,
#   505,
#   19,
#   97,
#   29,
#   99,
#   105,
#   206,
#   26,
#   21,
#   28,
#   614,
#   33,
#   8794],
#  [150, 8794],
#  [235, 40, 235, 42, 3814, 289, 740, 131, 256, 1045, 16, 2968, 8794],
#  [19, 78, 903, 3, 26, 649, 106, 14, 126, 8794],
#  ...]

# %% [markdown]
# <br>
#
# # 4. Building the Seq2Seq Model
#
# ---
#
# A typical sequence to sequence model has two parts which both the parts are practically two different neural network models combined into one giant network.:
#
# - **An Encoder:** The task of an encoder network is to understand the input sequence, and create a smaller dimensional representation of it. This representation is then forwarded to a decoder network
# - **An Decoder:** The task of an decoder network is to generates a sequence of its own that represents the output.
#
# This can be used for machine translation or for free-from question answering (generating a natural language answer given a natural language question) -- in general, it is applicable any time you need to generate text.

# %%
# Function for creating the placeholers for inputs and targets
def model_inputs():
    """
    Create placeholders for inputs, targets, learning rate, and keep probability for dropout.
    """
    # Inputs
    inputs = tf.placeholder(dtype = tf.int32, shape = [None, None], name = 'input')
    
    # Targets
    targets = tf.placeholder(dtype = tf.int32, shape = [None, None], name = 'target')
    
    # Learning rate
    lr = tf.placeholder(dtype = tf.float32, name = 'learning_rate')
    
    # Keep probability (for dropout)
    keep_prob = tf.placeholder(dtype = tf.float32, name = 'keep_prob')
    
    return inputs, targets, lr, keep_prob

# %%
# Function for preprocesing the targets (create batches + add <SOS> at the start of each sentence)
def preprocess_targets(targets, word2int, batch_size):
    """
    Preprocessing the target by:
        1. Creating batches
        2. Adding <SOS> at the begining of each sentence
    """
    # Left side: <SOS> tensor
    left_side = tf.fill(dims = [batch_size, 1], value = word2int['<SOS>'])
    
    # Right side: Sliced targets
    right_side = tf.strided_slice(input_ = targets, begin = [0,0], end = [batch_size, -1], strides = [1,1])
    
    # Concatenating two tensors
    preprocessed_targets = tf.concat(values = [left_side, right_side], axis = 1)
    
    return preprocessed_targets

# %%
# Create the Encoder RNN Layer
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    """
    Encoder RNN Layer
    """
    # Basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(num_units = rnn_size)
    
    # Add dropout
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(cell = lstm, input_keep_prob = keep_prob)
    
    # Create RNN cell composed sequentially of multiple simple cells
    encoder_cell = tf.contrib.rnn.MultiRNNCell(cells = [lstm_dropout] * num_layers)
    
    # Dynamic version of Bidirectional RNN
    encoder_output, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell,
                                                                    cell_bw = encoder_cell,
                                                                    sequence_length = sequence_length,
                                                                    inputs = rnn_inputs,
                                                                    dtype = tf.float32)
    return encoder_state

# %%
# Decode the training set
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, 
                        output_function, keep_prob, batch_size):
    """
    Decoding the training set.
    """
    # Initialize the attention
    attention_states = tf.zeros(shape = [batch_size, 1, decoder_cell.output_size])
    
    # Prepare keys / values / functions for attention
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states = attention_states, 
                                                                                                                                    attention_option = "bahdanau", 
                                                                                                                                    num_units = decoder_cell.output_size)
    
    # Attentional decoder function for dynamic_rnn_decoder during training
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state = encoder_state[0],
                                                                              attention_keys = attention_keys,
                                                                              attention_values = attention_values,
                                                                              attention_score_fn = attention_score_function,
                                                                              attention_construct_fn = attention_construct_function,
                                                                              name = "attn_dec_train")
    
    # Dynamic RNN decoder for a sequence-to-sequence model specified by RNNCell and decoder function
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(cell = decoder_cell,
                                                                                                              decoder_fn = training_decoder_function,
                                                                                                              inputs = decoder_embedded_input,
                                                                                                              sequence_length = sequence_length,
                                                                                                              scope = decoding_scope)
    # Add dropout
    decoder_output_dropout = tf.nn.dropout(x = decoder_output, keep_prob = keep_prob)
    
    return output_function(decoder_output_dropout)

# %%
# Decode the test/validation set
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, 
                    decoding_scope, output_function, keep_prob, batch_size):
    """
    Decoding the test set / validation set.
    """
    # Initialize the attention
    attention_states = tf.zeros(shape = [batch_size, 1, decoder_cell.output_size])
    
    # Prepare keys / values / functions for attention
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states = attention_states, 
                                                                                                                                    attention_option = "bahdanau", 
                                                                                                                                    num_units = decoder_cell.output_size)
    # Attentional decoder function for dynamic_rnn_decoder during inference
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_fn = output_function,
                                                                              encoder_state = encoder_state[0],
                                                                              attention_keys = attention_keys,
                                                                              attention_values = attention_values,
                                                                              attention_score_fn = attention_score_function,
                                                                              attention_construct_fn = attention_construct_function,
                                                                              embeddings = decoder_embeddings_matrix,
                                                                              start_of_sequence_id = sos_id,
                                                                              end_of_sequence_id = eos_id,
                                                                              maximum_length = maximum_length,
                                                                              num_decoder_symbols = num_words,
                                                                              name = "attn_dec_inf")
    
    # Dynamic RNN decoder for a sequence-to-sequence model specified by RNNCell and decoder function
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(cell = decoder_cell,
                                                                                                                decoder_fn = test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# %%
# Create Decoder RNN
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, 
                rnn_size, num_layers, word2int, keep_prob, batch_size):
    """
    Creating Decoder RNN
    """
    # Variable scope
    with tf.variable_scope("decoding") as decoding_scope:
        
        # Basic LSTM cell
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        
        # Add dropout
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        
        # Create RNN cell composed sequentially of multiple simple cells
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        
        # Initialize the weights
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        
        # Initialize the biases
        biases = tf.zeros_initializer()
        
        # Add a Fully Connected Layer
        output_function = lambda x: tf.contrib.layers.fully_connected(inputs = x,
                                                                      num_outputs = num_words,
                                                                      normalizer_fn = None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        # Decoding the training set
        training_predictions = decode_training_set(encoder_state = encoder_state,
                                                   decoder_cell = decoder_cell,
                                                   decoder_embedded_input = decoder_embedded_input,
                                                   sequence_length = sequence_length,
                                                   decoding_scope = decoding_scope,
                                                   output_function = output_function,
                                                   keep_prob = keep_prob,
                                                   batch_size = batch_size)
        
        # Reuse variables
        decoding_scope.reuse_variables()
        
        # Decoding the test set
        test_predictions = decode_test_set(encoder_state = encoder_state,
                                           decoder_cell = decoder_cell,
                                           decoder_embeddings_matrix = decoder_embeddings_matrix,
                                           sos_id = word2int['<SOS>'],
                                           eos_id = word2int['<EOS>'],
                                           maximum_length = sequence_length - 1,
                                           num_words = num_words,
                                           decoding_scope = decoding_scope,
                                           output_function = output_function,
                                           keep_prob = keep_prob,
                                           batch_size = batch_size)
        
    return training_predictions, test_predictions

# %%
# Build the seq2seq model
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, 
                  encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    """
    Seq2Seq Model
    """
    # Maps a sequence of symbols to a sequence of embeddings
    encoder_embedded_input = tf.contrib.layers.embed_sequence(ids = inputs,
                                                              vocab_size = answers_num_words + 1,
                                                              embed_dim = encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    
    # Encoder RNN Layer
    encoder_state = encoder_rnn(rnn_inputs = encoder_embedded_input, 
                                rnn_size = rnn_size, 
                                num_layers = num_layers, 
                                keep_prob = keep_prob, 
                                sequence_length = sequence_length)
    
    # Preprocessing the target by creating batches & Adding <SOS> at the begining of each sentence
    preprocessed_targets = preprocess_targets(targets = targets, 
                                              word2int = questionswords2int, 
                                              batch_size = batch_size)
    
    # Decoder embedding matrix
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform(shape = [questions_num_words + 1, decoder_embedding_size], minval = 0, maxval = 1))
    
    # Decoder embedding input
    decoder_embedded_input = tf.nn.embedding_lookup(params = decoder_embeddings_matrix, 
                                                    ids = preprocessed_targets)
    
    # Decoder RNN Layer
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input = decoder_embedded_input,
                                                         decoder_embeddings_matrix = decoder_embeddings_matrix,
                                                         encoder_state = encoder_state,
                                                         num_words = questions_num_words,
                                                         sequence_length = sequence_length,
                                                         rnn_size = rnn_size,
                                                         num_layers = num_layers,
                                                         word2int = questionswords2int,
                                                         keep_prob = keep_prob,
                                                         batch_size = batch_size)
    
    return training_predictions, test_predictions

# %% [markdown]
# <br>
#
# # 5. Training the Seq2Seq Model
#
# ---

# %%
# Setting the Hyperparameters
epochs = 10
batch_size = 64
rnn_size = 512
num_layers = 3
encoding_embedding_size = 512
decoding_embedding_size = 512
learning_rate = 0.01
learning_rate_decay = 0.9
min_learning_rate = 0.0001
keep_probability = 0.5  # Based on the paper for Geoffery Hinton: "Dropout 20% of the input units and 50% of the hidden units"

# %%
# Reset the default graph
tf.reset_default_graph()

# Define a session
session = tf.InteractiveSession()

# %%
# Load the model input
inputs, targets, lr, keep_prob = model_inputs()

# %%
# Set the sequence length (if you remmber, before we set this to 25 as maximum length)
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')

# %%
# Get the shape of the inputs tensor
input_shape = tf.shape(inputs)

# %%
# Get the training & test predictions
training_predictions, test_predictions = seq2seq_model(inputs = tf.reverse(tensor = inputs, axis = [-1]), 
                                                       targets = targets, 
                                                       keep_prob = keep_prob, 
                                                       batch_size = batch_size, 
                                                       sequence_length = sequence_length, 
                                                       answers_num_words = len(answerints2word), 
                                                       questions_num_words = len(questionwords2int), 
                                                       encoder_embedding_size = encoding_embedding_size, 
                                                       decoder_embedding_size = decoding_embedding_size, 
                                                       rnn_size = rnn_size, 
                                                       num_layers = num_layers, 
                                                       questionswords2int = questionwords2int)

# %%
# Set up the Loss Error, the Optimizer, and the Gradient Clipping
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)

# %%
# Padding the sequences with the <PAD> token (for having the same length)
# Question: [ 'Who', 'are', 'you', '<PAD>', '<PAD>', '<PAD>', '<PAD>' ]
# Answer: [ <SOS>, 'I', 'am', 'a', 'bot', '.', '<EOS>', '<PAD>' ]
def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %%
# Split the dataset into batches of questions and answers
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionwords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerwords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %%
# Split the questions & answers into training and validation sets
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]

# %%
# Training
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "chatbot_weights.ckpt" # For Windows users, replace this line of code by: checkpoint = "./chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")
# Out:
# Epoch:   1/10, Batch:    0/2689, Training Loss Error:  0.091, Training Time on 100 Batches: 1798 seconds
# Epoch:   1/10, Batch:  100/2689, Training Loss Error:  9.336, Training Time on 100 Batches: 789 seconds
# Epoch:   1/10, Batch:  200/2689, Training Loss Error:  4.966, Training Time on 100 Batches: 1309 seconds
# Epoch:   1/10, Batch:  300/2689, Training Loss Error:  2.495, Training Time on 100 Batches: 1160 seconds
# Epoch:   1/10, Batch:  400/2689, Training Loss Error:  2.389, Training Time on 100 Batches: 2446 seconds
# Epoch:   1/10, Batch:  500/2689, Training Loss Error:  2.338, Training Time on 100 Batches: 2396 seconds
# Epoch:   1/10, Batch:  600/2689, Training Loss Error:  2.180, Training Time on 100 Batches: 2235 seconds
# Epoch:   1/10, Batch:  700/2689, Training Loss Error:  2.372, Training Time on 100 Batches: 1640 seconds
# Epoch:   1/10, Batch:  800/2689, Training Loss Error:  2.232, Training Time on 100 Batches: 1197 seconds
# Epoch:   1/10, Batch:  900/2689, Training Loss Error:  2.061, Training Time on 100 Batches: 2361 seconds
# Epoch:   1/10, Batch: 1000/2689, Training Loss Error:  1.995, Training Time on 100 Batches: 1089 seconds
# Epoch:   1/10, Batch: 1100/2689, Training Loss Error:  1.927, Training Time on 100 Batches: 1274 seconds
# Epoch:   1/10, Batch: 1200/2689, Training Loss Error:  1.971, Training Time on 100 Batches: 1339 seconds
# Epoch:   1/10, Batch: 1300/2689, Training Loss Error:  1.945, Training Time on 100 Batches: 3164 seconds
# Validation Loss Error:  1.807, Batch Validation Time: 2386 seconds
# I speak better now!!
# Epoch:   1/10, Batch: 1400/2689, Training Loss Error:  1.904, Training Time on 100 Batches: 1789 seconds
# Epoch:   1/10, Batch: 1500/2689, Training Loss Error:  1.881, Training Time on 100 Batches: 2027 seconds
# Epoch:   1/10, Batch: 1600/2689, Training Loss Error:  1.930, Training Time on 100 Batches: 885 seconds
# Epoch:   1/10, Batch: 1700/2689, Training Loss Error:  1.880, Training Time on 100 Batches: 1132 seconds
# Epoch:   1/10, Batch: 1800/2689, Training Loss Error:  1.971, Training Time on 100 Batches: 1392 seconds
# Epoch:   1/10, Batch: 1900/2689, Training Loss Error:  2.027, Training Time on 100 Batches: 1085 seconds
# Epoch:   1/10, Batch: 2000/2689, Training Loss Error:  1.922, Training Time on 100 Batches: 1000 seconds
# Epoch:   1/10, Batch: 2100/2689, Training Loss Error:  1.944, Training Time on 100 Batches: 2693 seconds
# Epoch:   1/10, Batch: 2200/2689, Training Loss Error:  1.894, Training Time on 100 Batches: 1618 seconds
# Epoch:   1/10, Batch: 2300/2689, Training Loss Error:  1.930, Training Time on 100 Batches: 1376 seconds
# Epoch:   1/10, Batch: 2400/2689, Training Loss Error:  1.877, Training Time on 100 Batches: 1302 seconds
# Epoch:   1/10, Batch: 2500/2689, Training Loss Error:  1.928, Training Time on 100 Batches: 1380 seconds
# Epoch:   1/10, Batch: 2600/2689, Training Loss Error:  2.030, Training Time on 100 Batches: 1321 seconds
